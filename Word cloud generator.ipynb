# %%
import requests
import re
from bs4 import BeautifulSoup
import string
import numpy as np
import pandas as pd
# Out:
# 'my/url/'

# %% [markdown]
# ## Pulling all the reviews for a specific game

# %%
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36"
headers = {'User-Agent':user_agent}
justcause4_rev = requests.get("https://www.metacritic.com/game/playstation-4/just-cause-4/critic-reviews",
                         headers = headers)

# %%
justcause4_details = requests.get("https://www.metacritic.com/game/playstation-4/just-cause-4/details",
                         headers = headers)
jc4_detail_soup = BeautifulSoup(justcause4_details.content, 'html.parser')
jc4_detail_soup
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "https://www.w3.org/TR/html4/strict.dtd">
#
# <html xml:lang="en">
# <head>
# <title>Just Cause 4 Details and Credits for PlayStation 4 - Metacritic</title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/><script type="text/javascript">window.NREUM||(NREUM={}),__nr_require=function(e,n,t){function r(t){if(!n[t]){var o=n[t]={exports:{}};e[t][0].call(o.exports,function(n){var o=e[t][1][n];return r(o||n)},o,o.exports)}return n[t].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<t.length;o++)r(t[o]);return r}({1:[function(e,n,t){function r(){}function o(e,n,t){return function(){return i(e,[c.now()].concat(u(arguments)),n?null:this,t),n?void 0:this}}var i=e("handle"),a=e(3),u=e(4),f=e("ee").get("tracer"),c=e("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var p=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],d="api-",l=d+"ixn-";a(p,function(e,n){s[n]=o(d+n,!0,"api")}),s.addPageAction=o(d+"addPageAction",!0),s.setCurrentRouteName=o(d+"routeName",!0),n.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(e,n){var t={},r=this,o="function"==typeof n;return i(l+"tracer",[c.now(),e,t],r),function(){if(f.emit((o?"":"no-")+"fn-start",[c.now(),r,o],t),o)try{return n.apply(this,arguments)}catch(e){throw f.emit("fn-err",[arguments,this,e],t),e}finally{f.emit("fn-end",[c.now()],t)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(e,n){m[n]=o(l+n)}),newrelic.noticeError=function(e){"string"==typeof e&&(e=new Error(e)),i("err",[e,c.now()])}},{}],2:[function(e,n,t){function r(e,n){if(!o)return!1;if(e!==o)return!1;if(!n)return!0;if(!i)return!1;for(var t=i.split("."),r=n.split("."),a=0;a<r.length;a++)if(r[a]!==t[a])return!1;return!0}var o=null,i=null,a=/Version\/(\S+)\s+Safari/;if(navigator.userAgent){var u=navigator.userAgent,f=u.match(a);f&&u.indexOf("Chrome")===-1&&u.indexOf("Chromium")===-1&&(o="Safari",i=f[1])}n.exports={agent:o,version:i,match:r}},{}],3:[function(e,n,t){function r(e,n){var t=[],r="",i=0;for(r in e)o.call(e,r)&&(t[i]=n(r,e[r]),i+=1);return t}var o=Object.prototype.hasOwnProperty;n.exports=r},{}],4:[function(e,n,t){function r(e,n,t){n||(n=0),"undefined"==typeof t&&(t=e?e.length:0);for(var r=-1,o=t-n||0,i=Array(o<0?0:o);++r<o;)i[r]=e[n+r];return i}n.exports=r},{}],5:[function(e,n,t){n.exports={exists:"undefined"!=typeof window.performance&&window.performance.timing&&"undefined"!=typeof window.performance.timing.navigationStart}},{}],ee:[function(e,n,t){function r(){}function o(e){function n(e){return e&&e instanceof r?e:e?f(e,u,i):i()}function t(t,r,o,i){if(!d.aborted||i){e&&e(t,r,o);for(var a=n(o),u=v(t),f=u.length,c=0;c<f;c++)u[c].apply(a,r);var p=s[y[t]];return p&&p.push([b,t,r,a]),a}}function l(e,n){h[e]=v(e).concat(n)}function m(e,n){var t=h[e];if(t)for(var r=0;r<t.length;r++)t[r]===n&&t.splice(r,1)}function v(e){return h[e]||[]}function g(e){return p[e]=p[e]||o(t)}function w(e,n){c(e,function(e,t){n=n||"feature",y[t]=n,n in s||(s[n]=[])})}var h={},y={},b={on:l,addEventListener:l,removeEventListener:m,emit:t,get:g,listeners:v,context:n,buffer:w,abort:a,aborted:!1};return b}function i(){return new r}function a(){(s.api||s.feature)&&(d.aborted=!0,s=d.backlog={})}var u="nr@context",f=e("gos"),c=e(3),s={},p={},d=n.exports=o();d.backlog=s},{}],gos:[function(e,n,t){function r(e,n,t){if(o.call(e,n))return e[n];var r=t();if(Object.defineProperty&&Object.keys)try{return Object.defineProperty(e,n,{value:r,writable:!0,enumerable:!1}),r}catch(i){}return e[n]=r,r}var o=Object.prototype.hasOwnProperty;n.exports=r},{}],handle:[function(e,n,t){function r(e,n,t,r){o.buffer([e],r),o.emit(e,n,t)}var o=e("ee").get("handle");n.exports=r,r.ee=o},{}],id:[function(e,n,t){function r(e){var n=typeof e;return!e||"object"!==n&&"function"!==n?-1:e===window?0:a(e,i,function(){return o++})}var o=1,i="nr@id",a=e("gos");n.exports=r},{}],loader:[function(e,n,t){function r(){if(!E++){var e=x.info=NREUM.info,n=l.getElementsByTagName("script")[0];if(setTimeout(s.abort,3e4),!(e&&e.licenseKey&& ...
# <meta content="Get credits and details for Just Cause 4 on PlayStation 4 at Metacritic.com" name="description"/>
# <meta content="width=1024" name="viewport"/>
# <meta content="Metacritic" name="application-name"/>
# <meta content="#000000" name="msapplication-TileColor"/>
# <meta content="/images/win8tile/76bf1426-2886-4b87-ae1c-06424b6bb8a2.png" name="msapplication-TileImage"/>
# <meta content="Just Cause 4" property="og:title"/>
# <meta content="game" property="og:type"/>
# <meta content="https://www.metacritic.com/game/playstation-4/just-cause-4" property="og:url"/>
# <meta content="https://static.metacritic.com/images/products/games/2/5f6b71620647af99372eab883acaef21-98.jpg" property="og:image"/>
# <meta content="Metacritic" property="og:site_name"/>
# <meta content="123113677890173" property="fb:app_id"/>
# <meta content="Just Cause 4 for PlayStation 4 game reviews &amp; Metacritic score: Welcome to Solis, a huge South American world home of conflict, oppression and extreme weather conditions. Just Cause 4 sees rogue hero Rico Rodriguez land in S..." property="og:description"/>
# <link charset="utf-8" href="/css/fonts/proxima-nova/stylesheet.css" rel="stylesheet" type="text/css"/>
# <link href="/css/global.min.1544738507.css" rel="stylesheet" type="text/css"/>
# <link href="/css/product/base.min.1544738422.css" rel="stylesheet" type="text/css"/>
# <link href="//maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet"/>
# <link href="https://www.metacritic.com/game/playstation-4/just-cause-4/details" rel="canonical">
# <script type="text/javascript">
#
#         (function(id){function append(scriptid,url,async){var d=document,sn='script',f=d.getElementsByTagName(sn)[0];if(!f)f=d.head;var s=d.createElement(sn);s.async=!0;s.id=scriptid;s.src=url;f.parentNode.insertBefore(s,f)}
#         function getRootDomain(){var parts=window.location.hostname.split('.');if(parts.length===2)rootDomain=parts[0];else if(parts.length>2){var part=parts[parts.length-2];if(part==='com'||part==='co'){rootDomain=parts[parts.length-3]}
#         else{rootDomain=part}}
#         return rootDomain}
#         window.evidon={};window.evidon.id=id;var cdn='//c.evidon.com/',rootDomain=getRootDomain(),noticecdn=cdn+'sitenotice/';append('evidon-notice',noticecdn+'evidon-sitenotice-tag.js',!1);append('evidon-location',cdn+'geo/country.js',!0);append('evidon-themes',noticecdn+id+'/snthemes.js',!0);if(rootDomain)append('evidon-settings',noticecdn+id+'/'+rootDomain+'/settings.js',!0);
#         window.evidon.priorConsentCallback=function(){
#             // IX Ad Bidding
#             append('ix-lib',  (('https:' == document.location.protocol)?'https:':'http:') + '///js-sec.indexww.com/ht/ls-metacritic.js', true);
#             // GPT/DFP ads
#             append('gpt-lib', (('https:' == document.location.protocol)?'https:':'http:') + '//www.googletagservices.com/tag/js/gpt.js', true);
#             // Sharethrough
#             append('st-lib', (('https:' == document.location.protocol)?'https:':'http:') + '//native.sharethrough.com/assets/tag.js', true);
#             // Google Analytics
#             append('ga-lib', (('https:' == document.location.protocol)?'https://ssl':'http://www') + '.google-analytics.com/ga.js', true);
#             // Omniture
#             window.gdprConsent = true;
#             if (typeof om == 'object' && typeof om.fireGdprTags != 'undefined') { om.fireGdprTags(); }
#             // Taboola
#                         load_vendor_taboola();
#                     }
#         window.evidon.closeCallback=function(){}
#         window.evidon.consentWithdrawnCallback=function(){}})(425)
#
#     </script>
# <script src="/js/global.min.1544738507.js" type="text/javascript"></script>
# <script type="text/javascript">
#
#
#         var googletag = googletag || {};
#         googletag.cmd = googletag.cmd || [];
#         window.metac_ads_pushdisplay = window.metac_ads_pushdisplay || [];
#         window.metac_gallery_ads_pushdisplay = window.metac_gallery_ads_pushdisplay || [];
#         window.metac_hover_ads_pushdisplay = window.metac_hover_ads_pushdisplay || [];
#
#     </script>
# <script type="text/javascript">
#
#     	MC_USER_LOGGED_IN = false;
#
#
#
#             window._taboola = window._taboola || [];
#             function load_vendor_taboola(){
#                 _taboola.push({
#                     other : 'auto'
#                 });
#                 !function (e, f, u) {
#                     e.async = 1;
#                     e.src = u;
#                     f.parentNode.insertBefore(e, f);
#                 }(document.createElement('script'),
#                 document.getElementsByTagName('script')[0],
#                 '//cdn.taboola.com/libtrc/cbsinteractive-metacritic/loader.js');
#             }
#
#             </script>
# <script src="//vidtech.cbsinteractive.com/uvpjs/2.9.52/CBSI-PLAYER.js"></script>
# <script src="//imasdk.googleapis.com/js/sdkloader/ima3.js" type="text/javascript"></script>
# </link></head>
# <body>
# <div id="site_layout">
# <div id="masthead">
# <div id="nav_ad_wrapper">
# <div class="ad_unit" id="nav_ad">
# <script type="text/javascript">
#
#                         googletag.cmd.push(function() {
#
#                                                             window.metac_g_ad_nav_ad = googletag.defineSlot("/8264/uk-metacritic/games",[[5,5],[7,7]], "nav_ad").addService(googletag.pubads()).setTargeting("pos", "nav").setCollapseEmptyDiv(true, true);
#
#
#                         });
#
#                                                     window.metac_ads_pushdisplay.push("nav_ad");
#                                                             </script>
# </div>
# </div>
# <div id="content_header_wrapper">
# <header id="top_header">
# <nav id="primary_nav">
# <nav class="primary_nav_item" id="primary_logo">
# <a href="https://www.metacritic.com"><img alt="Metacritic logo" src="/images/icons/dark_logo.png"/></a>
# </nav>
# <nav class="primary_nav_item" id="primary_search">
# <div class="rounded_field">
# <div class="imgs">
# <img alt="search" class="inactive" src="/images/icons/search_inactive.png"/>
# <img alt="search" class="active" src="/images/icons/search_active.png"/>
# </div>
# <div class="field innerLabel">
# <div class="input_wrapper">
# <form action="/search" autocomplete="off" method="post">
# <label for="primary_search_box">search...</label>
# <input autocomplete="off" id="primary_search_box" name="search_term"/>
# <input name="search_filter" type="hidden" value="all"/>
# </form>
# </div>
# </div>
# </div>
# <div id="primary_search_results">
# </div>
# </nav>
# <nav class="primary_nav_item" id="primary_nav_item_movies">
# <span class="primary_nav_text">
# <a href="https://www.metacritic.com/movie">
#                                                     Movies
#                                             </a>
# </span>
# <nav class="primary_drop_down">
# <span class="cutout_wrapper">
# <i aria-hidden="true" class="fa fa-caret-down"></i>
# </span>
# <div class="primary_feature">
# <a href="/feature/best-movies-released-in-2018">
# <div class="primary_feature_blur" style="background-image: url(https://static.metacritic.com/images/features/main/2018best_movie_roma-180.jpg)"></div>
# <img alt="The Best Movies of 2018 Image" class="primary_feature_img" src="https://static.metacritic.com/images/features/main/2018best_movie_roma-180.jpg">
# </img></a>
# <span class="primary_feature_text"><a href="/feature/best-movies-released-in-2018">The Best Movies of 2018</a></span>
# </div>
# <nav class="primary_dditems">
# <a href="/feature/movie">More Reports</a>
# <a href="/movie">All Movies &gt;</a>
# <a href="/browse/movies/release-date/theaters/date">In Theaters</a>
# <a href="/browse/movies/release-date/coming-soon/date">Coming Soon</a>
# <a href="/browse/dvds/release-date/new-releases/date">New to DVD &amp; Streaming</a>
# <a href="/browse/movies/score/metascore/all/filtered/netflix">Best of Netflix</a>
# <a href="/browse/movies/score/metascore/all/filtered/piv">Best of Amazon</a>
# <a href="/browse/movies/score/metascore/all/filtered">Best Movies of All Time</a>
# <a href="/browse/movies/genre/date">Browse Movies by Genre</a>
# </nav>
# </nav>
# </nav>
# <nav class="primary_nav_item selected" id="primary_nav_item_games">
# <span class="primary_nav_text">
# <a href="https://www.metacritic.com/game">
#                                                     Games
#                                             </a>
# </span>
# <span class="cutout_wrapper selected">
# <i aria-hidden="true" class="fa fa-caret-down"></i>
# </span>
# <nav class="primary_drop_down">
# <span class="cutout_wrapper">
# <i aria-hidden="true" class="fa fa-caret-down"></i>
# </span>
# <div class="primary_feature">
# <a href="/feature/best-videogames-released-in-2018">
# <div class="primary_feature_blur" style="background-image: url(https://static.metacritic.com/images/features/main/2018best_game_rdr2-180.jpg)"></div>
# <img alt="The Best Videogames of 2018 Image" class="primary_feature_img" src="https://static.metacritic.com/images/features/main/2018best_game_rdr2-180.jpg">
# </img></a>
# <span class="primary_feature_text"><a href="/feature/best-videogames-released-in-2018">The Best Videogames of 2018</a></span>
# </div>
# <nav class="primary_dditems">
# <a href="/feature/game">More Reports</a>
# <a href="/game">All Games &gt;</a>
# <a href="/game/playstation-4">PS4</a>
# <a href="/game/xbox-one">Xbox One</a>
# <a href="/game/pc">PC</a>
# <a href="/game/switch">Switch</a>
# <a href="/game/wii-u">Wii U</a>
# <a href="/game/3ds">3DS</a>
# <a href="/game/playstation-vita">PS Vita</a>
# <a href="/game/ios">iOS</a>
# <a href="/game/legacy">Legacy</a>
# </nav>
# </nav>
# </nav>
# <nav class="primary_nav_item" id="primary_nav_item_tv">
# <span class="primary_nav_text">
# <a href="https://www.metacritic.com/tv">
#                                                     TV
#                                             </a>
# </span>
# <nav class="primary_drop_down">
# <span class="cutout_wrapper">
# <i aria-hidden="true" class="fa fa-caret-down"></i>
# </span>
# <div class="primary_feature">
# <a href="/feature/dvd-blu-ray-release-calendar-january-2019">
# <div class="primary_feature_blur" style="background-image: url(https://static.metacritic.com/images/features/main/dvd_2019_01-180.jpg)"></div>
# <img alt="DVD/Blu-ray Release Calendar: January 2019 Image" class="primary_feature_img" src="https://static.metacritic.com/images/features/main/dvd_2019_01-180.jpg">
# </img></a>
# <span class="primary_feature_text"><a href="/feature/dvd-blu-ray-release-calendar-january-2019">DVD/Blu-ray Release Calendar: January 2019</a></span>
# </div>
# <nav class="primary_dditems">
# <a href="/feature/tv">More Reports</a>
# <a href="/tv">All TV &gt;</a>
# <a href="/browse/tv/release-date/new-series/date">New Shows</a>
# <a href="/browse/tv/score/metascore/all/filtered/netflix">Best of Netflix</a>
# <a href="/browse/tv/score/metascore/all/filtered/piv">Best of Amazon</a>
# <a href="/browse/tv/score/metascore/all/filtered">Best TV Shows</a>
# <a href="/browse/tv/genre/date">Browse TV by Genre</a>
# </nav>
# </nav>
# </nav>
# <nav class="primary_nav_item" id="primary_nav_item_music">
# <span class="primary_nav_text">
# <a href="https://www.metacritic.com/music">
#                                                     Music
#                                             </a>
# </span>
# <nav class="primary_drop_down">
# <span class="cutout_wrapper">
# <i aria-hidden="true" class="fa fa-caret-down"></i>
# </span>
# <div class="primary_feature">
# <a href="/feature/best-albums-released-in-2018">
# <div class="primary_feature_blur" style="background-image: url(https://static.metacritic.com/images/features/main/2018best_music_noname-180.jpg)"></div>
# <img alt="The Best Albums of 2018 Image" class="primary_feature_img" src="https://static.metacritic.com/images/features/main/2018best_music_noname-180.jpg"/>
# </a>
# <span class="primary_feature_text"><a href="/feature/best-albums-released-in-2018">The Best Albums of 2018</a></span>
# </div>
# <nav class="primary_dditems">
# <a href="/feature/album">More Reports</a>
# <a href="/music">All Music &gt;</a>
# <a href="/browse/albums/release-date/new-releases/date">New Releases</a>
# <a href="/browse/albums/release-date/coming-soon/date">Coming Soon</a>
# <a href="/browse/albums/score/metascore/90day/filtered">Best New Albums</a>
# <a href="/browse/albums/score/metascore/all/filtered">Best Albums of All Time</a>
# <a href="/browse/albums/genre/date">Browse Music by Genre</a>
# </nav>
# </nav>
# </nav>
# <nav class="primary_nav_item" id="primary_nav_item_features">
# <span class="primary_nav_text">
# <a href="https://www.metacritic.com/feature">
#                                                     Reports
#                                             </a>
# </span>
# </nav>
# <nav class="" id="primary_menu_item_enter_search">
# <span class="">
#                 Enter to Search
#             </span>
# </nav>
# <nav class="primary_nav_item" id="primary_menu_item_create">
# <span class="primary_nav_text">
# <a href="https://secure.metacritic.com/signup" id="signup">+ Create Account</a>
# </span>
# </nav>
# <nav class="primary_nav_item" id="primary_menu_item_login">
# <span class="primary_nav_text">
# <a href="https://secure.metacritic.com/login" id="login">Login</a>
# </span>
# </nav>
# </nav>
# <nav class="clearfix hgrayblue inset_left2 inset_right2" id="secondary_nav">
# <div class="social_round" id="primary_social">
# <span>follow on</span>
# <a href="https://twitter.com/metacritic" rel="noopener" target="_blank"><i class="fa fa-twitter"></i></a>
# <a href="https://www.facebook.com/Metacritic" rel="noopener" target="_blank"><i class="fa fa-facebook"></i></a>
# </div>
# <nav class="secondary_nav_list" id="secondary_nav_games">
# <a href="/browse/games/release-date/new-releases/ps4/date">New Releases</a>
# <a href="/browse/games/release-date/coming-soon/ps4/date">Coming Soon</a>
# <a href="/browse/games/score/metascore/90day/ps4/filtered">Best Games</a>
# <a href="/browse/games/publication/reviewed">Publications</a>
# <a href="/browse/games/company/reviewed">Publishers</a>
# <a href="/browse/games/trailers/ps4/date">Trailers</a>
# </nav>
# </nav>
# <header id="primary_backdrop">
# </header>
# </header>
# </div>
# </div>
# <div class="site_gutters" id="mantle_skin">
# <div class="ad_unit" id="skin">
# <script type="text/javascript">
#
#                         googletag.cmd.push(function() {
#
#                                                             window.metac_g_ad_skin = googletag.defineSlot("/8264/uk-metacritic/games",[1600,1000], "skin").addService(googletag.pubads()).setTargeting("pos", "top");
#
#
#                         });
#
#                                                     window.metac_ads_pushdisplay.push("skin");
#                                                             </script>
# </div>
# <div class="site_gutters" id="gutters">
# <div class="site_gutters" id="gutters_mid">
# <div class="site_gutters" id="gutters_btm">
# <div class="site_gutters" id="gutters_top">
# <div id="container">
# <div class="leader" id="superleader">
# <div class="ad_height_min" id="leader_top_wrapper">
# <div class="ad_unit" id="leader_plus_top">
# <script type="text/javascript">
#
#                         googletag.cmd.push(function() {
#
#                                                             window.metac_g_ad_leader_plus_top = googletag.defineSlot("/8264/uk-metacritic/games",[[728,90],[970,66],[970,250],[728,91],[321,31],[7,7]], "leader_plus_top").addService(googletag.pubads()).setTargeting("pos", "top");
#
#
#                         });
#
#                                                     window.metac_ads_pushdisplay.push("leader_plus_top");
#                                                             </script>
# </div>
# </div>
# </div>
# <div class="col_layout" id="col_layout">
# <div class="content_section mpu_layout" id="main_content">
# <div class="layout">
# <div class="site_gutters" id="gutters">
# <div class="col main_col" id="main">
# <div class="content_head product_content_head game_content_head">
# <div class="sharing ">
# <a class="sharing-facebook" data-mc-social-url="https://www.metacritic.com/game/playstation-4/just-cause-4?ftag=fbsoshares" href="javascript:void(0);" rel="nofollow noopener popup:external" title="Share on Facebook"><span class="fa fa-fw fa-facebook"></span></a><a class="sharing-twitter" href="https://twitter.com/intent/tweet?via=metacritic&amp;text=Just%20Cause%204%20Details%20and%20Credits%20for%20PlayStation%204&amp;url=http%3A%2F%2Fmtcr.tc%2F2DSpsTK" rel="nofollow noopener popup:external" target="_blank" title="Share on Twitter"><span class="fa fa-fw fa-twitter"></span></a><a class="sharing-reddit" data-mc-social-track-id="6" href="https://www.reddit.com/submit?url=https%3A%2F%2Fwww.metacritic.com%2Fgame%2Fplaystation-4%2Fjust-cause-4%3Fftag%3Dredsoshares&amp;title=Just%20Cause%204%20Details%20and%20Credits%20for%20PlayStation%204" rel="nofollow noopener popup:external" target="_blank" title="Share on Reddit"><span class="fa fa-fw fa-reddit-alien"></span></a><a class="sharing-pinterest" data-mc-social-track-id="5" href="//pinterest.com/pin/create/link/?url=https%3A%2F%2Fwww.metacritic.com%2Fgame%2Fplaystation-4%2Fjust-cause-4%3Fftag%3Dpinsoshares&amp;description=Just%20Cause%204%20Details%20and%20Credits%20for%20PlayStation%204&amp;media=https://static.metacritic.com/images/products/games/2/5f6b71620647af99372eab883acaef21.jpg" rel="nofollow noopener popup:external" target="_blank" title="Share on Pinterest"><span class="fa fa-fw fa-pinterest"></span></a></div>
# <div class="product_title">
# <a class="hover_none" href="/game/playstation-4/just-cause-4">
# <h1>Just Cause 4</h1>
# </a>
# <span class="platform">
# <a href="/game/playstation-4">
#                                                         PlayStation 4
#                                                     </a>
# </span>
# </div>
# <div class="product_data">
# <ul class="summary_details">
# <li class="summary_detail publisher">
# <span class="label">Publisher:</span>
# <span class="data">
# <a href="/company/square-enix">
#                                                         Square Enix
#                                                     </a>
# </span>
# </li>
# <li class="summary_detail release_data">
# <span class="label">Release Date:</span>
# <span class="data">Dec  4, 2018</span>
# </li>
# <li class="summary_detail product_platforms">
# <span class="label">Also On:</span>
# <span class="data">
# <a class="hover_none" href="/game/pc/just-cause-4">PC</a>,                                                                            <a class="hover_none" href="/game/xbox-one/just-cause-4">Xbox One</a> </span>
# </li>
# </ul>
# </div>
# </div>
# <div class="content_nav">
# <ul class="nav_items content_nav">
# <li class="nav nav_summary first_nav">
# <span class="nav_item">
# <span class="nav_item_wrap">
# <a class="action" href="/game/playstation-4/just-cause-4">Summary</a>
# </span>
# </span>
# </li>
# <li class="nav nav_critic_reviews">
# <span class="nav_item">
# <span class="nav_item_wrap">
# <a class="action" href="/game/playstation-4/just-cause-4/critic-reviews">Critic Reviews</a>
# </span>
# </span>
# </li>
# <li class="nav nav_user_reviews">
# <span class="nav_item">
# <span class="nav_item_wrap">
# <a class="action" href="/game/playstation-4/just-cause-4/user-reviews">User Reviews</a>
# </span>
# </span>
# </li>
# <li class="nav nav_details active_nav">
# <span class="nav_item">
# <span class="nav_item_wrap">
# <span class="action">Details &amp; Credits</span>
# </span>
# </span>
# </li>
# <li class="nav nav_trailers last_nav">
# <span class="nav_item">
# <span class="nav_item_wrap">
# <a class="action" href="/game/playstation-4/just-cause-4/trailers">Trailers &amp; Videos</a>
# </span>
# </span>
# </li>
# </ul>
# </div>
# <div class="module product_data">
# <div class="module_wrap has_image has_large_image">
# <div class="product_media large_media">
# <div class="product_image large_image">
# <img alt="Just Cause 4 Image" class="product_image large_image" src="https://static.metacritic.com/images/products/games/2/5f6b71620647af99372eab883acaef21-98.jpg"/>
# </div>
# </div>
# <div class="summary_wrap">
# <div class="section product_scores">
# <div class="details main_details">
# <div class="score_summary metascore_summary">
# <div class="metascore_wrap feature_metascore">
# <div class="label">Metascore</div>
# <a class="metascore_anchor" href="/game/playstation-4/just-cause-4/critic-reviews">
# <div class="metascore_w large game mixed"><meta content="100" itemprop="bestRating"/><span itemprop="ratingValue">66</span></div>
# </a>
# <div class="summary">
# <p>
# <span class="desc">
#                                             Mixed or average reviews
#                                     </span>
# <span class="count">
# <span class="separator"> - </span>
# <span class="based">based on</span>
# <a href="/game/playstation-4/just-cause-4/critic-reviews">
# <span>
#                                 34
#                             </span> Critics                                            </a>
# </span>
# </p>
# </div>
# </div>
# </div>
# </div>
# <div class="details side_details">
# <div class="score_summary">
# <div class="userscore_wrap feature_userscore">
# <div class="label">User Score</div>
# <a class="metascore_anchor" href="/game/playstation-4/just-cause-4/user-reviews">
# <div class="metascore_w user large game mixed">5.6</div>
# </a>
# <div class="summary">
# <p><span class="desc">Mixed or average reviews</span><span class="count"><span class="separator">- </span><span class="based">based on</span> <a href="/game/playstation-4/just-cause-4/user-reviews">146 Ratings</a></span></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="section product_details">
# <div class="summary_detail product_summary">
# <span class="label">Summary:</span>
# <span class="data">Welcome to Solis, a huge South American world home of conflict, oppression and extreme weather conditions. Just Cause 4 sees rogue hero Rico Rodriguez land in Solis to hunt down the truth about his past, at any costs. Strap into your wingsuit, equip your fully customizable grappling hook, and get ready to bring the thunder. Soar through the skies with your wingsuit - Skydive, Base Jump and Free Dive with no limits. Fight your enemies under extreme weather conditions, including treacherous tornadoes and tropical lightning storms, taking the iconic Just Cause action to insane new heights. Use extreme weather events to your advantage thanks to never seen before in-game physics. Spearhead the rebellion and defeat the Black Hand, a hi-tech private military organisation. Face off against Gabriela Morales – your most fierce, capable, and unpredictable adversary yet. Uncover the truth of Rico’s father’s past life on Solís’ and its extreme weather. Explore the remote South American country of Solís, home of conflict, secrets, and danger. Enjoy 100 square kilometres of exotic playground, from rainforest to desert, via snowy mountain peaks. Discover a plethora of wonders as you explore the world of Solís from bustling cities to rural grasslands. [Square Enix]
#
# </span>
# </div>
# <div class="esite_list"><div class="esite_items clearfix list_expand_wrapper">
# <div class="esite_btn_wrapper">
# <div class="esite_btn esite_amazon esite_amazonbuy" title="Buy from Amazon">
# <table>
# <tr>
# <td class="esite_label_wrapper">
# <span>Buy On</span>
# </td>
# <td class="esite_img_wrapper">
# <a class="esite_url" data-leadid="1" data-leadname="amazon" data-leadplace="upper body" data-leadtag="metacritic-games-20" data-leadtype="Physical Product" href="http://www.amazon.com/dp/B07DJX3XWZ%3FSubscriptionId%3DAKIAJHSMUOWEQCQ7QDAQ%26tag%3Dmetacritic-games-20%26linkCode%3Dxm2%26camp%3D2025%26creative%3D165953%26creativeASIN%3DB07DJX3XWZ" rel="nofollow noopener" target="_blank">
# <img alt="" src="/images/buttons/esites/amazondotcom_30.png"/>
# </a>
# </td>
# </tr>
# </table>
# </div>
# </div></div><script type="text/javascript">window.eventAmazonBuyView = true;</script></div>
# </div>
# </div>
# </div>
# </div>
# <div class="product_details">
# <table cellspacing="0">
# <tr class="alt">
# <th scope="row">Rating:</th>
# <td>M</td>
# </tr>
# <tr>
# <th scope="row">Developer:</th>
# <td>Avalanche Studios</td>
# </tr>
# <tr class="alt">
# <th scope="row">Genre(s):</th>
# <td>
#                         Action Adventure,                                            Open-World                            </td>
# </tr>
# <tr><th scope="row">Number of Online Players:</th><td>No Online Multiplayer</td></tr> </table>
# </div>
# <div class="credits_list">
# <div class="credits_gamefaqs">
#         Designer/Producer/Programmer credits provided by <a href="https://gamefaqs.gamespot.com" target="_blank">GameFAQs</a>.
#     </div>
# <div class="credits_andme">
#         If you contributed to this game and feel you should be
#         credited, please read our
#
#         <a href="/faq">FAQ</a>.
#     </div>
# </div>
# <div id="taboola-below-content-thumbnails"></div>
# <script type="text/javascript">
#             var placement = 'desktop product_detail Below Content Thumbnails';
#             window._taboola = window._taboola || [];
#                 _taboola.push({
#                 mode: 'alternating-thumbnails-a',
#                 container: 'taboola-below-content-thumbnails',
#                 placement: placement,
#                 target_type: 'mix'
#             });
#         </script>
# </div>
# <div class="col side_col" id="side">
# <div class="ad_unit" id="mpu_plus_top">
# <script type="text/javascript">
#
#                         googletag.cmd.push(function() {
#
#                                                             window.metac_g_ad_mpu_plus_top = googletag.defineSlot("/8264/uk-metacritic/games",[[300,250],[300,600]], "mpu_plus_top").addService(googletag.pubads()).setTargeting("pos", "top");
#
#
#                         });
#
#                                                     window.metac_ads_pushdisplay.push("mpu_plus_top");
#                                                             </script>
# </div>
# <div class="module list_rankings contain_module">
# <div class="head head_type_1"><div class="head_wrap"><h2 class="module_title">Awards &amp; Rankings</h2></div></div>
# <div class="body">
# <table class="rankings">
# <tr>
# <td class="ranking_icon">
# <a href="/browse/games/score/metascore/discussed/ps4/filtered?sort=desc&amp;year_selected=2018">
# <i class="fa fa-trophy"></i>
# <div class="shield">35</div>
# </a>
# </td>
# <td class="ranking_wrap">
# <div class="ranking_title">
# <a href="/browse/games/score/metascore/discussed/ps4/filtered?sort=desc&amp;year_selected=2018">#35 Most Discussed PS4 Game of 2018</a>
# </div>
# </td>
# </tr>
# </table>
# </div>
# </div>
# <div class="module supplements_module" id="supplementary-nav">
# <div class="head head_type_1"><div class="head_wrap"><h2 class="module_title">Essential Links</h2></div></div>
# <div class="body">
# <div class="body_wrap">
# <div class="supplements supplement_links" id="supplementary-items">
# <ol class="supplements supplement_links">
# <li class="supplement supplement_link">
# <a class="section dw_tag {'tag':'supplementary-nav;item;1'}" href="https://www.metacritic.com/browse/games/release-date/new-releases/ps4/date">New PS4 Releases by Date</a>
# </li>
# <li class="supplement supplement_link">
# <a class="section dw_tag {'tag':'supplementary-nav;item;2'}" href="https://www.metacritic.com/browse/games/release-date/new-releases/ps4/name">New PS4 Releases by Title</a>
# </li>
# <li class="supplement supplement_link">
# <a class="section dw_tag {'tag':'supplementary-nav;item;3'}" href="https://www.metacritic.com/browse/games/release-date/new-releases/ps4/metascore">Best Recent Releases for PS4</a>
# </li>
# <li class="supplement supplement_link">
# <a class="section dw_tag {'tag':'supplementary-nav;item;4'}" href="https://www.metacritic.com/browse/games/release-date/coming-soon/ps4/date">Upcoming PS4 Release Calendar</a>
# </li>
# <li class="supplement supplement_link">
# <a class="section dw_tag {'tag':'supplementary-nav;item;5'}" href="https://www.metacritic.com/browse/games/score/metascore/year/ps4?year_selected=2018&amp;sort=desc">2018 High Scores - PS4</a>
# </li>
# <li class="supplement supplement_link">
# <a class="section dw_tag {'tag':'supplementary-nav;item;6'}" href="https://www.metacritic.com/browse/games/score/metascore/all/ps4?sort=desc">All-Time High Scores - PS4</a>
# </li>
# <li class="supplement supplement_link">
# <a class="section dw_tag {'tag':'supplementary-nav;item;7'}" href="https://www.metacritic.com/browse/games/title/ps4">All PS4 Games: A-Z Index</a>
# </li>
# <li class="supplement supplement_link">
# <a class="section dw_tag {'tag':'supplementary-nav;item;8'}" href="https://www.metacritic.com/pictures/worst-videogames-of-2018">Worst Games of 2018</a>
# </li>
# </ol>
# </div>
# <div class="supplements supplement_articles" id="supplementary-articles">
# <ol class="supplements supplement_articles">
# <li class="supplement supplement_link">
# <a class="dw_tag {'tag':'supplementary-nav;article;1'}" href="/feature/vote-for-the-best-of-2018">Vote for the Best of 2018</a>
# </li>
# <li class="supplement supplement_link">
# <a class="dw_tag {'tag':'supplementary-nav;article;2'}" href="https://www.metacritic.com/feature/major-upcoming-video-game-release-dates-xbox-ps4-pc-switch">Release Dates for Notable Upcoming Games</a>
# </li>
# <li class="supplement supplement_link">
# <a class="dw_tag {'tag':'supplementary-nav;article;3'}" href="https://www.metacritic.com/feature/new-free-games-playstation-xbox-pc-switch">This Month's Free PS4 Games</a>
# </li>
# </ol>
# <div class="more_supplements more_articles">
# <a class="dw_tag {'tag':'supplementary-nav;more-articles'}" href="/feature">More articles »</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div id="taboola-right-rail-thumbnails"></div>
# <script type="text/javascript">
#         if ( window._taboola ) {
#                         var placement = 'desktop product_detail Right Rail Thumbnails';
#             _taboola.push({
#                 mode: 'alternating-thumbnails-rr',
#                 container: 'taboola-right-rail-thumbnails',
#                 placement: placement,
#                 target_type: 'mix'
#             });
#                     }
#     </script>
# <div class="module products_module list_product_titles_widget_module contain_module">
# <div class="head head_type_1"><div class="head_wrap"><h2 class="module_title"><a href="/browse/games/release-date/new-releases/ps4/date">Current PS4 Games</a></h2><div class="more"><span class="more_item"><a href="/browse/games/release-date/new-releases/ps4/date">Full List »</a></span></div></div></div>
# <div class="body">
# <div class="tabs ">
# <div class="tab_wrap">
# <ul class="tabs tabs_type_1"> <li class="tab tab_type_1 tab_metascore first">
# <span class="active"><span>By Metascore</span></span>
# </li>
# <li class="tab tab_type_1 tab_userscore last">
# <a href="/game/playstation-4/just-cause-4/details?recent-sort=userscore"><span>By user score</span></a>
# </li>
# </ul>
# </div>
# </div>
# <div class="body_wrap">
# <div class="product_titles">
# <table class="score_title_table">
# <tr class="score_title_row">
# <td class="score_col">
# <a class="metascore_anchor" href="/game/playstation-4/red-dead-redemption-2">
# <span class="metascore_w small game positive">97</span>
# </a>
# </td>
# <td class="title_col">
# <a class="product_title" href="/game/playstation-4/red-dead-redemption-2">
#                     Red Dead Redemption 2
#                     </a>
# </td>
# </tr>
# <tr class="score_title_row">
# <td class="score_col">
# <a class="metascore_anchor" href="/game/playstation-4/marvels-spider-man">
# <span class="metascore_w small game positive">87</span>
# </a>
# </td>
# <td class="title_col">
# <a class="product_title" href="/game/playstation-4/marvels-spider-man">
#                     Marvel's Spider-Man
#                     </a>
# </td>
# </tr>
# <tr class="score_title_row">
# <td class="score_col">
# <a class="metascore_anchor" href="/game/playstation-4/dragon-quest-xi-echoes-of-an-elusive-age">
# <span class="metascore_w small game positive">86</span>
# </a>
# </td>
# <td class="title_col">
# <a class="product_title" href="/game/playstation-4/dragon-quest-xi-echoes-of-an-elusive-age">
#                     Dragon Quest XI: Echoes of an Elusive Age
#                     </a>
# </td>
# </tr>
# <tr class="score_title_row">
# <td class="score_col">
# <a class="metascore_anchor" href="/game/playstation-4/yakuza-kiwami-2">
# <span class="metascore_w small game positive">85</span>
# </a>
# </td>
# <td class="title_col">
# <a class="product_title" href="/game/playstation-4/yakuza-kiwami-2">
#                     Yakuza Kiwami 2
#                     </a>
# </td>
# </tr>
# <tr class="score_title_row">
# <td class="score_col">
# <a class="metascore_anchor" href="/game/playstation-4/valkyria-chronicles-4">
# <span class="metascore_w small game positive">84</span>
# </a>
# </td>
# <td class="title_col">
# <a class="product_title" href="/game/playstation-4/valkyria-chronicles-4">
#                     Valkyria Chronicles 4
#                     </a>
# </td>
# </tr>
# <tr class="score_title_row">
# <td class="score_col">
# <a class="metascore_anchor" href="/game/playstation-4/call-of-duty-black-ops-4">
# <span class="metascore_w small game positive">83</span>
# </a>
# </td>
# <td class="title_col">
# <a class="product_title" href="/game/playstation-4/call-of-duty-black-ops-4">
#                     Call of Duty: Black Ops 4
#                     </a>
# </td>
# </tr>
# <tr class="score_title_row">
# <td class="score_col">
# <a class="metascore_anchor" href="/game/playstation-4/assassins-creed-odyssey">
# <span class="metascore_w small game positive">82</span>
# </a>
# </td>
# <td class="title_col">
# <a class="product_title" href="/game/playstation-4/assassins-creed-odyssey">
#                     Assassin's Creed Odyssey
#                     </a>
# </td>
# </tr>
# <tr class="score_title_row">
# <td class="score_col">
# <a class="metascore_anchor" href="/game/playstation-4/mega-man-x-legacy-collection-1-+-2">
# <span class="metascore_w small game positive">80</span>
# </a>
# </td>
# <td class="title_col">
# <a class="product_title" href="/game/playstation-4/mega-man-x-legacy-collection-1-+-2">
#                     Mega Man X Legacy Collection 1 + 2
#                     </a>
# </td>
# </tr>
# <tr class="score_title_row">
# <td class="score_col">
# <a class="metascore_anchor" href="/game/playstation-4/shadow-of-the-tomb-raider">
# <span class="metascore_w small game positive">76</span>
# </a>
# </td>
# <td class="title_col">
# <a class="product_title" href="/game/playstation-4/shadow-of-the-tomb-raider">
#                     Shadow of the Tomb Raider
#                     </a>
# </td>
# </tr>
# <tr class="score_title_row">
# <td class="score_col">
# <a class="metascore_anchor" href="/game/playstation-4/battlefield-v">
# <span class="metascore_w small game mixed">73</span>
# </a>
# </td>
# <td class="title_col">
# <a class="product_title" href="/game/playstation-4/battlefield-v">
#                     Battlefield V
#                     </a>
# </td>
# </tr>
# <tr class="score_title_row">
# <td class="score_col">
# <a class="metascore_anchor" href="/game/playstation-4/deaths-gambit">
# <span class="metascore_w small game mixed">70</span>
# </a>
# </td>
# <td class="title_col">
# <a class="product_title" href="/game/playstation-4/deaths-gambit">
#                     Death's Gambit
#                     </a>
# </td>
# </tr>
# <tr class="score_title_row">
# <td class="score_col">
# <a class="metascore_anchor" href="/game/playstation-4/shining-resonance-refrain">
# <span class="metascore_w small game mixed">67</span>
# </a>
# </td>
# <td class="title_col">
# <a class="product_title" href="/game/playstation-4/shining-resonance-refrain">
#                     Shining Resonance Refrain
#                     </a>
# </td>
# </tr>
# <tr class="score_title_row">
# <td class="score_col">
# <a class="metascore_anchor" href="/game/playstation-4/we-happy-few">
# <span class="metascore_w small game mixed">67</span>
# </a>
# </td>
# <td class="title_col">
# <a class="product_title" href="/game/playstation-4/we-happy-few">
#                     We Happy Few
#                     </a>
# </td>
# </tr>
# <tr class="score_title_row">
# <td class="score_col">
# <a class="metascore_anchor" href="/game/playstation-4/h1z1-battle-royale">
# <span class="metascore_w small game mixed">66</span>
# </a>
# </td>
# <td class="title_col">
# <a class="product_title" href="/game/playstation-4/h1z1-battle-royale">
#                     H1Z1: Battle Royale
#                     </a>
# </td>
# </tr>
# <tr class="score_title_row">
# <td class="score_col">
# <a class="metascore_anchor" href="/game/playstation-4/warhammer-40000-inquisitor---martyr">
# <span class="metascore_w small game mixed">64</span>
# </a>
# </td>
# <td class="title_col">
# <a class="product_title" href="/game/playstation-4/warhammer-40000-inquisitor---martyr">
#                     Warhammer 40,000: Inquisitor - Martyr
#                     </a>
# </td>
# </tr>
# <tr class="score_title_row">
# <td class="score_col">
# <a class="metascore_anchor" href="/game/playstation-4/mxgp-pro">
# <span class="metascore_w small game mixed">64</span>
# </a>
# </td>
# <td class="title_col">
# <a class="product_title" href="/game/playstation-4/mxgp-pro">
#                     MXGP Pro
#                     </a>
# </td>
# </tr>
# <tr class="score_title_row">
# <td class="score_col">
# <a class="metascore_anchor" href="/game/playstation-4/adventure-time-pirates-of-the-enchiridion">
# <span class="metascore_w small game mixed">62</span>
# </a>
# </td>
# <td class="title_col">
# <a class="product_title" href="/game/playstation-4/adventure-time-pirates-of-the-enchiridion">
#                     Adventure Time: Pirates of the Enchiridion
#                     </a>
# </td>
# </tr>
# <tr class="score_title_row">
# <td class="score_col">
# <a class="metascore_anchor" href="/game/playstation-4/earthfall">
# <span class="metascore_w small game mixed">54</span>
# </a>
# </td>
# <td class="title_col">
# <a class="product_title" href="/game/playstation-4/earthfall">
#                     Earthfall
#                     </a>
# </td>
# </tr>
# <tr class="score_title_row">
# <td class="score_col">
# <a class="metascore_anchor" href="/game/playstation-4/fallout-76">
# <span class="metascore_w small game mixed">53</span>
# </a>
# </td>
# <td class="title_col">
# <a class="product_title" href="/game/playstation-4/fallout-76">
#                     Fallout 76
#                     </a>
# </td>
# </tr>
# <tr class="score_title_row">
# <td class="score_col">
# <a class="metascore_anchor" href="/game/playstation-4/immortal-unchained">
# <span class="metascore_w small game negative">48</span>
# </a>
# </td>
# <td class="title_col">
# <a class="product_title" href="/game/playstation-4/immortal-unchained">
#                     Immortal: Unchained
#                     </a>
# </td>
# </tr>
# </table>
# </div>
# </div>
# </div>
# <div class="foot">
# <div class="foot_wrap">
# <div class="more">
# <span class="more_item"><a href="/browse/games/release-date/new-releases/ps4/date">All Current Games »</a></span>
# </div>
# </div>
# </div>
# </div>
# <div class="module list_trailers">
# <div class="head head_type_2"><div class="head_wrap"><h2 class="module_title"><a href="/browse/games/trailers/all/date">Top Trailers</a></h2><div class="more"><span class="more_item"><a href="/browse/games/trailers/all/date">See all »</a></span></div></div></div>
# <div class="body">
# <ul class="trailers">
# <li class="trailer">
# <div class="trailer_wrap">
# <div class="trailer_title">
# <h3 class="trailer_title"><a href="/game/xbox-one/recore/trailers/7322621">ReCore - Launch Trailer</a></h3>
# </div>
# <div class="details">
# <div class="thumb video_thumb">
# <a href="/game/xbox-one/recore/trailers/7322621">
# <span class="play_button">Play Video</span> <img alt="ReCore - Launch Trailer" src="https://static.gamespot.com/uploads/screen_small/536/5360430/3123981-trailer_recore_launch_20160902.jpg">
# </img></a>
# </div>
# <div class="trailer_stats">
# <ul class="trailer_stats">
# <li class="trailer_stat duration">1:31</li> <li class="trailer_stat count views">(35441 views)</li> </ul>
# </div>
# <div class="trailer_actions">
# <div class="action">
# <span class="now_playing">now playing</span>
# <span class="play_action">
# <span><a href="/game/xbox-one/recore/trailers/7322621">play now</a></span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="trailer alt">
# <div class="trailer_wrap">
# <div class="trailer_title">
# <h3 class="trailer_title"><a href="/game/playstation-4/pro-evolution-soccer-2017/trailers/6843146">PES 2017 - E3 2016 Teaser Trailer</a></h3>
# </div>
# <div class="details">
# <div class="thumb video_thumb">
# <a href="/game/playstation-4/pro-evolution-soccer-2017/trailers/6843146">
# <span class="play_button">Play Video</span> <img alt="PES 2017 - E3 2016 Teaser Trailer" src="https://static.gamespot.com/uploads/screen_small/1197/11970954/3080134-e32016-breakout-template.jpg"/>
# </a>
# </div>
# <div class="trailer_stats">
# <ul class="trailer_stats">
# <li class="trailer_stat duration">1:14</li> <li class="trailer_stat count views">(27374 views)</li> </ul>
# </div>
# <div class="trailer_actions">
# <div class="action">
# <span class="now_playing">now playing</span>
# <span class="play_action">
# <span><a href="/game/playstation-4/pro-evolution-soccer-2017/trailers/6843146">play now</a></span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="trailer">
# <div class="trailer_wrap">
# <div class="trailer_title">
# <h3 class="trailer_title"><a href="/game/xbox-one/forza-horizon-3/trailers/7428455">Forza Horizon 3 - Official Launch Trailer</a></h3>
# </div>
# <div class="details">
# <div class="thumb video_thumb">
# <a href="/game/xbox-one/forza-horizon-3/trailers/7428455">
# <span class="play_button">Play Video</span> <img alt="Forza Horizon 3 - Official Launch Trailer" src="https://static.gamespot.com/uploads/screen_small/1197/11970954/3132313-trailer_forzahorizon3_launch_20160920.jpg"/>
# </a>
# </div>
# <div class="trailer_stats">
# <ul class="trailer_stats">
# <li class="trailer_stat duration">1:23</li> <li class="trailer_stat count views">(23588 views)</li> </ul>
# </div>
# <div class="trailer_actions">
# <div class="action">
# <span class="now_playing">now playing</span>
# <span class="play_action">
# <span><a href="/game/xbox-one/forza-horizon-3/trailers/7428455">play now</a></span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="foot">
# <div class="foot_wrap">
# <div class="more">
# <span class="more_item"><a href="/browse/games/trailers/all/date">See all trailers »</a></span>
# </div>
# </div>
# </div>
# </div>
# <script>
#     MetaC.Video.addVideoStartCallback(function(payloadRco){
#         $('.trailer_actions .action.playing').removeClass('playing');
#         var playaction = $('.trailer_actions .play_action a[href$=' + payloadRco.mc_id + ']');
#         var actionObj = playaction.closest('.action');
#         actionObj.addClass('playing');
#     });
# </script>
# <div class="ad_unit" id="mpu_bottom">
# <script type="text/javascript">
#
#                         googletag.cmd.push(function() {
#
#                                                             window.metac_g_ad_mpu_bottom = googletag.defineSlot("/8264/uk-metacritic/games",[300,250], "mpu_bottom").addService(googletag.pubads()).setTargeting("pos", "bottom");
#
#
#                         });
#
#                                                     window.metac_ads_pushdisplay.push("mpu_bottom");
#                                                             </script>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="ad_unit" id="leader_bottom">
# <script type="text/javascript">
#
#                         googletag.cmd.push(function() {
#
#                                                             window.metac_g_ad_leader_bottom = googletag.defineSlot("/8264/uk-metacritic/games",[[728,90],[970,66],[728,92],[970,250],[7,7]], "leader_bottom").addService(googletag.pubads()).setTargeting("pos", "bottom");
#
#
#                         });
#
#                                                     window.metac_ads_pushdisplay.push("leader_bottom");
#                                                             </script>
# </div>
# </div>
# </div>
# <div class="ad_unit" id="intromercial">
# <script type="text/javascript">
#
#                         googletag.cmd.push(function() {
#
#                                                             window.metac_g_ad_intromercial = googletag.defineOutOfPageSlot("/8264/uk-metacritic/games",
#                                     "intromercial").addService(googletag.pubads());
#
#
#                         });
#
#                                                     window.metac_ads_pushdisplay.push("intromercial");
#                                                             </script>
# </div>
# <div id="mastfoot">
# <footer id="bottom_footer">
# <div id="providers">
# <a href="https://www.allmusic.com" target="_blank">Music title data, credits, and images provided by <span>AMG</span></a>
# <span class="link_divider">|</span><a href="https://www.imdb.com" target="_blank">Movie title data, credits, and poster art provided by <span>IMDb</span></a>
# <span class="link_divider">|</span><a href="https://www.internetvideoarchive.com" target="_blank">Video and Images provided by <span>IVA</span></a>
# <div id="trademark">
#         We Deal With Criticism<sup>®</sup>
# 	</div>
# </div>
# <div class="site_links upper">
# <a href="https://www.metacritic.com/movie">
# <span>
#                                             Movies
#                                     </span>
# </a>
# <a href="https://www.metacritic.com/tv">
# <span>
#                                             TV
#                                     </span>
# </a>
# <a href="https://www.metacritic.com/music">
# <span>
#                                             Music
#                                     </span>
# </a>
# <a href="https://www.metacritic.com/game/playstation-4">
# <span>
#                                             PS4
#                                     </span>
# </a>
# <a href="https://www.metacritic.com/game/xbox-one">
# <span>
#                                             XboxOne
#                                     </span>
# </a>
# <a href="https://www.metacritic.com/game/switch">
# <span>
#                                             Switch
#                                     </span>
# </a>
# <a href="https://www.metacritic.com/game/pc">
# <span>
#                                             PC
#                                     </span>
# </a>
# <a href="https://www.metacritic.com/game/wii-u">
# <span>
#                                             WiiU
#                                     </span>
# </a>
# <a href="https://www.metacritic.com/game/3ds">
# <span>
#                                             3DS
#                                     </span>
# </a>
# <a href="https://www.metacritic.com/game/playstation-vita">
# <span>
#                                             PS Vita
#                                     </span>
# </a>
# <a href="https://www.metacritic.com/game/ios">
# <span>
#                                             iOS
#                                     </span>
# </a>
# <a href="https://www.metacritic.com/feature">
# <span>
#                                             Reports
#                                     </span>
# </a>
# <a href="https://www.metacritic.com/rss">
# <span>
#                                             RSS Feeds
#                                     </span>
# </a>
# </div>
# <div class="pad_top1 pad_btm1">
# <div class="social_round">
# <a href="https://www.facebook.com/Metacritic" rel="noopener" target="_blank"><i class="fa fa-facebook"></i></a>
# <a href="https://twitter.com/metacritic" rel="noopener" target="_blank"><i class="fa fa-twitter"></i></a>
# </div>
# </div>
# <div class="about_cbs">
# <div id="footer_about_links">
# <a class="first" href="https://www.cbsinteractive.com" target="_blank">About CBS Interactive</a>
# <span class="link_divider">|</span><a href="https://www.cbsinteractive.com/careers/" target="_blank">Jobs</a>
# <span class="link_divider">|</span><a href="https://www.cbsinteractive.com/advertise/" target="_blank">Advertise</a>
# <span class="link_divider">|</span><a href="https://www.metacritic.com/faq">FAQ</a>
# <span class="link_divider">|</span><a href="https://www.metacritic.com/about-metacritic">About Metacritic</a>
# <span class="link_divider">|</span><a href="https://www.metacritic.com/contact-us">Contact</a>
# <span class="link_divider">|</span><span id="footer_privacy"><a href="https://legalterms.cbsinteractive.com/privacy" target="_blank">Privacy Policy</a></span>
# <span class="link_divider">|</span><span id="footer_terms"><a href="https://cbsi.secure.force.com/CBSi/articles/FAQ/CBSi-Terms-of-Use?template=template_tougl&amp;referer=tougl.com&amp;data=&amp;cfs=default" target="_blank">Terms of Use</a></span>
# <span class="link_divider">|</span><span id="footer_attribution"><a href="https://www.gamespot.com/" target="_blank">Gamespot</a></span>
# </div>
# <div class="pad_btm2" id="footer_rights">
#             © 2019 CBS Interactive Inc. All rights reserved.
#         </div>
# </div>
# </footer>
# </div>
# <div id="amzn-assoc-ad-23cf2fa7-c9fd-4908-97de-fbc48a779984"></div>
# <script async="" src="//z-na.amazon-adsystem.com/widgets/onejs?MarketPlace=US&amp;adInstanceId=23cf2fa7-c9fd-4908-97de-fbc48a779984"></script>
# </div>
# <div class="dw_tracking" id="site_scripts">
# <script src="/js/omniture/uuid.js" type="text/javascript"></script>
# <script type="text/javascript">
#
#     if (self != top) {
#         top.location = self.location;
#     }
#     var MC_UUID = uuid.v1();
# </script>
# <script language="JavaScript" type="text/javascript">
#
#     var utag_data = {
#         isDev:0,
#                             siteType:"desktop web",
#                 deviceType:"desktop",
#                 siteSection:"games",
#                 pageType:"product_detail",
#                 pageFindingMethod:"External",
#                 session: MetaC.adSession() + ':' + MetaC.adSubses(),
#                 userId:null,userState:"not authenticated",userType:"anon",gameId:"mc-game-527332",gameTitle:"Just Cause 4",gamePlatform:"PlayStation 4",bkPath:"/8264/uk-metacritic/games",_test:"",pageViewGuid:MC_UUID
#     };
#
#
#
#             window.om_lead_media = {
#                 mediaType: "Game",
#                 mediaId: "mc-game-527332",
#                 mediaTitle: "Just Cause 4"
#             };
#
#
#
#
#     if ( window.eventAmazonBuyView ) {
#         utag_data.eventAmazonBuyView = 1;
#     }
#     if ( window.eventAmazonPivView ) {
#         utag_data.eventAmazonPivView = 1;
#     }
#
#
#
#     if ( MetaC._utagAutoPlay != -1 ) {
#         utag_data.videoAutoPlay = MetaC._utagAutoPlay ? 'on' : 'off';
#     }
#
#
#
# </script>
# <script type="text/javascript">
#
#
#     var __pv = MetaC.handleGooglePageView();
#     googletag.cmd.push(function() {
#
#         googletag.pubads().setTargeting("ptype", "product_detail");
#                     googletag.pubads().setTargeting("gameId", "game-527332");
#                     googletag.pubads().setTargeting("game", "just-cause-4");
#                     googletag.pubads().setTargeting("con", "playstation-4");
#                     googletag.pubads().setTargeting("franchise", "Just-Cause");
#                     googletag.pubads().setTargeting("genre", "action-adventure, ");
#                     googletag.pubads().setTargeting("score", "66");
#                             googletag.pubads().setTargeting("test", "mcold");
#
#         googletag.pubads().setTargeting("vguid", MC_UUID);
#         googletag.pubads().setTargeting("session", MetaC.adSession());
#         googletag.pubads().setTargeting("subses", MetaC.adSubses());
#         googletag.pubads().setTargeting("env", "prod");
#                         var parts = window.location.hash.split("=");
#         if ( parts.length > 1 && parts[0] == '#ftag' ) {
#             googletag.pubads().setTargeting("ftag",parts[1]);
#         }
#
#
#
#         if ( window.I11C) {
#             if (window.I11C.Morph && window.I11C.Morph === 1) {
#                 utag_data.adBlockRecovery = "unblocked";
#                 utag_data.adsAreBlocked = "true";
#
#                 var geo = MetaC.Cookie.get('il_geo');
#                 if ( geo ) {
#                     geo = MetaC.Cookie.ilParse(geo);
#                     if ( geo && geo.postal_code && geo.country_code ) {
#                         googletag.pubads().setLocation(geo.postal_code + ',' + geo.country_code)
#                     }
#                 }
#             } else {
#                 utag_data.adBlockRecovery = 'instart_noop';
#                 utag_data.adsAreBlocked = "false";
#             }
#         } else {
#             utag_data.adBlockRecovery = 'no_instart';
#             utag_data.adsAreBlocked = "false";
#         }
#
#         googletag.pubads().setTargeting("pv", __pv+""); // must be a string
#
#         googletag.pubads().enableAsyncRendering();
#         googletag.pubads().enableSingleRequest();
#         googletag.pubads().collapseEmptyDivs();
#         if (window.metac_ads_push_progressive_display && window.metac_ads_push_progressive_display.length)
#             googletag.pubads().disableInitialLoad();
#         googletag.enableServices();
#     });
#
#
#
#
#
#     if ( MetaC && MetaC.Video ) {
#
#                     MetaC.Video.setIMATargeting("gameId", "game-527332");
#                     MetaC.Video.setIMATargeting("game", "just-cause-4");
#                     MetaC.Video.setIMATargeting("con", "playstation-4");
#                     MetaC.Video.setIMATargeting("franchise", "Just-Cause");
#                     MetaC.Video.setIMATargeting("genre", "action-adventure, ");
#                     MetaC.Video.setIMATargeting("score", "66");
#
#     }
#
# </script>
# <script src="https://urs.metacritic.com/sdk/urs.js" type="text/javascript"></script>
# <script type="text/javascript">
#         if ( window.MetaC && MetaC.URS ) {
#             MetaC.URS.config(227, false);
#         }
#     </script>
# <script type="text/javascript">
#     (function(a,b,c,d){
#     a='//tags.tiqcdn.com/utag/cbsi/metacriticsite/prod/utag.js';
#     b=document;c='script';d=b.createElement(c);d.src=a;d.type='text/java'+c;d.async=true;
#     a=b.getElementsByTagName(c)[0];a.parentNode.insertBefore(d,a);
#     })();
# </script>
# <script type="text/javascript">
#         $(document).ready(function(){
#             setTimeout(function(){
#                 MetaC.checkOmniEvents();
#             }, 300);
#         });
#     </script>
# <script type="text/javascript">
#
#     dwVars = {"siteId":"50","onId":"35319","ptId":"6123","ctype":"entitytype;entityid","cval":"game;527332"};
#     if (typeof DW == "object"){
#         DW.pageParams = dwVars;
#         DW.regSilo = '12';
#         DW.clear();
#     }
# </script>
# <script>
#     var cbsiApexGlobal = {
#         'SITE': dwVars.siteId,
#         'NODE': dwVars.onId,
#         'PTYPE':dwVars.ptId
#     };
# </script>
# <script>
#     var _gaq = _gaq || [];
#     _gaq.push(['_setAccount', 'UA-22577913-5']);
#     _gaq.push(['_setCustomVar',1,'PageType',dwVars.ptId,3]);
#     _gaq.push(['_trackPageview']);
#     _gaq.push(['_trackPageLoadTime']);
#     _gaq.push(['_setAllowLinker', true]);
#     _gaq.push(['nT._setAccount', 'UA-27653683-1']);
#     _gaq.push(['nT._setAllowLinker', true]);
#     _gaq.push(['nT._setSampleRate', '1']);
#     _gaq.push(['nT._trackPageview']);
# </script>
# <div id="fb-root"></div>
# <script>
#     window.fbAsyncInit = function() {
#         FB.init({
#             appId      : '123113677890173',
#             version    : 'v2.6',
#             channelUrl : 'https://www.metacritic.com/static/fbchannel.html',
#             status     : true,
#             xfbml      : true,
#             cookie     : true
#             });
#          MetaC.FB.initialized();
#         };
#
#     (function(d, s, id){
#         var js, fjs = d.getElementsByTagName(s)[0];
#         if (d.getElementById(id)) {return;}
#         js = d.createElement(s); js.id = id;
#         js.src = "//connect.facebook.net/en_US/sdk.js";
#         fjs.parentNode.insertBefore(js, fjs);
#     }(document, 'script', 'facebook-jssdk'));
#
# </script>
# <script>
#     window.twttr = (function (d,s,id) {
#       var t, js, fjs = d.getElementsByTagName(s)[0];
#       if (d.getElementById(id)) return; js=d.createElement(s); js.id=id;
#       js.src="https://platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js, fjs);
#       return window.twttr || (t = { _e: [], ready: function(f){ t._e.push(f) } });
#     }(document, "script", "twitter-wjs"));
#
#     twttr.ready(function (twttr) {
#         MetaC.Twitter.initialized();
#     });
# </script>
# <script>
#     /* display the google ads now that the html is finished processing */
#     googletag.cmd.push(function() {
#         MetaC.displayAds();
#         if (window.metac_ads_push_progressive_display && window.metac_ads_push_progressive_display.length)
#             MetaC._refreshWithLightSpeed(window.metac_ads_pushdisplay);
#     });
# </script>
# <script>
#
#
#     if ( window._taboola && window.mcwait_taboola == null ) {
#         _taboola.push({flush: true});
#     }
#
# </script>
# <div id="amzn-assoc-ad-23cf2fa7-c9fd-4908-97de-fbc48a779984"></div>
# <script async="" src="//z-na.amazon-adsystem.com/widgets/onejs?MarketPlace=US&amp;adInstanceId=23cf2fa7-c9fd-4908-97de-fbc48a779984"></script>
# <script>
#     	if (typeof cbsiLoadOffer == "function"){
#                 cbsiLoadOffer(cbsiApexGlobal,1000);
#         }
#     </script>
# </div>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"860f7644b8","applicationID":"2033002","transactionName":"MgQEZ0dYCxEAVRBbDQtOJUZGTQoPTnEFXwc1EwlXQFoRWFtSAUYDDA0V","queueTime":0,"applicationTime":1301,"atts":"HkMTEQ9CGE5DV0YIGRgc","errorBeacon":"bam.nr-data.net","agent":""}</script></div></body>
# </html>

# %%
jc4_pub = jc4_detail_soup.find_all('a', {'href': re.compile(r'/company')})[1].get_text().strip()
jc4_details = jc4_detail_soup.find_all('th', scope='row')
jc4_details[1].get_text().strip(':')
jc4_deets = {}
for detail in jc4_details:
    if detail.get_text() == "Number of Online Players:":
        value = detail.next_sibling.get_text().strip()
    elif detail.get_text() == "Genre(s):":
        value = detail.next_sibling.next_sibling.get_text().split(',')
        for i in range(len(value)):
            value[i] = value[i].strip()
    else:
        value = detail.next_sibling.next_sibling.get_text().strip()
    jc4_deets[detail.get_text().strip(':')] = value
    
jc4_deets
# Out:
# {'Rating': 'M',
#  'Developer': 'Avalanche Studios',
#  'Genre(s)': ['Action Adventure', 'Open-World'],
#  'Number of Online Players': 'No Online Multiplayer'}

# %%
jc4_rev_soup = BeautifulSoup(justcause4_rev.content, 'html.parser')
#jc4_reviews = jc4_soup.find_all('a', text='Read full review')
jc4_review_links = [a.get('href') for a in jc4_rev_soup.find_all('a', href=True, text='Read full review')]
jc4_review_links
# Out:
# ['https://www.gamerevolution.com/review/467609-just-cause-4-review-a-cause-for-celebration',
#  'http://www.impulsegamer.com/just-cause-4-ps4-review/',
#  'https://www.gamingnexus.com/Article/5859/Just-Cause-4/',
#  'https://areajugones.sport.es/just-cause-4/analisis/',
#  'http://digitalchumps.com/justcause4',
#  'https://www.thedigitalfix.com/gaming/content/12007/just-cause-4/',
#  'http://www.game-over.com/content/2018/12/just-cause-4/#sthash.b7nCtqaE.dpbs',
#  'https://www.hobbyconsolas.com/reviews/analisis-just-cause-4-ps4-xbox-one-pc-339491',
#  'https://www.psu.com/reviews/just-cause-4-review-ps4/',
#  'http://www.bazicenter.com/?p=756005',
#  'http://www.egmnow.com/articles/reviews/just-cause-4-review/',
#  'https://twinfinite.net/2018/12/just-cause-4-review/',
#  'https://www.playstationlifestyle.net/2018/12/07/just-cause-4-review-ps4/#/slide/1',
#  'https://atomix.vg/review-just-cause-4/',
#  'http://www.jeuxvideo.com/test/969086/just-cause-4-une-aventure-libertaire-mais-techniquement-limitee-sur-consoles.htm',
#  'https://www.ausgamers.com/games/just-cause-4/review/',
#  'http://www.gaming-age.com/2018/12/just-cause-4-review-for-ps4-xbox-one-pc/',
#  'https://www.psx-sense.nl/341970/review-just-cause-4/',
#  'https://easyallies.com/#!/review/just-cause-4',
#  'https://wccftech.com/review/just-cause-4-workmanlike-revolution/',
#  'https://www.gamecrate.com/reviews/review-just-cause-4-amusing-not-engaging-or-exciting/21614',
#  'https://www.gamer.no/artikler/anmeldelse-just-cause-4/454156',
#  'https://attackofthefanboy.com/reviews/just-cause-4-review/',
#  'https://gameover.gr/reviews/38587-just-cause-4-review',
#  'https://www.hardcoregamer.com/2018/12/10/review-just-cause-4/319938/',
#  'https://www.digitaltrends.com/game-reviews/just-cause-4-review/',
#  'http://www.pushsquare.com/reviews/ps4/just_cause_4',
#  'https://metro.co.uk/2018/12/06/just-cause-4-review-grappling-with-problems-8214002/',
#  'http://www.gamersheroes.com/honest-game-reviews/just-cause-4-review-chaotic-repetition',
#  'https://cogconnected.com/review/just-cause-4-review/',
#  'https://www.usgamer.net/articles/just-cause-4-review',
#  'http://www.gameblog.fr/tests/3251-just-cause-4-ps4',
#  'https://www.slantmagazine.com/games/review/just-cause-4',
#  'http://www.thejimquisition.com/just-cause-4-the-sandbox-is-full-jimpressions/']

# %%
just_cause4 = requests.get("https://www.metacritic.com/game/playstation-4/just-cause-4/",
                         headers = headers)
jc4_soup = BeautifulSoup(just_cause4.content, 'html.parser')

# %%
jc4_sum_details = [a.find_all('span', {"class": "data"}) for a in jc4_soup.find_all('li', {"class": "summary_detail"})]
#jc4_sum_details = jc4_soup.find_all('li', {"class": "summary_detail"})

developers = jc4_sum_details[4][0].get_text().strip()

genres = [g.get_text().strip() for g in jc4_sum_details[5]]
print(developers, genres)
# Out:
# Avalanche Studios ['Action Adventure', 'Open-World']

# %%
page = requests.get("https://www.gamerevolution.com/review/467609-just-cause-4-review-a-cause-for-celebration")
page.status_code == 200
# Out:
# True

# %%
soup = BeautifulSoup(page.content, 'html.parser')
body = soup.find('body')
the_contents_of_body_without_body_tags = body.find_all('p')
string = ""
for i in the_contents_of_body_without_body_tags:
    string += i.get_text()
    string += " "
    
print(string)
# Out:
# Video games have almost always looked at Hollywood for inspiration. Gaming has been been fixated on emulating the silver screen’s cinematography and storytelling techniques as the medium strives to be taken more seriously. The Just Cause series, on the other hand, hasn’t studied narrative as hard but rather the explosive set pieces that make up most blockbusters. Avalanche Studios has been implementing more and more tools with each successive installment to make the moment-to-moment gameplay more evocative of an explosive action movie that you can play. JUST CAUSE 4 is the natural zenith of that mentality as its newly expanded toolset gives players the freedom to goof off in the huge sandbox in a way that few games can match. The grappling hook is vital component of Just Cause 4’s huge push towards player choice. Instead of only tethering objects together, it can now attach balloons and rocket boosters to almost anything in the world. On the surface, it’s hilarious to toss seven balloons and three rockets on a car and watch it spin around at Mach 4 but it goes so much deeper. Each of the three components has a dizzying array of options that allow for a nearly overwhelming amount of customization. Unlockable mods change how the three behave and can be activated instantly or through holding down or pressing a button. For example, you can set the balloons to follow your reticle, inflate on a button press, and to explode when destroyed while having the rocket boosters only fire upwards, thrust quickly at an extreme speed, and activate only when the button is held down.  When combined in the right ways, this breathtaking number of options gives you a command over the environment in way that leads to constant discovery. When combined in the wrong ways, this incredible array of options is hilarious as your engineering failures—combined with the random parts of the open world—are always unscripted comedy gold. And almost everything can be manipulated, moved, or propelled into space at your whim and the tools give you that freedom to have better control over the mayhem inherent to the series, granted you can get over the learning curve. Something productive, clever, funny, or a combination of the three is almost always possible if you can just think of how to combine the tools in a way to make it a reality. Objectives hardly force you to craft solutions but are often open enough to silently invite your creativity in different ways. Just Cause 4 is usually pretty unrestrictive so you can create a flying tank equipped with balloons and boosters or use nearby metal shipping containers to create impromptu protective barriers in almost any general activity. But there are times where both story and side objectives will task you with moving an object or vehicle to a certain area, which is where the game pushes you to utilize its toolset in whatever way you see fit. Freeform objectives don’t grow stale because there’s always some new contraption to think up and different plan to execute. And that sense of newness snowballs as you spend more time with the tools and string together more elaborate methods of achieving the same goals. Although some missions could better facilitate the game’s bombastic nature. Grappling around and using the wingsuit is still a joy because of how it makes normal traversal actively engaging as well as how it turns you into an agile Ethan Hunt version of Spider-Man. You feel like what every Mission Impossible movie looks like. But not as many of the main missions push these mechanics to their limit in clever ways not possible in the open world. They end up being more of what you see in the other parts of the game: zipping around and blowing things up in clever ways. Thus, campaign missions thrive off the incredible strength of the core mechanics yet still could have been pushed just a bit further with more memorable specialized scenarios. Side missions use the sandbox well in the same ways but also drag on and rely to ...

# %%
all_review_text = {}

for link in jc4_review_links:
    page = requests.get(link)
    soup = BeautifulSoup(page.content, 'html.parser')
    body = soup.find('body')
    body_content = body.find_all('p')
    review_string = ""
    for i in body_content:
        review_string += i.get_text()
        review_string += " "
    all_review_text[link] = review_string

# %%
# Making the review text into a list of words
all_reviews_string = "\n".join(all_review_text.values())
all_review_words = all_reviews_string.split()
review_words = []
for word in all_review_words:
    cur_word = word.rstrip(' .,')
    review_words.append(cur_word)
review_words
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-dfbaa9fe29b4> in <module>
#       7     review_words.append(cur_word)
#       8 review_words
# ----> 9 dt = np.dtype(review_words[1], 10)
#
# TypeError: data type "games" not understood

# %%
filtered_review_words = []
for word in review_words:
    if word in list_of_adjectives:
        filtered_review_words.append(word)
jc4_adjectives = ' '.join(filtered_review_words)
jc4_adjectives = jc4_adjectives.split(' ')

# %%
np.savetxt("Data/jc4.txt", jc4_adjectives, delimiter=",", fmt='%s')

# %% [markdown]
# # Doing the above for all games

# %%
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36"
headers = {'User-Agent':user_agent}

# %%
# Loading in list of all games
meta_games = pd.read_csv('Data/result.csv')

meta_games.sort_values(by='metascore',ascending=False).head(20)
#np.unique(meta_games['console'])

# Adding new columns for genre, publisher
meta_games["genre"] = np.nan
meta_games["developer"] = np.nan
meta_games["players"] = np.nan
meta_games["publisher"] = np.nan
meta_games["rating"] = np.nan

np.sum(meta_games['console']=='PS4')
# Out:
# 1373

# %%
def URLMaker(name,platform,end=""):
    base_url = 'https://www.metacritic.com/game'
    platform_dict = {'PS':'playstation',
                    'PS2':'playstation-2',
                    'PS3':'playstation-3',
                    'PS4':'playstation-4',
                    'X360':'xbox-360',
                    'XBOX':'xbox',
                    'PC':'pc',
                    'VITA':'playstation-vita',
                    '3DS':'3ds',
                    'DC':'dreamcast',
                    'DS':'ds',
                    'GBA':'game-boy-advance',
                    'GC':'gamecube',
                    'N64':'nintendo-64',
                    'PSP':'psp',
                    'Switch':'switch',
                    'WII':'wii',
                    'WIIU':'wii-u',
                    'XONE':'xbox-one'}
    full_platform = platform_dict[platform.strip()]
    simplified_name = name.lower().strip()
    # Getting rid of junk from the title
    simplified_name = simplified_name.replace('\'','').replace(',','').replace(':','').replace('/','')
    simplified_name = simplified_name.replace('.','').replace(';','').replace('&','')
    simplified_name = simplified_name.replace(' ', '-')
    
    complete_url= '/'.join([base_url,full_platform,simplified_name,end])
    return complete_url

urls = []
for row in meta_games.iterrows():
    urls.append(URLMaker(row[1]['name'], row[1]['console']))
urls
# Out:
# ['https://www.metacritic.com/game/playstation-3/grand-theft-auto-v/',
#  'https://www.metacritic.com/game/xbox-360/grand-theft-auto-v/',
#  'https://www.metacritic.com/game/playstation-3/the-last-of-us/',
#  'https://www.metacritic.com/game/playstation-3/bioshock-infinite/',
#  'https://www.metacritic.com/game/pc/bioshock-infinite/',
#  'https://www.metacritic.com/game/xbox-360/bioshock-infinite/',
#  'https://www.metacritic.com/game/wii-u/super-mario-3d-world/',
#  'https://www.metacritic.com/game/3ds/fire-emblem-awakening/',
#  'https://www.metacritic.com/game/wii-u/rayman-legends/',
#  'https://www.metacritic.com/game/pc/fez/',
#  'https://www.metacritic.com/game/playstation-3/rayman-legends/',
#  'https://www.metacritic.com/game/3ds/the-legend-of-zelda-a-link-between-worlds/',
#  'https://www.metacritic.com/game/playstation-4/flower/',
#  'https://www.metacritic.com/game/pc/spelunky/',
#  'https://www.metacritic.com/game/wii-u/the-legend-of-zelda-the-wind-waker-hd/',
#  'https://www.metacritic.com/game/pc/brothers-a-tale-of-two-sons/',
#  'https://www.metacritic.com/game/pc/dota-2/',
#  'https://www.metacritic.com/game/xbox-360/rayman-legends/',
#  'https://www.metacritic.com/game/wii-u/skylanders-swap-force/',
#  'https://www.metacritic.com/game/pc/rocksmith-2014-edition/',
#  'https://www.metacritic.com/game/playstation-vita/spelunky/',
#  'https://www.metacritic.com/game/wii-u/deus-ex-human-revolution---directors-cut/',
#  'https://www.metacritic.com/game/pc/crusader-kings-ii-the-old-gods/',
#  'https://www.metacritic.com/game/xbox-one/fifa-14/',
#  'https://www.metacritic.com/game/playstation-3/assassins-creed-iv-black-flag/',
#  'https://www.metacritic.com/game/xbox-360/star-wars-pinball-balance-of-the-force/',
#  'https://www.metacritic.com/game/xbox-360/xcom-enemy-within/',
#  'https://www.metacritic.com/game/3ds/pokemon-y/',
#  'https://www.metacritic.com/game/pc/the-stanley-parable/',
#  'https://www.metacritic.com/game/pc/guacamelee!-gold-edition/',
#  'https://www.metacritic.com/game/3ds/animal-crossing-new-leaf/',
#  'https://www.metacritic.com/game/xbox-360/rocksmith-2014-edition/',
#  'https://www.metacritic.com/game/3ds/pokemon-x/',
#  'https://www.metacritic.com/game/playstation-vita/guacamelee!/',
#  'https://www.metacritic.com/game/pc/the-swapper/',
#  'https://www.metacritic.com/game/playstation-3/tomb-raider/',
#  'https://www.metacritic.com/game/playstation-vita/rayman-legends/',
#  'https://www.metacritic.com/game/playstation-vita/tearaway/',
#  'https://www.metacritic.com/game/playstation-3/mlb-13-the-show/',
#  'https://www.metacritic.com/game/playstation-4/fifa-14/',
#  'https://www.metacritic.com/game/playstation-3/hotline-miami/',
#  'https://www.metacritic.com/game/xbox-360/bittrip-presentsrunner2-future-legend-of-rhythm-alien/',
#  'https://www.metacritic.com/game/xbox-360/pinball-fx-2-star-wars-pinball/',
#  'https://www.metacritic.com/game/pc/europa-universalis-iv/',
#  'https://www.metacritic.com/game/xbox-360/diablo-iii/',
#  'https://www.metacritic.com/game/wii-u/pikmin-3/',
#  'https://www.metacritic.com/game/playstation-vita/velocity-ultra/',
#  'https://www.metacritic.com/game/xbox-360/nba-2k14/',
#  'https://www.metacritic.com/game/pc/gone-home/',
#  'https://www.metacritic.com/game/pc/pac-man-championship-edition-dx-+/',
#  'https://www.metacritic.com/game/pc/out-of-the-park-baseball-14/',
#  'https://www.metacritic.com/game/xbox-one/nba-2k14/',
#  'https://www.metacritic.com/game/pc/saints-row-iv/',
#  'https://www.metacritic.com/game/wii-u/need-for-speed-most-wanted-u/',
#  'https://www.metacritic.com/game/xbox-360/tomb-raider/',
#  'https://www.metacritic.com/game/xbox-360/borderlands-2-tiny-tinas-assault-on-dragon-keep/',
#  'https://www.metacritic.com/game/xbox-one/grand-theft-auto-v/',
#  'https://www.metacritic.com/game/pc/starcraft-ii-heart-of-the-swarm/',
#  'https://www.metacritic.com/game/playstation-3/bittrip-presentsrunner2-future-legend-of-rhythm-alien/',
#  'https://www.metacritic.com/game/xbox-360/brothers-a-tale-of-two-sons/',
#  'https://www.metacritic.com/game/pc/tomb-raider/',
#  'https://www.metacritic.com/game/xbox-360/dmc-devil-may-cry/',
#  'https://www.metacritic.com/game/xbox-360/assassins-creed-iv-black-flag/',
#  'https://www.metacritic.com/game/playstation-3/minecraft-playstation-3-edition/',
#  'https://www.metacritic.com/game/playstation-3/diablo-iii/',
#  'https://www.metacritic.com/game/playstation-3/rocksmith-2014-edition/',
#  'https://www.metacritic.com/game/playstation-3/fifa-14/',
#  'https://www.metacritic.com/game/playstation-4/grand-theft-auto-v/',
#  'https://www.metacritic.com/game/playstation-4/the-last-of-us-remastered/',
#  'https://www.metacritic.com/game/wii-u/super-smash-bros-for-wii-u/',
#  'https://www.metacritic.com/game/xbox-360/dark-souls-ii/',
#  'https://www.metacritic.com/game/wii-u/bayonetta-2/',
#  'https://www.metacritic.com/game/pc/kentucky-route-zero---act-iii/',
#  'https://www.metacritic.com/game/pc/dark-souls-ii/',
#  'https://www.metacritic.com/game/playstation-3/dark-souls-ii/',
#  'https://www.metacritic.com/game/playstation-4/diablo-iii-ultimate-evil-edition/',
#  'https://www.metacritic.com/game/playstation-4/rayman-legends/',
#  'https://www.metacritic.com/game/pc/xcom-enemy-within/',
#  'https://www.metacritic.com/game/3ds/luigis-mansion-dark-moon/',
#  'https://www.metacritic.com/game/pc/path-of-exile/',
#  'https://www.metacritic.com/game/playstation-3/ni-no-kuni-wrath-of-the-white-witch/',
#  'https://www.metacritic.com/game/playstation-3/the-wolf-among-us-episode-1---faith/',
#  'https://www.metacritic.com/game/playstation-4/battlefield-4/',
#  'https://www.metacritic.com/game/playstation-4/nba-2k14/',
#  'https://www.metacritic.com/game/pc/bittrip-presentsrunner2-future-legend-of-rhythm-alien/',
#  'https://www.metacritic.com/game/playstation-vita/velocity-2x/',
#  'https://www.metacritic.com/game/playstation-4/fez/',
#  'https://www.metacritic.com/game/3ds/shovel-knight/',
#  'https://www.metacritic.com/game/wii-u/guacamelee!-super-turbo-championship-edition/',
#  'https://www.metacritic.com/game/pc/out-of-the-park-baseball-15/',
#  'https://www.metacritic.com/game/playstation-4/dragon-age-inquisition/',
#  'https://www.metacritic.com/game/playstation-4/minecraft-playstation-4-edition/',
#  'https://www.metacritic.com/game/wii-u/mario-kart-8/',
#  'https://www.metacritic.com/game/playstation-4/the-binding-of-isaac-rebirth/',
#  'https://www.metacritic.com/game/playstation-3/the-last-of-us-left-behind/',
#  'https://www.metacritic.com/game/playstation-vita/hotline-miami/',
#  'https://www.metacritic.com/game/pc/dust-an-elysian-tail/',
#  'https://www.metacritic.com/game/pc/dmc-devil-may-cry/',
#  'https://www.metacritic.com/game/pc/the-wolf-among-us-episode-1---faith/',
#  'https://www.metacritic.com/game/pc/rogue-legacy/',
#  'https://www.metacritic.com/game/xbox-360/battleblock-theater/',
#  'https://www.metacritic.com/game/playstation-3/brothers-a-tale-of-two-sons/',
#  'https://www.metacritic.com/game/pc/football-manager-2014/',
#  'https://www.metacritic.com/game/pc/sid-meiers-civilization-v-brave-new-world/',
#  'https://www.metacritic.com/game/pc/trials-evolution-gold-edition/',
#  'https://www.metacritic.com/game/wii-u/shovel-knight/',
#  'https://www.metacritic.com/game/xbox-one/minecraft-xbox-one-edition/',
#  'https://www.metacritic.com/game/xbox-one/guacamelee!-super-turbo-championship-edition/',
#  'https://www.metacritic.com/game/pc/hearthstone-heroes-of-warcraft/',
#  'https://www.metacritic.com/game/playstation-4/guacamelee!-super-turbo-championship-edition/',
#  'https://www.metacritic.com/game/xbox-one/middle-earth-shadow-of-mordor/',
#  'https://www.metacritic.com/game/pc/steins-gate/',
#  'https://www.metacritic.com/game/playstation-3/the-walking-dead-season-two-episode-5---no-going-back/',
#  'https://www.metacritic.com/game/pc/year-walk/',
#  'https://www.metacritic.com/game/playstation-vita/terraria/',
#  'https://www.metacritic.com/game/playstation-3/dmc-devil-may-cry/',
#  'https://www.metacritic.com/game/pc/papers-please/',
#  'https://www.metacritic.com/game/xbox-360/mass-effect-3-citadel/',
#  'https://www.metacritic.com/game/playstation-3/guacamelee!/',
#  'https://www.metacritic.com/game/playstation-3/nba-2k14/',
#  'https://www.metacritic.com/game/pc/mass-effect-3-citadel/',
#  'https://www.metacritic.com/game/pc/assassins-creed-iv-black-flag/',
#  'https://www.metacritic.com/game/playstation-3/lone-survivor-the-directors-cut/',
#  'https://www.metacritic.com/game/wii-u/mario-kart-8-dlc-pack-1/',
#  'https://www.metacritic.com/game/pc/towerfall-ascension/',
#  'https://www.metacritic.com/game/playstation-4/towerfall-ascension/',
#  'https://www.metacritic.com/game/pc/diablo-iii-reaper-of-souls/',
#  'https://www.metacritic.com/game/pc/divinity-original-sin/',
#  'https://www.metacritic.com/game/playstation-3/dark-souls-ii-crown-of-the-ivory-king/',
#  'https://www.metacritic.com/game/pc/world-of-warcraft-warlords-of-draenor/',
#  'https://www.metacritic.com/game/pc/astebreed/',
#  'https://www.metacritic.com/game/playstation-4/velocity-2x/',
#  'https://www.metacritic.com/game/playstation-vita/final-fantasy-x--x-2-hd-remaster/',
#  'https://www.metacritic.com/game/xbox-one/titanfall/',
#  'https://www.metacritic.com/game/3ds/etrian-odyssey-iv-legends-of-the-titan/',
#  'https://www.metacritic.com/game/playstation-4/resogun/',
#  'https://www.metacritic.com/game/wii-u/mutant-mudds-deluxe/',
#  'https://www.metacritic.com/game/wii-u/bittrip-presentsrunner2-future-legend-of-rhythm-alien/',
#  'https://www.metacritic.com/game/xbox-360/fifa-14/',
#  'https://www.metacritic.com/game/playstation-vita/pixeljunk-monsters-ultimate-hd/',
#  'https://www.metacritic.com/game/playstation-3/tom-clancys-splinter-cell-blacklist/',
#  'https://www.metacritic.com/game/pc/the-binding-of-isaac-rebirth/',
#  'https://www.metacritic.com/game/pc/titanfall/',
#  'https://www.metacritic.com/game/xbox-one/diablo-iii-ultimate-evil-edition/',
#  'https://www.metacritic.com/game/xbox-one/tomb-raider-definitive-edition/',
#  'https://www.metacritic.com/game/xbox-one/forza-horizon-2/',
#  'https://www.metacritic.com/game/wii-u/bayonetta/',
#  'https://www.metacritic.com/game/playstation-4/final-fantasy-xiv-online-a-realm-reborn/',
#  'https://www.metacritic.com/game/playstation-4/resogun-heroes/',
#  'https://www.metacritic.com/game/pc/the-talos-principle/',
#  'https://www.metacritic.com/game/pc/legend-of-grimrock-ii/',
#  'https://www.metacritic.com/game/pc/dragon-age-inquisition/',
#  'https://www.metacritic.com/game/3ds/bravely-default/',
#  'https://www.metacritic.com/game/playstation-vita/rogue-legacy/',
#  'https://www.metacritic.com/game/pc/south-park-the-stick-of-truth/',
#  'https://www.metacritic.com/game/xbox-one/dragon-age-inquisition/',
#  'https://www.metacritic.com/game/3ds/super-smash-bros-for-nintendo-3ds/',
#  'https://www.metacritic.com/game/pc/shovel-knight/',
#  'https://www.metacritic.com/game/playstation-3/final-fantasy-x--x-2-hd-remaster/',
#  'https://www.metacritic.com/game/pc/assetto-corsa/',
#  'https://www.metacritic.com/game/pc/valkyria-chronicles/',
#  'https://www.metacritic.com/game/pc/battleblock-theater/',
#  'https://www.metacritic.com/game/xbox-one/halo-the-master-chief-collection/',
#  'https://www.metacritic.com/game/xbox-360/persona-4-arena-ultimax/',
#  'https://www.metacritic.com/game/playstation-4/super-mega-baseball/',
#  'https://www.metacritic.com/game/playstation-3/south-park-the-stick-of-truth/',
#  'https://www.metacritic.com/game/xbox-360/the-wolf-among-us-episode-5---cry-wolf/',
#  'https://www.metacritic.com/game/playstation-4/rogue-legacy/',
#  'https://www.metacritic.com/game/playstation-4/geometry-wars-3-dimensions/',
#  'https://www.metacritic.com/game/playstation-4/far-cry-4/',
#  'https://www.metacritic.com/game/wii-u/shantae-and-the-pirates-curse/',
#  'https://www.metacritic.com/game/playstation-4/tomb-raider-definitive-edition/',
#  'https://www.metacritic.com/game/playstation-3/persona-4-arena-ultimax/',
#  'https://www.metacritic.com/game/pc/middle-earth-shadow-of-mordor/',
#  'https://www.metacritic.com/game/playstation-4/middle-earth-shadow-of-mordor/',
#  'https://www.metacritic.com/game/playstation-4/guilty-gear-xrd--sign-/',
#  'https://www.metacritic.com/game/playstation-vita/txk/',
#  'https://www.metacritic.com/game/pc/hearthstone-goblins-vs-gnomes/',
#  'https://www.metacritic.com/game/pc/tales-from-the-borderlands-episode-1---zer0-sum/',
#  'https://www.metacritic.com/game/playstation-4/zen-pinball-2-south-park-super-sweet-pinball/',
#  'https://www.metacritic.com/game/pc/metro-redux/',
#  'https://www.metacritic.com/game/playstation-vita/frozen-synapse-prime/',
#  'https://www.metacritic.com/game/pc/europa-universalis-iv-wealth-of-nations/',
#  'https://www.metacritic.com/game/xbox-360/bioshock-infinite-burial-at-sea---episode-two/',
#  'https://www.metacritic.com/game/wii-u/child-of-light/',
#  'https://www.metacritic.com/game/xbox-one/metro-redux/',
#  'https://www.metacritic.com/game/playstation-4/oddworld-abes-oddysee---new-n-tasty/',
#  'https://www.metacritic.com/game/playstation-vita/minecraft-playstation-vita-edition/',
#  'https://www.metacritic.com/game/xbox-360/ultra-street-fighter-iv/',
#  'https://www.metacritic.com/game/xbox-360/the-walking-dead-season-two-episode-5---no-going-back/',
#  'https://www.metacritic.com/game/pc/the-wolf-among-us-episode-5---cry-wolf/',
#  'https://www.metacritic.com/game/pc/ultimate-general-gettysburg/',
#  'https://www.metacritic.com/game/playstation-3/blazblue-chrono-phantasma/',
#  'https://www.metacritic.com/game/pc/smite/',
#  'https://www.metacritic.com/game/playstation-3/ultra-street-fighter-iv/',
#  'https://www.metacritic.com/game/3ds/persona-q-shadow-of-the-labyrinth/',
#  'https://www.metacritic.com/game/playstation-3/dark-souls-ii-crown-of-the-old-iron-king/',
#  'https://www.metacritic.com/game/pc/the-blackwell-epiphany/',
#  'https://www.metacritic.com/game/3ds/retro-city-rampage-dx/',
#  'https://www.metacritic.com/game/playstation-4/transistor/',
#  'https://www.metacritic.com/game/xbox-one/red-dead-redemption-2/',
#  'https://www.metacritic.com/game/playstation-4/red-dead-redemption-2/',
#  'https://www.metacritic.com/game/playstation-4/god-of-war/',
#  'https://www.metacritic.com/game/xbox-one/celeste/',
#  'https://www.metacritic.com/game/switch/undertale/',
#  'https://www.metacritic.com/game/xbox-one/divinity-original-sin-ii---definitive-edition/',
#  'https://www.metacritic.com/game/xbox-one/forza-horizon-4/',
#  'https://www.metacritic.com/game/switch/celeste/',
#  'https://www.metacritic.com/game/playstation-4/divinity-original-sin-ii---definitive-edition/',
#  'https://www.metacritic.com/game/switch/bayonetta-2/',
#  'https://www.metacritic.com/game/switch/inside/',
#  'https://www.metacritic.com/game/switch/sonic-mania-plus/',
#  'https://www.metacritic.com/game/xbox-one/dead-cells/',
#  'https://www.metacritic.com/game/playstation-4/shadow-of-the-colossus/',
#  'https://www.metacritic.com/game/pc/return-of-the-obra-dinn/',
#  'https://www.metacritic.com/game/playstation-4/celeste/',
#  'https://www.metacritic.com/game/switch/into-the-breach/',
#  'https://www.metacritic.com/game/xbox-one/nier-automata---become-as-gods-edition/',
#  'https://www.metacritic.com/game/xbox-one/monster-hunter-world/',
#  'https://www.metacritic.com/game/switch/hollow-knight/',
#  'https://www.metacritic.com/game/playstation-4/monster-hunter-world/',
#  'https://www.metacritic.com/game/pc/into-the-breach/',
#  'https://www.metacritic.com/game/switch/dead-cells/',
#  'https://www.metacritic.com/game/switch/bayonetta-+-bayonetta-2/',
#  'https://www.metacritic.com/game/playstation-4/astro-bot-rescue-mission/',
#  'https://www.metacritic.com/game/pc/dead-cells/',
#  'https://www.metacritic.com/game/playstation-4/owlboy/',
#  'https://www.metacritic.com/game/switch/okami-hd/',
#  'https://www.metacritic.com/game/pc/forza-horizon-4/',
#  'https://www.metacritic.com/game/xbox-one/the-banner-saga-3/',
#  'https://www.metacritic.com/game/playstation-4/injustice-2-legendary-edition/',
#  'https://www.metacritic.com/game/xbox-one/call-of-duty-black-ops-4/',
#  'https://www.metacritic.com/game/pc/pillars-of-eternity-ii-deadfire/',
#  'https://www.metacritic.com/game/switch/hyper-light-drifter/',
#  'https://www.metacritic.com/game/pc/monster-hunter-world/',
#  'https://www.metacritic.com/game/switch/ikaruga/',
#  'https://www.metacritic.com/game/pc/celeste/',
#  'https://www.metacritic.com/game/pc/assassins-creed-odyssey/',
#  'https://www.metacritic.com/game/playstation-3/batman-arkham-city/',
#  'https://www.metacritic.com/game/playstation-4/dead-cells/',
#  'https://www.metacritic.com/game/xbox-one/hellblade-senuas-sacrifice/',
#  'https://www.metacritic.com/game/switch/dragon-ball-fighterz/',
#  'https://www.metacritic.com/game/pc/subnautica/',
#  'https://www.metacritic.com/game/playstation-4/street-fighter-v-arcade-edition/',
#  'https://www.metacritic.com/game/playstation-4/dragon-ball-fighterz/',
#  'https://www.metacritic.com/game/xbox-one/assassins-creed-odyssey/',
#  'https://www.metacritic.com/game/playstation-4/marvels-spider-man/',
#  'https://www.metacritic.com/game/switch/velocity-2x/',
#  'https://www.metacritic.com/game/switch/owlboy/',
#  'https://www.metacritic.com/game/xbox-360/the-elder-scrolls-v-skyrim/',
#  'https://www.metacritic.com/game/pc/portal-2/',
#  'https://www.metacritic.com/game/xbox-360/portal-2/',
#  'https://www.metacritic.com/game/playstation-3/portal-2/',
#  'https://www.metacritic.com/game/xbox-360/batman-arkham-city/',
#  'https://www.metacritic.com/game/pc/the-elder-scrolls-v-skyrim/',
#  'https://www.metacritic.com/game/3ds/the-legend-of-zelda-ocarina-of-time-3d/',
#  'https://www.metacritic.com/game/playstation-3/mass-effect-2/',
#  'https://www.metacritic.com/game/wii/the-legend-of-zelda-skyward-sword/',
#  'https://www.metacritic.com/game/playstation-3/the-elder-scrolls-v-skyrim/',
#  'https://www.metacritic.com/game/switch/iconoclasts/',
#  'https://www.metacritic.com/game/playstation-4/sonic-mania-plus/',
#  'https://www.metacritic.com/game/pc/iconoclasts/',
#  'https://www.metacritic.com/game/pc/thronebreaker-the-witcher-tales/',
#  'https://www.metacritic.com/game/switch/the-messenger/',
#  'https://www.metacritic.com/game/switch/crypt-of-the-necrodancer-nintendo-switch-edition/',
#  'https://www.metacritic.com/game/switch/donkey-kong-country-tropical-freeze/',
#  'https://www.metacritic.com/game/switch/shantae-and-the-pirates-curse/',
#  'https://www.metacritic.com/game/playstation-4/dragon-quest-xi-echoes-of-an-elusive-age/',
#  'https://www.metacritic.com/game/pc/unavowed/',
#  'https://www.metacritic.com/game/playstation-4/uncharted-4-a-thiefs-end/',
#  'https://www.metacritic.com/game/playstation-3/uncharted-3-drakes-deception/',
#  'https://www.metacritic.com/game/playstation-3/the-ico--shadow-of-the-colossus-collection/',
#  'https://www.metacritic.com/game/wii/rayman-origins/',
#  'https://www.metacritic.com/game/playstation-3/littlebigplanet-2/',
#  'https://www.metacritic.com/game/xbox-360/forza-motorsport-4/',
#  'https://www.metacritic.com/game/pc/batman-arkham-city/',
#  'https://www.metacritic.com/game/xbox-360/gears-of-war-3/',
#  'https://www.metacritic.com/game/playstation-3/nba-2k12/',
#  'https://www.metacritic.com/game/playstation-3/fifa-soccer-12/',
#  'https://www.metacritic.com/game/xbox-360/fifa-soccer-12/',
#  'https://www.metacritic.com/game/xbox-one/dragon-ball-fighterz/',
#  'https://www.metacritic.com/game/pc/yakuza-0/',
#  'https://www.metacritic.com/game/xbox-one/destiny-2-forsaken/',
#  'https://www.metacritic.com/game/switch/keep-talking-and-nobody-explodes/',
#  'https://www.metacritic.com/game/xbox-one/playerunknowns-battlegrounds/',
#  'https://www.metacritic.com/game/switch/mini-metro/',
#  'https://www.metacritic.com/game/xbox-one/dark-souls-remastered/',
#  'https://www.metacritic.com/game/switch/child-of-light/',
#  'https://www.metacritic.com/game/playstation-4/dark-souls-remastered/',
#  'https://www.metacritic.com/game/switch/night-in-the-woods/',
#  'https://www.metacritic.com/game/xbox-one/inside/',
#  'https://www.metacritic.com/game/pc/out-of-the-park-baseball-17/',
#  'https://www.metacritic.com/game/pc/the-witcher-3-wild-hunt---blood-and-wine/',
#  'https://www.metacritic.com/game/pc/overwatch/',
#  'https://www.metacritic.com/game/xbox-one/overwatch/',
#  'https://www.metacritic.com/game/xbox-one/forza-horizon-3/',
#  'https://www.metacritic.com/game/playstation-4/the-witcher-3-wild-hunt---blood-and-wine/',
#  'https://www.metacritic.com/game/playstation-4/inside/',
#  'https://www.metacritic.com/game/playstation-4/overwatch/',
#  'https://www.metacritic.com/game/pc/stephens-sausage-roll/',
#  'https://www.metacritic.com/game/xbox-one/nba-2k17/',
#  'https://www.metacritic.com/game/playstation-3/mlb-11-the-show/',
#  'https://www.metacritic.com/game/xbox-360/dead-space-2/',
#  'https://www.metacritic.com/game/3ds/super-mario-3d-land/',
#  'https://www.metacritic.com/game/pc/deus-ex-human-revolution/',
#  'https://www.metacritic.com/game/3ds/pushmo/',
#  'https://www.metacritic.com/game/xbox-360/metal-gear-solid-hd-collection/',
#  'https://www.metacritic.com/game/playstation-3/limbo/',
#  'https://www.metacritic.com/game/pc/total-war-shogun-2/',
#  'https://www.metacritic.com/game/xbox-360/nba-2k12/',
#  'https://www.metacritic.com/game/xbox-360/dark-souls/',
#  'https://www.metacritic.com/game/playstation-3/deus-ex-human-revolution/',
#  'https://www.metacritic.com/game/pc/guacamelee!-2/',
#  'https://www.metacritic.com/game/pc/final-fantasy-xv-windows-edition/',
#  'https://www.metacritic.com/game/pc/crosscode/',
#  'https://www.metacritic.com/game/playstation-4/djmax-respect/',
#  'https://www.metacritic.com/game/pc/dragon-ball-fighterz/',
#  'https://www.metacritic.com/game/pc/batman-the-enemy-within---episode-5-same-stitch/',
#  'https://www.metacritic.com/game/playstation-4/yakuza-kiwami-2/',
#  'https://www.metacritic.com/game/pc/full-metal-furies/',
#  'https://www.metacritic.com/game/playstation-4/call-of-duty-black-ops-4/',
#  'https://www.metacritic.com/game/switch/the-legend-of-zelda-breath-of-the-wild/',
#  'https://www.metacritic.com/game/pc/kentucky-route-zero---act-iv/',
#  'https://www.metacritic.com/game/pc/dark-souls-iii/',
#  'https://www.metacritic.com/game/playstation-4/rez-infinite/',
#  'https://www.metacritic.com/game/wii-u/axiom-verge/',
#  'https://www.metacritic.com/game/playstation-4/titanfall-2/',
#  'https://www.metacritic.com/game/playstation-4/dark-souls-iii/',
#  'https://www.metacritic.com/game/xbox-one/stardew-valley/',
#  'https://www.metacritic.com/game/playstation-4/battlefield-1/',
#  'https://www.metacritic.com/game/pc/stardew-valley/',
#  'https://www.metacritic.com/game/pc/ori-and-the-blind-forest-definitive-edition/',
#  'https://www.metacritic.com/game/xbox-one/ori-and-the-blind-forest-definitive-edition/',
#  'https://www.metacritic.com/game/xbox-one/dishonored-2/',
#  'https://www.metacritic.com/game/playstation-4/rise-of-the-tomb-raider-20-year-celebration/',
#  'https://www.metacritic.com/game/playstation-3/la-noire/',
#  'https://www.metacritic.com/game/pc/fifa-soccer-12/',
#  'https://www.metacritic.com/game/playstation-3/metal-gear-solid-hd-collection/',
#  'https://www.metacritic.com/game/pc/battlefield-3/',
#  'https://www.metacritic.com/game/playstation-3/dead-space-2/',
#  'https://www.metacritic.com/game/xbox-360/deus-ex-human-revolution/',
#  'https://www.metacritic.com/game/xbox-360/la-noire/',
#  'https://www.metacritic.com/game/playstation-3/dark-souls/',
#  'https://www.metacritic.com/game/xbox-360/call-of-duty-modern-warfare-3/',
#  'https://www.metacritic.com/game/playstation-4/valkyria-chronicles-4/',
#  'https://www.metacritic.com/game/switch/west-of-loathing/',
#  'https://www.metacritic.com/game/switch/darkest-dungeon/',
#  'https://www.metacritic.com/game/playstation-4/moss/',
#  'https://www.metacritic.com/game/playstation-4/f1-2018/',
#  'https://www.metacritic.com/game/3ds/radiant-historia-perfect-chronology/',
#  'https://www.metacritic.com/game/switch/flat-heroes/',
#  'https://www.metacritic.com/game/playstation-4/ni-no-kuni-ii-revenant-kingdom/',
#  'https://www.metacritic.com/game/switch/shantae-half-genie-hero---ultimate-edition/',
#  'https://www.metacritic.com/game/switch/the-banner-saga-3/',
#  'https://www.metacritic.com/game/pc/two-point-hospital/',
#  'https://www.metacritic.com/game/playstation-4/428-shibuya-scramble/',
#  'https://www.metacritic.com/game/switch/super-mario-odyssey/',
#  'https://www.metacritic.com/game/wii-u/the-legend-of-zelda-breath-of-the-wild/',
#  'https://www.metacritic.com/game/pc/divinity-original-sin-ii/',
#  'https://www.metacritic.com/game/playstation-4/persona-5/',
#  'https://www.metacritic.com/game/xbox-one/what-remains-of-edith-finch/',
#  'https://www.metacritic.com/game/playstation-4/undertale/',
#  'https://www.metacritic.com/game/pc/okami-hd/',
#  'https://www.metacritic.com/game/switch/mario-kart-8-deluxe/',
#  'https://www.metacritic.com/game/switch/steamworld-heist-ultimate-edition/',
#  'https://www.metacritic.com/game/switch/shovel-knight-treasure-trove/',
#  'https://www.metacritic.com/game/pc/bayonetta/',
#  'https://www.metacritic.com/game/playstation-4/nba-2k17/',
#  'https://www.metacritic.com/game/pc/xcom-2/',
#  'https://www.metacritic.com/game/playstation-4/dishonored-2/',
#  'https://www.metacritic.com/game/3ds/fire-emblem-fates-special-edition/',
#  'https://www.metacritic.com/game/3ds/fire-emblem-fates-revelation/',
#  'https://www.metacritic.com/game/pc/sid-meiers-civilization-vi/',
#  'https://www.metacritic.com/game/pc/battlefield-1/',
#  'https://www.metacritic.com/game/pc/world-of-warcraft-legion/',
#  'https://www.metacritic.com/game/playstation-4/keep-talking-and-nobody-explodes/',
#  'https://www.metacritic.com/game/pc/owlboy/',
#  'https://www.metacritic.com/game/playstation-4/xcom-2/',
#  'https://www.metacritic.com/game/playstation-4/the-witness/',
#  'https://www.metacritic.com/game/pc/limbo/',
#  'https://www.metacritic.com/game/pc/assassins-creed-brotherhood/',
#  'https://www.metacritic.com/game/playstation-3/call-of-duty-modern-warfare-3/',
#  'https://www.metacritic.com/game/xbox-360/joe-danger-special-edition/',
#  'https://www.metacritic.com/game/pc/the-witcher-2-assassins-of-kings/',
#  'https://www.metacritic.com/game/ds/pokemon-white-version/',
#  'https://www.metacritic.com/game/playstation-3/dirt-3/',
#  'https://www.metacritic.com/game/psp/tactics-ogre-let-us-cling-together/',
#  'https://www.metacritic.com/game/xbox-360/dirt-3/',
#  'https://www.metacritic.com/game/pc/sprint-vector/',
#  'https://www.metacritic.com/game/switch/toki-tori-2-+/',
#  'https://www.metacritic.com/game/switch/bayonetta/',
#  'https://www.metacritic.com/game/xbox-one/soulcalibur-vi/',
#  'https://www.metacritic.com/game/xbox-one/f1-2018/',
#  'https://www.metacritic.com/game/pc/total-war-warhammer-ii---rise-of-the-tomb-kings/',
#  'https://www.metacritic.com/game/pc/valkyria-chronicles-4/',
#  'https://www.metacritic.com/game/switch/mega-man-x-legacy-collection/',
#  'https://www.metacritic.com/game/pc/frostpunk/',
#  'https://www.metacritic.com/game/playstation-4/soulcalibur-vi/',
#  'https://www.metacritic.com/game/pc/f1-2017/',
#  'https://www.metacritic.com/game/playstation-4/final-fantasy-xiv-stormblood/',
#  'https://www.metacritic.com/game/pc/lone-echo/',
#  'https://www.metacritic.com/game/pc/rez-infinite/',
#  'https://www.metacritic.com/game/playstation-4/horizon-zero-dawn/',
#  'https://www.metacritic.com/game/xbox-one/injustice-2/',
#  'https://www.metacritic.com/game/pc/what-remains-of-edith-finch/',
#  'https://www.metacritic.com/game/pc/xcom-2-war-of-the-chosen/',
#  'https://www.metacritic.com/game/xbox-one/n++/',
#  'https://www.metacritic.com/game/playstation-4/what-remains-of-edith-finch/',
#  'https://www.metacritic.com/game/xbox-one/wolfenstein-ii-the-new-colossus/',
#  'https://www.metacritic.com/game/playstation-4/nier-automata/',
#  'https://www.metacritic.com/game/xbox-one/doom/',
#  'https://www.metacritic.com/game/xbox-one/battlefield-1/',
#  'https://www.metacritic.com/game/xbox-one/dark-souls-iii/',
#  'https://www.metacritic.com/game/3ds/pokemon-sun/',
#  'https://www.metacritic.com/game/3ds/pokemon-moon/',
#  'https://www.metacritic.com/game/pc/the-witness/',
#  'https://www.metacritic.com/game/3ds/fire-emblem-fates-conquest/',
#  'https://www.metacritic.com/game/xbox-one/rocket-league/',
#  'https://www.metacritic.com/game/wii-u/steamworld-heist/',
#  'https://www.metacritic.com/game/xbox-one/pro-evolution-soccer-2017/',
#  'https://www.metacritic.com/game/xbox-one/titanfall-2/',
#  'https://www.metacritic.com/game/playstation-vita/persona-4-golden/',
#  'https://www.metacritic.com/game/pc/dead-space-2/',
#  'https://www.metacritic.com/game/playstation-3/rayman-origins/',
#  'https://www.metacritic.com/game/ds/pokemon-black-version/',
#  'https://www.metacritic.com/game/xbox-360/rayman-origins/',
#  'https://www.metacritic.com/game/pc/bastion/',
#  'https://www.metacritic.com/game/xbox-360/radiant-silvergun/',
#  'https://www.metacritic.com/game/pc/crysis-2/',
#  'https://www.metacritic.com/game/xbox-360/mortal-kombat/',
#  'https://www.metacritic.com/game/playstation-3/nhl-12/',
#  'https://www.metacritic.com/game/xbox-one/moonlighter/',
#  'https://www.metacritic.com/game/pc/cuphead/',
#  'https://www.metacritic.com/game/xbox-one/okami-hd/',
#  'https://www.metacritic.com/game/switch/steamworld-dig-2/',
#  'https://www.metacritic.com/game/switch/cave-story-+/',
#  'https://www.metacritic.com/game/pc/night-in-the-woods/',
#  'https://www.metacritic.com/game/playstation-4/nex-machina-death-machine/',
#  'https://www.metacritic.com/game/playstation-4/nioh/',
#  'https://www.metacritic.com/game/switch/stardew-valley/',
#  'https://www.metacritic.com/game/pc/final-fantasy-xiv-stormblood/',
#  'https://www.metacritic.com/game/playstation-4/odin-sphere-leifthrasir/',
#  'https://www.metacritic.com/game/xbox-one/forza-horizon-3-blizzard-mountain/',
#  'https://www.metacritic.com/game/pc/inside/',
#  'https://www.metacritic.com/game/xbox-one/xcom-2/',
#  'https://www.metacritic.com/game/pc/hex-shards-of-fate/',
#  'https://www.metacritic.com/game/pc/forza-horizon-3/',
#  'https://www.metacritic.com/game/xbox-one/the-witness/',
#  'https://www.metacritic.com/game/xbox-one/dirt-rally/',
#  'https://www.metacritic.com/game/pc/grand-theft-auto-v/',
#  'https://www.metacritic.com/game/xbox-360/mass-effect-3/',
#  'https://www.metacritic.com/game/playstation-3/mass-effect-3/',
#  'https://www.metacritic.com/game/xbox-360/the-walking-dead-a-telltale-games-series/',
#  'https://www.metacritic.com/game/playstation-3/journey/',
#  'https://www.metacritic.com/game/wii/xenoblade-chronicles/',
#  'https://www.metacritic.com/game/pc/dishonored/',
#  'https://www.metacritic.com/game/playstation-3/borderlands-2/',
#  'https://www.metacritic.com/game/pc/mark-of-the-ninja/',
#  'https://www.metacritic.com/game/xbox-360/street-fighter-iii-third-strike-online-edition/',
#  'https://www.metacritic.com/game/playstation-3/street-fighter-iii-third-strike-online-edition/',
#  'https://www.metacritic.com/game/xbox-360/dance-central-2/',
#  'https://www.metacritic.com/game/xbox-360/bastion/',
#  'https://www.metacritic.com/game/pc/dirt-3/',
#  'https://www.metacritic.com/game/xbox-360/fight-night-champion/',
#  'https://www.metacritic.com/game/xbox-360/nhl-12/',
#  'https://www.metacritic.com/game/pc/battlefield-3-back-to-karkand/',
#  'https://www.metacritic.com/game/playstation-4/injustice-2/',
#  'https://www.metacritic.com/game/playstation-4/night-in-the-woods/',
#  'https://www.metacritic.com/game/playstation-4/okami-hd/',
#  'https://www.metacritic.com/game/pc/hollow-knight/',
#  'https://www.metacritic.com/game/switch/enter-the-gungeon/',
#  'https://www.metacritic.com/game/pc/raw-data/',
#  'https://www.metacritic.com/game/playstation-4/wolfenstein-ii-the-new-colossus/',
#  'https://www.metacritic.com/game/playstation-4/zero-escape-the-nonary-games/',
#  'https://www.metacritic.com/game/xbox-one/killer-instinct-season-3/',
#  'https://www.metacritic.com/game/playstation-4/stardew-valley/',
#  'https://www.metacritic.com/game/pc/rise-of-the-tomb-raider/',
#  'https://www.metacritic.com/game/pc/total-war-warhammer/',
#  'https://www.metacritic.com/game/3ds/picross-3d-round-2/',
#  'https://www.metacritic.com/game/pc/gears-of-war-4/',
#  'https://www.metacritic.com/game/playstation-4/guilty-gear-xrd--revelator-/',
#  'https://www.metacritic.com/game/xbox-one/metal-gear-solid-v-the-phantom-pain/',
#  'https://www.metacritic.com/game/pc/the-witcher-3-wild-hunt/',
#  'https://www.metacritic.com/game/playstation-4/metal-gear-solid-v-the-phantom-pain/',
#  'https://www.metacritic.com/game/playstation-4/journey/',
#  'https://www.metacritic.com/game/playstation-4/bloodborne/',
#  'https://www.metacritic.com/game/playstation-4/the-witcher-3-wild-hunt/',
#  'https://www.metacritic.com/game/xbox-360/far-cry-3/',
#  'https://www.metacritic.com/game/playstation-3/far-cry-3/',
#  'https://www.metacritic.com/game/xbox-360/trials-evolution/',
#  'https://www.metacritic.com/game/xbox-360/mark-of-the-ninja/',
#  'https://www.metacritic.com/game/playstation-3/okami-hd/',
#  'https://www.metacritic.com/game/xbox-360/xcom-enemy-unknown/',
#  'https://www.metacritic.com/game/pc/guild-wars-2/',
#  'https://www.metacritic.com/game/ds/radiant-historia/',
#  'https://www.metacritic.com/game/playstation-3/plants-vs-zombies/',
#  'https://www.metacritic.com/game/3ds/super-street-fighter-iv-3d-edition/',
#  'https://www.metacritic.com/game/playstation-3/battlefield-3/',
#  'https://www.metacritic.com/game/playstation-3/crysis-2/',
#  'https://www.metacritic.com/game/ds/the-legend-of-zelda-four-swords-anniversary-edition/',
#  'https://www.metacritic.com/game/xbox-360/marvel-vs-capcom-3-fate-of-two-worlds/',
#  'https://www.metacritic.com/game/pc/frozen-synapse/',
#  'https://www.metacritic.com/game/xbox-360/nba-jam-on-fire-edition/',
#  'https://www.metacritic.com/game/switch/axiom-verge/',
#  'https://www.metacritic.com/game/xbox-one/destiny-2/',
#  'https://www.metacritic.com/game/pc/total-war-warhammer-ii/',
#  'https://www.metacritic.com/game/xbox-one/forza-horizon-3-hot-wheels/',
#  'https://www.metacritic.com/game/xbox-one/thumper/',
#  'https://www.metacritic.com/game/switch/rocket-league/',
#  'https://www.metacritic.com/game/playstation-4/f1-2017/',
#  'https://www.metacritic.com/game/xbox-one/cuphead/',
#  'https://www.metacritic.com/game/xbox-one/pillars-of-eternity-complete-edition/',
#  'https://www.metacritic.com/game/xbox-one/sky-force-reloaded/',
#  'https://www.metacritic.com/game/pc/dishonored-2/',
#  'https://www.metacritic.com/game/pc/f1-2016/',
#  'https://www.metacritic.com/game/pc/pony-island/',
#  'https://www.metacritic.com/game/pc/titanfall-2/',
#  'https://www.metacritic.com/game/xbox-one/dying-light-the-following/',
#  'https://www.metacritic.com/game/pc/day-of-the-tentacle-remastered/',
#  'https://www.metacritic.com/game/3ds/fire-emblem-fates-birthright/',
#  'https://www.metacritic.com/game/wii-u/the-legend-of-zelda-twilight-princess-hd/',
#  'https://www.metacritic.com/game/3ds/monster-hunter-generations/',
#  'https://www.metacritic.com/game/playstation-4/dirt-rally/',
#  'https://www.metacritic.com/game/playstation-4/crypt-of-the-necrodancer/',
#  'https://www.metacritic.com/game/pc/undertale/',
#  'https://www.metacritic.com/game/xbox-one/the-witcher-3-wild-hunt/',
#  'https://www.metacritic.com/game/pc/metal-gear-solid-v-the-phantom-pain/',
#  'https://www.metacritic.com/game/playstation-4/shovel-knight/',
#  'https://www.metacritic.com/game/wii-u/mario-kart-8-dlc-pack-2/',
#  'https://www.metacritic.com/game/playstation-4/tales-from-the-borderlands-episode-5---the-vault-of-the-traveler/',
#  'https://www.metacritic.com/game/playstation-4/the-witcher-3-wild-hunt---hearts-of-stone/',
#  'https://www.metacritic.com/game/pc/the-witcher-3-wild-hunt---hearts-of-stone/',
#  'https://www.metacritic.com/game/3ds/the-legend-of-zelda-majoras-mask-3d/',
#  'https://www.metacritic.com/game/pc/pillars-of-eternity/',
#  'https://www.metacritic.com/game/3ds/3d-gunstar-heroes/',
#  'https://www.metacritic.com/game/xbox-one/dark-souls-ii-scholar-of-the-first-sin/',
#  'https://www.metacritic.com/game/xbox-360/fifa-soccer-13/',
#  'https://www.metacritic.com/game/playstation-3/nba-2k13/',
#  'https://www.metacritic.com/game/xbox-360/borderlands-2/',
#  'https://www.metacritic.com/game/playstation-3/xcom-enemy-unknown/',
#  'https://www.metacritic.com/game/pc/the-walking-dead-a-telltale-games-series/',
#  'https://www.metacritic.com/game/xbox-360/fez/',
#  'https://www.metacritic.com/game/pc/the-walking-dead-episode-5---no-time-left/',
#  'https://www.metacritic.com/game/pc/borderlands-2/',
#  'https://www.metacritic.com/game/playstation-3/dishonored/',
#  'https://www.metacritic.com/game/pc/xcom-enemy-unknown/',
#  'https://www.metacritic.com/game/3ds/mario-kart-7/',
#  'https://www.metacritic.com/game/xbox-360/trine-2/',
#  'https://www.metacritic.com/game/playstation-3/trine-2/',
#  'https://www.metacritic.com/game/wii/tiger-woods-pga-tour-12-the-masters/',
#  'https://www.metacritic.com/game/pc/star-wars-the-old-republic/',
#  'https://www.metacritic.com/game/pc/saints-row-the-third/',
#  'https://www.metacritic.com/game/xbox-360/crysis-2/',
#  'https://www.metacritic.com/game/pc/spacechem/',
#  'https://www.metacritic.com/game/playstation-3/might--magic-clash-of-heroes/',
#  'https://www.metacritic.com/game/xbox-360/beyond-good--evil-hd/',
#  'https://www.metacritic.com/game/playstation-4/thimbleweed-park/',
#  'https://www.metacritic.com/game/switch/minecraft-switch-edition/',
#  'https://www.metacritic.com/game/xbox-one/resident-evil-7-biohazard/',
#  'https://www.metacritic.com/game/playstation-4/final-fantasy-xii-the-zodiac-age/',
#  'https://www.metacritic.com/game/pc/wolfenstein-ii-the-new-colossus/',
#  'https://www.metacritic.com/game/playstation-4/sonic-mania/',
#  'https://www.metacritic.com/game/playstation-4/resident-evil-7-biohazard/',
#  'https://www.metacritic.com/game/pc/playerunknowns-battlegrounds/',
#  'https://www.metacritic.com/game/xbox-one/observer/',
#  'https://www.metacritic.com/game/pc/robo-recall/',
#  'https://www.metacritic.com/game/pc/west-of-loathing/',
#  'https://www.metacritic.com/game/pc/hearthstone-whispers-of-the-old-gods/',
#  'https://www.metacritic.com/game/xbox-one/firewatch/',
#  'https://www.metacritic.com/game/pc/blazblue-chrono-phantasma-extend/',
#  'https://www.metacritic.com/game/playstation-4/doom/',
#  'https://www.metacritic.com/game/pc/shadow-tactics-blades-of-the-shogun/',
#  'https://www.metacritic.com/game/pc/superhot-vr/',
#  'https://www.metacritic.com/game/playstation-4/pro-evolution-soccer-2017/',
#  'https://www.metacritic.com/game/xbox-one/f1-2016/',
#  'https://www.metacritic.com/game/pc/thumper/',
#  'https://www.metacritic.com/game/playstation-4/assault-android-cactus/',
#  'https://www.metacritic.com/game/playstation-4/mortal-kombat-xl/',
#  'https://www.metacritic.com/game/3ds/3d-streets-of-rage-ii/',
#  'https://www.metacritic.com/game/playstation-4/bastion/',
#  'https://www.metacritic.com/game/xbox-one/destiny-the-taken-king/',
#  'https://www.metacritic.com/game/xbox-one/fallout-4/',
#  'https://www.metacritic.com/game/pc/nuclear-throne/',
#  'https://www.metacritic.com/game/wii-u/super-mario-maker/',
#  'https://www.metacritic.com/game/xbox-one/divinity-original-sin-enhanced-edition/',
#  'https://www.metacritic.com/game/pc/kerbal-space-program/',
#  'https://www.metacritic.com/game/playstation-4/divinity-original-sin-enhanced-edition/',
#  'https://www.metacritic.com/game/xbox-one/ori-and-the-blind-forest/',
#  'https://www.metacritic.com/game/pc/starcraft-ii-legacy-of-the-void/',
#  'https://www.metacritic.com/game/playstation-4/the-talos-principle/',
#  'https://www.metacritic.com/game/pc/mass-effect-3/',
#  'https://www.metacritic.com/game/xbox-360/dark-souls-artorias-of-the-abyss/',
#  'https://www.metacritic.com/game/xbox-360/the-walking-dead-episode-5---no-time-left/',
#  'https://www.metacritic.com/game/3ds/colors!-3d/',
#  'https://www.metacritic.com/game/xbox-360/dishonored/',
#  'https://www.metacritic.com/game/xbox-360/pinball-fx-2-marvel-pinball---avengers-chronicles/',
#  'https://www.metacritic.com/game/3ds/zero-escape-virtues-last-reward/',
#  'https://www.metacritic.com/game/pc/far-cry-3/',
#  'https://www.metacritic.com/game/playstation-vita/rayman-origins/',
#  'https://www.metacritic.com/game/pc/torchlight-ii/',
#  'https://www.metacritic.com/game/playstation-3/fight-night-champion/',
#  'https://www.metacritic.com/game/playstation-3/god-of-war-origins-collection/',
#  'https://www.metacritic.com/game/xbox-360/top-spin-4/',
#  'https://www.metacritic.com/game/xbox-360/battlefield-3/',
#  'https://www.metacritic.com/game/xbox-360/outland/',
#  'https://www.metacritic.com/game/pc/super-street-fighter-iv-arcade-edition/',
#  'https://www.metacritic.com/game/pc/football-manager-2012/',
#  'https://www.metacritic.com/game/pc/unity-of-command/',
#  'https://www.metacritic.com/game/playstation-3/marvel-vs-capcom-3-fate-of-two-worlds/',
#  'https://www.metacritic.com/game/playstation-3/resident-evil-4-hd/',
#  'https://www.metacritic.com/game/xbox-one/dirt-4/',
#  'https://www.metacritic.com/game/playstation-4/guilty-gear-xrd-rev-2/',
#  'https://www.metacritic.com/game/xbox-one/forza-motorsport-7/',
#  'https://www.metacritic.com/game/switch/sonic-mania/',
#  'https://www.metacritic.com/game/pc/injustice-2/',
#  'https://www.metacritic.com/game/switch/thumper/',
#  'https://www.metacritic.com/game/3ds/metroid-samus-returns/',
#  'https://www.metacritic.com/game/3ds/dragon-quest-viii-journey-of-the-cursed-king/',
#  'https://www.metacritic.com/game/playstation-4/pillars-of-eternity-complete-edition/',
#  'https://www.metacritic.com/game/playstation-4/ratchet--clank/',
#  'https://www.metacritic.com/game/playstation-4/mlb-the-show-16/',
#  'https://www.metacritic.com/game/pc/the-last-door-season-2/',
#  'https://www.metacritic.com/game/pc/chime-sharp/',
#  'https://www.metacritic.com/game/playstation-4/fifa-17/',
#  'https://www.metacritic.com/game/pc/doom/',
#  'https://www.metacritic.com/game/playstation-4/gone-home-console-edition/',
#  'https://www.metacritic.com/game/playstation-4/valkyria-chronicles-remastered/',
#  'https://www.metacritic.com/game/pc/ori-and-the-blind-forest/',
#  'https://www.metacritic.com/game/playstation-4/bloodborne-the-old-hunters/',
#  'https://www.metacritic.com/game/pc/oddworld-abes-oddysee---new-n-tasty/',
#  'https://www.metacritic.com/game/pc/crypt-of-the-necrodancer/',
#  'https://www.metacritic.com/game/playstation-4/batman-arkham-knight/',
#  'https://www.metacritic.com/game/xbox-one/forza-motorsport-6/',
#  'https://www.metacritic.com/game/wii-u/skylanders-superchargers/',
#  'https://www.metacritic.com/game/3ds/3d-sonic-the-hedgehog-2/',
#  'https://www.metacritic.com/game/playstation-4/pro-evolution-soccer-2016/',
#  'https://www.metacritic.com/game/3ds/3d-out-run/',
#  'https://www.metacritic.com/game/playstation-4/dark-souls-ii-scholar-of-the-first-sin/',
#  'https://www.metacritic.com/game/playstation-4/nba-2k16/',
#  'https://www.metacritic.com/game/pc/thirty-flights-of-loving/',
#  'https://www.metacritic.com/game/xbox-360/the-witcher-2-assassins-of-kings/',
#  'https://www.metacritic.com/game/xbox-360/the-walking-dead-episode-3---long-road-ahead/',
#  'https://www.metacritic.com/game/pc/diablo-iii/',
#  'https://www.metacritic.com/game/playstation-vita/littlebigplanet-ps-vita/',
#  'https://www.metacritic.com/game/playstation-3/fifa-soccer-13/',
#  'https://www.metacritic.com/game/playstation-3/the-walking-dead-episode-5---no-time-left/',
#  'https://www.metacritic.com/game/xbox-360/nba-2k13/',
#  'https://www.metacritic.com/game/xbox-360/halo-4/',
#  'https://www.metacritic.com/game/wii/la-mulana/',
#  'https://www.metacritic.com/game/playstation-3/max-payne-3/',
#  'https://www.metacritic.com/game/playstation-3/killzone-3/',
#  'https://www.metacritic.com/game/xbox-360/stacking/',
#  'https://www.metacritic.com/game/xbox-360/f1-2011/',
#  'https://www.metacritic.com/game/playstation-3/mortal-kombat/',
#  'https://www.metacritic.com/game/pc/paradigm/',
#  'https://www.metacritic.com/game/pc/battlerite/',
#  'https://www.metacritic.com/game/playstation-4/nioh-bloodsheds-end/',
#  'https://www.metacritic.com/game/xbox-one/assassins-creed-origins/',
#  'https://www.metacritic.com/game/playstation-4/final-fantasy-ix/',
#  'https://www.metacritic.com/game/switch/the-binding-of-isaac-afterbirth-+/',
#  'https://www.metacritic.com/game/playstation-4/ys-viii-lacrimosa-of-dana/',
#  'https://www.metacritic.com/game/pc/galactic-civilizations-iii-crusade/',
#  'https://www.metacritic.com/game/pc/steamworld-dig-2/',
#  'https://www.metacritic.com/game/pc/planet-coaster/',
#  'https://www.metacritic.com/game/xbox-one/fifa-17/',
#  'https://www.metacritic.com/game/xbox-one/bioshock-the-collection/',
#  'https://www.metacritic.com/game/playstation-4/blazblue-central-fiction/',
#  'https://www.metacritic.com/game/playstation-4/salt-and-sanctuary/',
#  'https://www.metacritic.com/game/playstation-vita/steins-gate-0/',
#  'https://www.metacritic.com/game/xbox-one/gears-of-war-4/',
#  'https://www.metacritic.com/game/playstation-4/fallout-4/',
#  'https://www.metacritic.com/game/pc/tales-from-the-borderlands-episode-5---the-vault-of-the-traveler/',
#  'https://www.metacritic.com/game/playstation-4/uncharted-the-nathan-drake-collection/',
#  'https://www.metacritic.com/game/playstation-4/tales-from-the-borderlands-a-telltale-game-series/',
#  'https://www.metacritic.com/game/pc/final-fantasy-xiv-heavensward/',
#  'https://www.metacritic.com/game/xbox-one/shovel-knight/',
#  'https://www.metacritic.com/game/xbox-one/dmc-devil-may-cry-definitive-edition/',
#  'https://www.metacritic.com/game/3ds/monster-hunter-4-ultimate/',
#  'https://www.metacritic.com/game/xbox-one/nba-2k16/',
#  'https://www.metacritic.com/game/pc/max-payne-3/',
#  'https://www.metacritic.com/game/pc/battlefield-3-armored-kill/',
#  'https://www.metacritic.com/game/playstation-3/the-walking-dead-episode-3---long-road-ahead/',
#  'https://www.metacritic.com/game/playstation-3/mlb-12-the-show/',
#  'https://www.metacritic.com/game/psp/velocity/',
#  'https://www.metacritic.com/game/xbox-360/spelunky/',
#  'https://www.metacritic.com/game/pc/total-war-shogun-2---fall-of-the-samurai/',
#  'https://www.metacritic.com/game/playstation-4/yakuza-0/',
#  'https://www.metacritic.com/game/playstation-4/mlb-the-show-17/',
#  'https://www.metacritic.com/game/playstation-4/destiny-2/',
#  'https://www.metacritic.com/game/playstation-4/wipeout-omega-collection/',
#  'https://www.metacritic.com/game/switch/mutant-mudds-collection/',
#  'https://www.metacritic.com/game/switch/neurovoider/',
#  'https://www.metacritic.com/game/pc/starcraft-remastered/',
#  'https://www.metacritic.com/game/xbox-one/nba-2k18/',
#  'https://www.metacritic.com/game/playstation-4/shadow-tactics-blades-of-the-shogun/',
#  'https://www.metacritic.com/game/pc/her-story/',
#  'https://www.metacritic.com/game/pc/homeworld-remastered-collection/',
#  'https://www.metacritic.com/game/xbox-one/rise-of-the-tomb-raider/',
#  'https://www.metacritic.com/game/3ds/steamworld-heist/',
#  'https://www.metacritic.com/game/playstation-4/final-fantasy-xiv-heavensward/',
#  'https://www.metacritic.com/game/playstation-4/destiny-the-taken-king/',
#  'https://www.metacritic.com/game/pc/heroes-of-the-storm/',
#  'https://www.metacritic.com/game/playstation-vita/coderealize---guardian-of-rebirth/',
#  'https://www.metacritic.com/game/playstation-4/olliolli2-welcome-to-olliwood/',
#  'https://www.metacritic.com/game/pc/football-manager-2013/',
#  'https://www.metacritic.com/game/playstation-3/ufc-undisputed-3/',
#  'https://www.metacritic.com/game/pc/black-mesa/',
#  'https://www.metacritic.com/game/pc/fifa-soccer-13/',
#  'https://www.metacritic.com/game/pc/tribes-ascend/',
#  'https://www.metacritic.com/game/pc/rayman-origins/',
#  'https://www.metacritic.com/game/3ds/crashmo/',
#  'https://www.metacritic.com/game/playstation-vita/tales-from-space-mutant-blobs-attack/',
#  'https://www.metacritic.com/game/pc/planescape-torment---enhanced-edition/',
#  'https://www.metacritic.com/game/playstation-4/pyre/',
#  'https://www.metacritic.com/game/playstation-4/dirt-4/',
#  'https://www.metacritic.com/game/switch/mario-+-rabbids-kingdom-battle/',
#  'https://www.metacritic.com/game/xbox-one/project-cars-2/',
#  'https://www.metacritic.com/game/playstation-4/statik/',
#  'https://www.metacritic.com/game/playstation-4/kingdom-hearts-hd-i5-+-ii5-remix/',
#  'https://www.metacritic.com/game/3ds/pokemon-ultra-sun/',
#  'https://www.metacritic.com/game/xbox-one/south-park-the-fractured-but-whole/',
#  'https://www.metacritic.com/game/switch/shovel-knight-specter-of-torment/',
# ...
#  'https://www.metacritic.com/game/pc/pinball-fx-2/',
#  'https://www.metacritic.com/game/pc/planetside-2/',
#  'https://www.metacritic.com/game/playstation-3/street-fighter-x-tekken/',
#  'https://www.metacritic.com/game/xbox-360/mass-effect-2/',
#  'https://www.metacritic.com/game/playstation-3/red-dead-redemption/',
#  'https://www.metacritic.com/game/xbox-360/red-dead-redemption/',
#  'https://www.metacritic.com/game/pc/mass-effect-2/',
#  'https://www.metacritic.com/game/xbox-360/pac-man-championship-edition-dx/',
#  'https://www.metacritic.com/game/pc/starcraft-ii-wings-of-liberty/',
#  'https://www.metacritic.com/game/xbox-360/rock-band-3/',
#  'https://www.metacritic.com/game/playstation-3/god-of-war-iii/',
#  'https://www.metacritic.com/game/playstation-3/super-street-fighter-iv/',
#  'https://www.metacritic.com/game/xbox-360/super-street-fighter-iv/',
#  'https://www.metacritic.com/game/playstation-3/pac-man-championship-edition-dx/',
#  'https://www.metacritic.com/game/wii/rock-band-3/',
#  'https://www.metacritic.com/game/playstation-3/rock-band-3/',
#  'https://www.metacritic.com/game/playstation-4/super-meat-boy/',
#  'https://www.metacritic.com/game/xbox-one/rare-replay/',
#  'https://www.metacritic.com/game/wii-u/freedom-planet/',
#  'https://www.metacritic.com/game/3ds/shin-megami-tensei-devil-survivor-2-record-breaker/',
#  'https://www.metacritic.com/game/xbox-one/halo-5-guardians/',
#  'https://www.metacritic.com/game/pc/80-days-2015/',
#  'https://www.metacritic.com/game/pc/hearthstone-the-grand-tournament/',
#  'https://www.metacritic.com/game/playstation-vita/grim-fandango-remastered/',
#  'https://www.metacritic.com/game/playstation-vita/sound-shapes/',
#  'https://www.metacritic.com/game/xbox-360/assassins-creed-iii/',
#  'https://www.metacritic.com/game/wii-u/trine-2-directors-cut/',
#  'https://www.metacritic.com/game/xbox-360/the-walking-dead-episode-2---starved-for-help/',
#  'https://www.metacritic.com/game/playstation-3/need-for-speed-most-wanted---a-criterion-game/',
#  'https://www.metacritic.com/game/xbox-360/f1-2012/',
#  'https://www.metacritic.com/game/xbox-360/need-for-speed-most-wanted---a-criterion-game/',
#  'https://www.metacritic.com/game/playstation-3/the-walking-dead-episode-1---a-new-day/',
#  'https://www.metacritic.com/game/pc/ftl-faster-than-light/',
#  'https://www.metacritic.com/game/playstation-3/the-walking-dead-episode-2---starved-for-help/',
#  'https://www.metacritic.com/game/playstation-3/darksiders-ii/',
#  'https://www.metacritic.com/game/wii-u/new-super-mario-bros-u/',
#  'https://www.metacritic.com/game/playstation-3/mlb-10-the-show/',
#  'https://www.metacritic.com/game/xbox-360/halo-reach/',
#  'https://www.metacritic.com/game/pc/world-of-warcraft-cataclysm/',
#  'https://www.metacritic.com/game/xbox-360/bayonetta/',
#  'https://www.metacritic.com/game/xbox-360/limbo/',
#  'https://www.metacritic.com/game/playstation-3/assassins-creed-brotherhood/',
#  'https://www.metacritic.com/game/xbox-360/super-meat-boy/',
#  'https://www.metacritic.com/game/pc/sid-meiers-civilization-v/',
#  'https://www.metacritic.com/game/psp/shin-megami-tensei-persona-3-portable/',
#  'https://www.metacritic.com/game/xbox-360/plants-vs-zombies/',
#  'https://www.metacritic.com/game/xbox-360/assassins-creed-brotherhood/',
#  'https://www.metacritic.com/game/playstation-4/axiom-verge/',
#  'https://www.metacritic.com/game/wii-u/xenoblade-chronicles-x/',
#  'https://www.metacritic.com/game/pc/soma/',
#  'https://www.metacritic.com/game/pc/grim-fandango-remastered/',
#  'https://www.metacritic.com/game/pc/fallout-4/',
#  'https://www.metacritic.com/game/xbox-one/madden-nfl-16/',
#  'https://www.metacritic.com/game/xbox-one/fifa-16/',
#  'https://www.metacritic.com/game/playstation-4/final-fantasy-x--x-2-hd-remaster/',
#  'https://www.metacritic.com/game/playstation-4/dmc-devil-may-cry-definitive-edition/',
#  'https://www.metacritic.com/game/pc/life-is-strange/',
#  'https://www.metacritic.com/game/playstation-vita/steins-gate/',
#  'https://www.metacritic.com/game/playstation-vita/zero-escape-virtues-last-reward/',
#  'https://www.metacritic.com/game/playstation-3/nhl-13/',
#  'https://www.metacritic.com/game/playstation-3/sound-shapes/',
#  'https://www.metacritic.com/game/playstation-3/need-for-speed-hot-pursuit/',
#  'https://www.metacritic.com/game/wii/cave-story/',
#  'https://www.metacritic.com/game/playstation-3/fifa-soccer-11/',
#  'https://www.metacritic.com/game/psp/metal-gear-solid-peace-walker/',
#  'https://www.metacritic.com/game/xbox-360/nba-2k11/',
#  'https://www.metacritic.com/game/playstation-3/nba-2k11/',
#  'https://www.metacritic.com/game/wii/dj-hero-2/',
#  'https://www.metacritic.com/game/playstation-3/nhl-11/',
#  'https://www.metacritic.com/game/playstation-4/resident-evil-hd-remaster/',
#  'https://www.metacritic.com/game/xbox-360/bioshock-2/',
#  'https://www.metacritic.com/game/playstation-3/battlefield-bad-company-2/',
#  'https://www.metacritic.com/game/xbox-360/battlefield-bad-company-2/',
#  'https://www.metacritic.com/game/xbox-360/pinball-fx-2/',
#  'https://www.metacritic.com/game/xbox-360/nhl-11/',
#  'https://www.metacritic.com/game/playstation-3/call-of-duty-black-ops/',
#  'https://www.metacritic.com/game/playstation-3/bioshock-2/',
#  'https://www.metacritic.com/game/pc/bioshock-2/',
#  'https://www.metacritic.com/game/playstation-3/battlefield-bad-company-2-vietnam/',
#  'https://www.metacritic.com/game/xbox-360/fifa-soccer-11/',
#  'https://www.metacritic.com/game/wii/art-of-balance/',
#  'https://www.metacritic.com/game/xbox-360/battlefield-bad-company-2-vietnam/',
#  'https://www.metacritic.com/game/xbox-360/need-for-speed-hot-pursuit/',
#  'https://www.metacritic.com/game/pc/super-meat-boy/',
#  'https://www.metacritic.com/game/playstation-3/monkey-island-2-special-edition-lechucks-revenge/',
#  'https://www.metacritic.com/game/playstation-3/red-dead-redemption-undead-nightmare-pack/',
#  'https://www.metacritic.com/game/ds/dragon-quest-ix-sentinels-of-the-starry-skies/',
#  'https://www.metacritic.com/game/pc/battlefield-bad-company-2/',
#  'https://www.metacritic.com/game/playstation-3/heavy-rain/',
#  'https://www.metacritic.com/game/pc/monkey-island-2-special-edition-lechucks-revenge/',
#  'https://www.metacritic.com/game/xbox-360/mass-effect-2-lair-of-the-shadow-broker/',
#  'https://www.metacritic.com/game/ds/pokemon-soulsilver-version/',
#  'https://www.metacritic.com/game/xbox-360/red-dead-redemption-undead-nightmare-pack/',
#  'https://www.metacritic.com/game/wii/donkey-kong-country-returns/',
#  'https://www.metacritic.com/game/xbox-360/call-of-duty-black-ops/',
#  'https://www.metacritic.com/game/playstation-3/blazblue-continuum-shift/',
#  'https://www.metacritic.com/game/ds/pokemon-heartgold-version/',
#  'https://www.metacritic.com/game/wii/sin--punishment-star-successor/',
#  'https://www.metacritic.com/game/playstation-3/bayonetta/',
#  'https://www.metacritic.com/game/wii/kirbys-epic-yarn/',
#  'https://www.metacritic.com/game/playstation-3/dj-hero-2/',
#  'https://www.metacritic.com/game/pc/borderlands-the-secret-armory-of-general-knoxx/',
#  'https://www.metacritic.com/game/pc/need-for-speed-hot-pursuit/',
#  'https://www.metacritic.com/game/wii/fluidity/',
#  'https://www.metacritic.com/game/xbox-360/pinball-fx-2-marvel-pinball/',
#  'https://www.metacritic.com/game/psp/god-of-war-ghost-of-sparta/',
#  'https://www.metacritic.com/game/pc/mass-effect-2-lair-of-the-shadow-broker/',
#  'https://www.metacritic.com/game/xbox-360/ncaa-football-11/',
#  'https://www.metacritic.com/game/ds/professor-layton-and-the-unwound-future/',
#  'https://www.metacritic.com/game/playstation-3/joe-danger/',
#  'https://www.metacritic.com/game/xbox-360/dj-hero-2/',
#  'https://www.metacritic.com/game/pc/battlefield-bad-company-2-vietnam/',
#  'https://www.metacritic.com/game/pc/assassins-creed-ii/',
#  'https://www.metacritic.com/game/ds/shantae-riskys-revenge/',
#  'https://www.metacritic.com/game/xbox-360/tom-clancys-splinter-cell-conviction/',
#  'https://www.metacritic.com/game/playstation-3/uncharted-2-among-thieves/',
#  'https://www.metacritic.com/game/playstation-3/ufc-undisputed-2010/',
#  'https://www.metacritic.com/game/playstation-3/the-sly-collection/',
#  'https://www.metacritic.com/game/wii/tatsunoko-vs-capcom-ultimate-all-stars/',
#  'https://www.metacritic.com/game/playstation-3/castle-crashers/',
#  'https://www.metacritic.com/game/xbox-360/lara-croft-and-the-guardian-of-light/',
#  'https://www.metacritic.com/game/xbox-360/blazblue-continuum-shift/',
#  'https://www.metacritic.com/game/pc/amnesia-the-dark-descent/',
#  'https://www.metacritic.com/game/pc/football-manager-2011/',
#  'https://www.metacritic.com/game/xbox-360/monkey-island-2-special-edition-lechucks-revenge/',
#  'https://www.metacritic.com/game/pc/warhammer-40000-dawn-of-war-ii---chaos-rising/',
#  'https://www.metacritic.com/game/playstation-3/ncaa-football-11/',
#  'https://www.metacritic.com/game/playstation-3/call-of-duty-modern-warfare-2/',
#  'https://www.metacritic.com/game/playstation-3/street-fighter-iv/',
#  'https://www.metacritic.com/game/xbox-360/call-of-duty-modern-warfare-2/',
#  'https://www.metacritic.com/game/ds/grand-theft-auto-chinatown-wars/',
#  'https://www.metacritic.com/game/xbox-360/street-fighter-iv/',
#  'https://www.metacritic.com/game/pc/minecraft/',
#  'https://www.metacritic.com/game/playstation-3/braid/',
#  'https://www.metacritic.com/game/ds/flipnote-studio/',
#  'https://www.metacritic.com/game/xbox-360/forza-motorsport-3/',
#  'https://www.metacritic.com/game/xbox-360/batman-arkham-asylum/',
#  'https://www.metacritic.com/game/playstation-3/castlevania-lords-of-shadow/',
#  'https://www.metacritic.com/game/xbox-360/borderlands-the-secret-armory-of-general-knoxx/',
#  'https://www.metacritic.com/game/playstation-3/sam--max-the-devils-playhouse---episode-2-the-tomb-of-sammun-mak/',
#  'https://www.metacritic.com/game/playstation-3/borderlands-the-secret-armory-of-general-knoxx/',
#  'https://www.metacritic.com/game/pc/fallout-new-vegas/',
#  'https://www.metacritic.com/game/wii/tiger-woods-pga-tour-11/',
#  'https://www.metacritic.com/game/playstation-3/f1-2010/',
#  'https://www.metacritic.com/game/xbox-360/ufc-undisputed-2010/',
#  'https://www.metacritic.com/game/wii/monster-hunter-tri/',
#  'https://www.metacritic.com/game/wii/no-more-heroes-2-desperate-struggle/',
#  'https://www.metacritic.com/game/pc/just-cause-2/',
#  'https://www.metacritic.com/game/wii/metroid-prime-trilogy/',
#  'https://www.metacritic.com/game/playstation-3/fifa-soccer-10/',
#  'https://www.metacritic.com/game/playstation-3/assassins-creed-ii/',
#  'https://www.metacritic.com/game/playstation-3/peggle/',
#  'https://www.metacritic.com/game/pc/batman-arkham-asylum/',
#  'https://www.metacritic.com/game/playstation-3/god-of-war-collection/',
#  'https://www.metacritic.com/game/pc/street-fighter-iv/',
#  'https://www.metacritic.com/game/playstation-3/killzone-2/',
#  'https://www.metacritic.com/game/playstation-3/batman-arkham-asylum/',
#  'https://www.metacritic.com/game/pc/dragon-age-origins/',
#  'https://www.metacritic.com/game/xbox-360/assassins-creed-ii/',
#  'https://www.metacritic.com/game/ds/mario--luigi-bowsers-inside-story/',
#  'https://www.metacritic.com/game/xbox-360/grand-theft-auto-iv-the-lost-and-damned/',
#  'https://www.metacritic.com/game/xbox-360/fifa-soccer-10/',
#  'https://www.metacritic.com/game/pc/braid/',
#  'https://www.metacritic.com/game/playstation-3/mlb-09-the-show/',
#  'https://www.metacritic.com/game/psp/grand-theft-auto-chinatown-wars/',
#  'https://www.metacritic.com/game/pc/empire-total-war/',
#  'https://www.metacritic.com/game/playstation-3/wipeout-hd-fury/',
#  'https://www.metacritic.com/game/playstation-3/demons-souls/',
#  'https://www.metacritic.com/game/wii/the-beatles-rock-band/',
#  'https://www.metacritic.com/game/xbox-360/left-4-dead-2/',
#  'https://www.metacritic.com/game/pc/left-4-dead-2/',
#  'https://www.metacritic.com/game/xbox-360/grand-theft-auto-iv-the-ballad-of-gay-tony/',
#  'https://www.metacritic.com/game/wii/guitar-hero-5/',
#  'https://www.metacritic.com/game/xbox-360/the-beatles-rock-band/',
#  'https://www.metacritic.com/game/pc/dirt-2/',
#  'https://www.metacritic.com/game/xbox-360/peggle/',
#  'https://www.metacritic.com/game/playstation-3/the-beatles-rock-band/',
#  'https://www.metacritic.com/game/xbox-360/shadow-complex/',
#  'https://www.metacritic.com/game/xbox-360/nhl-10/',
#  'https://www.metacritic.com/game/playstation-3/nhl-10/',
#  'https://www.metacritic.com/game/wii/tiger-woods-pga-tour-10/',
#  'https://www.metacritic.com/game/xbox-360/the-secret-of-monkey-island-special-edition/',
#  'https://www.metacritic.com/game/playstation-3/fight-night-round-4/',
#  'https://www.metacritic.com/game/pc/eve-online-special-edition/',
#  'https://www.metacritic.com/game/pc/plants-vs-zombies/',
#  'https://www.metacritic.com/game/pc/football-manager-2010/',
#  'https://www.metacritic.com/game/playstation-3/blazblue-calamity-trigger/',
#  'https://www.metacritic.com/game/pc/burnout-paradise-the-ultimate-box/',
#  'https://www.metacritic.com/game/playstation-3/critter-crunch/',
#  'https://www.metacritic.com/game/wii/new-super-mario-bros-wii/',
#  'https://www.metacritic.com/game/wii/dj-hero/',
#  'https://www.metacritic.com/game/xbox-360/fight-night-round-4/',
#  'https://www.metacritic.com/game/ds/the-legend-of-zelda-spirit-tracks/',
#  'https://www.metacritic.com/game/playstation-3/dirt-2/',
#  'https://www.metacritic.com/game/playstation-3/dragon-age-origins/',
#  'https://www.metacritic.com/game/wii/little-kings-story/',
#  'https://www.metacritic.com/game/xbox-360/dirt-2/',
#  'https://www.metacritic.com/game/playstation-3/flower/',
#  'https://www.metacritic.com/game/psp/littlebigplanet/',
#  'https://www.metacritic.com/game/playstation-3/pixeljunk-shooter/',
#  'https://www.metacritic.com/game/playstation-3/ratchet--clank-future-a-crack-in-time/',
#  'https://www.metacritic.com/game/psp/pixeljunk-monsters-deluxe/',
#  'https://www.metacritic.com/game/wii/lostwinds-winter-of-the-melodias/',
#  'https://www.metacritic.com/game/wii/boom-blox-bash-party/',
#  'https://www.metacritic.com/game/ds/might--magic-clash-of-heroes/',
#  'https://www.metacritic.com/game/xbox-360/blazblue-calamity-trigger/',
#  'https://www.metacritic.com/game/pc/resident-evil-5/',
#  'https://www.metacritic.com/game/playstation-3/guitar-hero-metallica/',
#  'https://www.metacritic.com/game/xbox-360/dragon-age-origins/',
#  'https://www.metacritic.com/game/pc/the-sims-3/',
#  'https://www.metacritic.com/game/xbox-360/trials-hd/',
#  'https://www.metacritic.com/game/wii/punch-out!!/',
#  'https://www.metacritic.com/game/pc/call-of-duty-modern-warfare-2/',
#  'https://www.metacritic.com/game/pc/the-secret-of-monkey-island-special-edition/',
#  'https://www.metacritic.com/game/playstation-3/dj-hero/',
#  'https://www.metacritic.com/game/playstation-3/shatter/',
#  'https://www.metacritic.com/game/playstation-3/guitar-hero-5/',
#  'https://www.metacritic.com/game/pc/warhammer-40000-dawn-of-war-ii/',
#  'https://www.metacritic.com/game/playstation-3/red-faction-guerrilla/',
#  'https://www.metacritic.com/game/xbox-360/madden-nfl-10/',
#  'https://www.metacritic.com/game/psp/locoroco-2/',
#  'https://www.metacritic.com/game/playstation-3/madden-nfl-10/',
#  'https://www.metacritic.com/game/pc/machinarium/',
#  'https://www.metacritic.com/game/xbox-360/guitar-hero-5/',
#  'https://www.metacritic.com/game/wii/guitar-hero-metallica/',
#  'https://www.metacritic.com/game/xbox-360/red-faction-guerrilla/',
#  'https://www.metacritic.com/game/playstation-3/marvel-vs-capcom-2/',
#  'https://www.metacritic.com/game/psp/tetris/',
#  'https://www.metacritic.com/game/playstation-3/infamous/',
#  'https://www.metacritic.com/game/ds/peggle-dual-shot/',
#  'https://www.metacritic.com/game/psp/blast-off/',
#  'https://www.metacritic.com/game/xbox-360/splosion-man/',
#  'https://www.metacritic.com/game/wii/pro-evolution-soccer-2009/',
#  'https://www.metacritic.com/game/playstation-3/resident-evil-5/',
#  'https://www.metacritic.com/game/ds/shin-megami-tensei-devil-survivor/',
#  'https://www.metacritic.com/game/xbox-360/guitar-hero-metallica/',
#  'https://www.metacritic.com/game/pc/time-gentlemen-please!/',
#  ...]

# %%
for i, row in meta_games.iterrows():
    row_metacritic_details_url = URLMaker(row[1]['name'], row[1]['console'], 'details')
    row_req = requests.get(url, headers = headers)
    if cur_req.status_code != 200:
        print(cur_req.status_code,url)
    else:
        publisher = detail_soup.find_all('a', {'href': re.compile(r'/company')})
        publisher = publisher[1].get_text().strip()
        genre =
# Out:
# 0
# metascore                    97
# name         Grand Theft Auto V
# console                     PS3
# userscore                   8.3
# date               Sep 17, 2013
# genre                       NaN
# developer                   NaN
# players                     NaN
# publisher                   NaN
# rating                      NaN
# Name: 0, dtype: object
# 1
# metascore                    97
# name         Grand Theft Auto V
# console                    X360
# userscore                   8.3
# date               Sep 17, 2013
# genre                       NaN
# developer                   NaN
# players                     NaN
# publisher                   NaN
# rating                      NaN
# Name: 1, dtype: object
# 2
# metascore                95
# name         The Last of Us
# console                 PS3
# userscore               9.2
# date           Jun 14, 2013
# genre                   NaN
# developer               NaN
# players                 NaN
# publisher               NaN
# rating                  NaN
# Name: 2, dtype: object
# 3
# metascore                   94
# name         BioShock Infinite
# console                    PS3
# userscore                  8.5
# date              Mar 26, 2013
# genre                      NaN
# developer                  NaN
# players                    NaN
# publisher                  NaN
# rating                     NaN
# Name: 3, dtype: object
# 4
# metascore                   94
# name         BioShock Infinite
# console                     PC
# userscore                  8.6
# date              Mar 25, 2013
# genre                      NaN
# developer                  NaN
# players                    NaN
# publisher                  NaN
# rating                     NaN
# Name: 4, dtype: object
# 5
# metascore                   93
# name         BioShock Infinite
# console                   X360
# userscore                  8.5
# date              Mar 26, 2013
# genre                      NaN
# developer                  NaN
# players                    NaN
# publisher                  NaN
# rating                     NaN
# Name: 5, dtype: object
# 6
# metascore                      93
# name         Super Mario 3D World
# console                      WIIU
# userscore                     8.9
# date                 Nov 22, 2013
# genre                         NaN
# developer                     NaN
# players                       NaN
# publisher                     NaN
# rating                        NaN
# Name: 6, dtype: object
# 7
# metascore                        92
# name         Fire Emblem: Awakening
# console                         3DS
# userscore                       9.1
# date                    Feb 4, 2013
# genre                           NaN
# developer                       NaN
# players                         NaN
# publisher                       NaN
# rating                          NaN
# Name: 7, dtype: object
# 8
# metascore                92
# name         Rayman Legends
# console                WIIU
# userscore               8.7
# date            Sep 3, 2013
# genre                   NaN
# developer               NaN
# players                 NaN
# publisher               NaN
# rating                  NaN
# Name: 8, dtype: object
# 9
# metascore             91
# name                 Fez
# console               PC
# userscore            6.7
# date         May 1, 2013
# genre                NaN
# developer            NaN
# players              NaN
# publisher            NaN
# rating               NaN
# Name: 9, dtype: object

# %%
for row in meta_games.iterrows():
    urls.append(URLMaker(row[1]['name'], row[1]['console']))
urls

for url in urls:
    try:
        cur_req = requests.get(url, headers = headers)
        if cur_req.status_code != 200:
            print('404:',url)
    except:
        print('Broken:',url)
# Out:
# 404: https://www.metacritic.com/game/pc/gone-home
# 404: https://www.metacritic.com/game/pc/pac-man-championship-edition-dx-+
# 404: https://www.metacritic.com/game/playstation-vita/final-fantasy-x--x-2-hd-remaster
# 404: https://www.metacritic.com/game/playstation-3/final-fantasy-x--x-2-hd-remaster
# 404: https://www.metacritic.com/game/playstation-3/the-ico-&-shadow-of-the-colossus-collection
# 404: https://www.metacritic.com/game/playstation-3/might-&-magic-clash-of-heroes
# 404: https://www.metacritic.com/game/xbox-360/beyond-good-&-evil-hd
# 404: https://www.metacritic.com/game/playstation-4/ratchet-&-clank
# 404: https://www.metacritic.com/game/playstation-vita/steins-gate-0
# 404: https://www.metacritic.com/game/playstation-4/final-fantasy-x--x-2-hd-remaster
# 404: https://www.metacritic.com/game/playstation-vita/steins-gate
# 404: https://www.metacritic.com/game/wii/sin-&-punishment-star-successor
# 404: https://www.metacritic.com/game/playstation-3/sam-&-max-the-devils-playhouse---episode-2-the-tomb-of-sammun-mak
# 404: https://www.metacritic.com/game/ds/mario-&-luigi-bowsers-inside-story

# %% [markdown]
# ## Getting list of positive and negative adjectives

# %%
adjectives_4800 = requests.get("https://patternbasedwriting.com/elementary_writing_success/list-4800-adjectives/")
soup_4800 = BeautifulSoup(adjectives_4800.content, 'html.parser')
words_4800 = soup_4800.find_all('table')[2].get_text()
words_4800 = words_4800.split('\n')
words_4800
# Out:
# ['',
#  '',
#  '',
#  '1.  a   2',
#  '2.  abandoned',
#  '3.  abdominal',
#  '4.  abhorrent',
#  '5.  abiding',
#  '6.  abject',
#  '7.  able   1',
#  '8.  able-bodied',
#  '9.  abnormal',
#  '10.  abounding',
#  '11.  abrasive',
#  '12.  abrupt',
#  '13.  absent',
#  '14.  absentminded',
#  '15.  absolute',
#  '16.  absorbed',
#  '17.  absorbing',
#  '18.  abstracted',
#  '19.  absurd',
#  '20.  abundant',
#  '21.  abusive',
#  '22.  abysmal',
#  '23.  academic',
#  '24.  acceptable',
#  '25.  accepting',
#  '26.  accessible',
#  '27.  accidental',
#  '28.  acclaimed',
#  '29.  accommodating',
#  '30.  accompanying',
#  '31.  accountable',
#  '32.  accurate',
#  '33.  accusative',
#  '34.  accused',
#  '35.  accusing',
#  '36.  acerbic',
#  '37.  achievable',
#  '38.  aching',
#  '39.  acid   3',
#  '40.  acidic',
#  '41.  acknowledged',
#  '42.  acoustic',
#  '43.  acrid',
#  '44.  acrimonious',
#  '45.  acrobatic',
#  '46.  actionable',
#  '47.  active',
#  '48.  actual',
#  '49.  ad hoc',
#  '50.  adamant',
#  '51.  adaptable',
#  '52.  adaptive',
#  '53.  addicted',
#  '54.  addictive',
#  '55.  additional',
#  '56.  adept',
#  '57.  adequate',
#  '58.  adhesive',
#  '59.  adjacent',
#  '60.  adjoining',
#  '61.  adjustable',
#  '62.  administrative',
#  '63.  admirable',
#  '64.  admired',
#  '65.  admiring',
#  '66.  adopted',
#  '67.  adoptive',
#  '68.  adorable',
#  '69.  adored',
#  '70.  adoring',
#  '71.  adrenalized',
#  '72.  adroit',
#  '73.  adult',
#  '74.  advanced',
#  '75.  advantageous',
#  '76.  adventurous',
#  '77.  adversarial',
#  '78.  advisable',
#  '79.  aerial',
#  '80.  affable',
#  '81.  affected',
#  '82.  affectionate',
#  '83.  affirmative',
#  '84.  affordable',
#  '85.  afraid',
#  '86.  afternoon',
#  '87.  ageless',
#  '88.  aggravated',
#  '89.  aggravating',
#  '90.  aggressive',
#  '91.  agitated',
#  '92.  agonizing',
#  '93.  agrarian',
#  '94.  agreeable',
#  '95.  aimless',
#  '96.  airline   3',
#  '97.  airsick',
#  '98.  ajar',
#  '99.  alarmed',
#  '100.  alarming',
#  '101.  alert',
#  '102.  algebraic',
#  '103.  alien',
#  '104.  alienated',
#  '105.  alike',
#  '106.  alive',
#  '107.  all   2',
#  '108.  all-around',
#  '109.  alleged',
#  '110.  allowable',
#  '111.  all-purpose',
#  '112.  all-too-common',
#  '113.  alluring',
#  '114.  allusive',
#  '115.  alone',
#  '116.  aloof',
#  '117.  alterable',
#  '118.  alternating',
#  '119.  alternative',
#  '120.  amazed',
#  '121.  amazing',
#  '122.  ambiguous',
#  '123.  ambitious',
#  '124.  ambulant',
#  '125.  ambulatory',
#  '126.  amiable',
#  '127.  amicable',
#  '128.  amphibian',
#  '129.  amused',
#  '130.  amusing',
#  '131.  an   2',
#  '132.  ancient',
#  '133.  anecdotal',
#  '134.  anemic',
#  '135.  angelic',
#  '136.  angered',
#  '137.  angry   1',
#  '138.  angular',
#  '139.  animal   3',
#  '140.  animated',
#  '141.  annoyed',
#  '142.  annoying',
#  '143.  annual',
#  '144.  anonymous',
#  '145.  another   2',
#  '146.  antagonistic',
#  '147.  anticipated',
#  '148.  anticlimactic',
#  '149.  anticorrosive',
#  '150.  antiquated',
#  '151.  antiseptic',
#  '152.  antisocial',
#  '153.  antsy',
#  '154.  anxious',
#  '155.  any',
#  '156.  apathetic',
#  '157.  apologetic',
#  '158.  apologizing',
#  '159.  appalling',
#  '160.  appealing',
#  '161.  appetizing',
#  '162.  applauding',
#  '163.  applicable',
#  '164.  applicative',
#  '165.  appreciative',
#  '166.  apprehensive',
#  '167.  approachable',
#  '168.  approaching',
#  '169.  appropriate',
#  '170.  approving',
#  '171.  approximate',
#  '172.  aquatic',
#  '173.  architectural',
#  '174.  ardent',
#  '175.  arduous',
#  '176.  arguable',
#  '177.  argumentative',
#  '178.  arid',
#  '179.  aristocratic',
#  '180.  aromatic',
#  '181.  arresting',
#  '182.  arrogant',
#  '183.  artful',
#  '184.  artificial',
#  '185.  artistic',
#  '186.  artless',
#  '187.  ashamed',
#  '188.  aspiring',
#  '189.  assertive',
#  '190.  assignable',
#  '191.  assorted',
#  '192.  assumable',
#  '193.  assured',
#  '194.  assuring',
#  '195.  astonished',
#  '196.  astonishing',
#  '197.  astounded',
#  '198.  astounding',
#  '199.  astringent',
#  '200.  astronomical',
#  '201.  astute',
#  '202.  asymmetrical',
#  '203.  athletic',
#  '204.  atomic',
#  '205.  atrocious',
#  '206.  attachable',
#  '207.  attainable',
#  '208.  attentive',
#  '209.  attractive',
#  '210.  attributable',
#  '211.  atypical',
#  '212.  audacious',
#  '213.  auspicious',
#  '214.  authentic',
#  '215.  authoritarian',
#  '216.  authoritative',
#  '217.  autobiographic',
#  '218.  autographed',
#  '219.  automatic',
#  '220.  autonomous',
#  '221.  available',
#  '222.  avant-garde',
#  '223.  avenging',
#  '224.  average',
#  '225.  avian',
#  '226.  avid',
#  '227.  avoidable',
#  '228.  awake',
#  '229.  awakening',
#  '230.  aware',
#  '231.  away',
#  '232.  awesome',
#  '233.  awful',
#  '234.  awkward',
#  '235.  axiomatic',
#  '236.  babbling',
#  '237.  baby   3',
#  '238.  background   3',
#  '239.  backhanded',
#  '240.  bacterial',
#  '241.  bad   1',
#  '242.  bad-tempered',
#  '243.  baffled',
#  '244.  baffling',
#  '245.  bald   1',
#  '246.  balding',
#  '247.  balmy',
#  '248.  bandaged',
#  '249.  banging',
#  '250.  bankable',
#  '251.  banned',
#  '252.  bantering',
#  '253.  barbaric',
#  '254.  barbarous',
#  '255.  barbequed',
#  '256.  barefooted',
#  '257.  barking',
#  '258.  barren',
#  '259.  bashful',
#  '260.  basic',
#  '261.  battered',
#  '262.  batty   1',
#  '263.  bawling',
#  '264.  beady   1',
#  '265.  beaming',
#  '266.  bearable',
#  '267.  beautiful',
#  '268.  beckoning',
#  '269.  bedazzled',
#  '270.  bedazzling',
#  '271.  beefy',
#  '272.  beeping',
#  '273.  befitting',
#  '274.  befuddled',
#  '275.  beginning',
#  '276.  belching',
#  '277.  believable',
#  '278.  bellicose',
#  '279.  belligerent',
#  '280.  bellowing',
#  '281.  bendable',
#  '282.  beneficial',
#  '283.  benevolent',
#  '284.  benign',
#  '285.  bent',
#  '286.  berserk',
#  '287.  best',
#  '288.  betrayed',
#  '289.  better',
#  '290.  better off',
#  '291.  better-late-than-never',
#  '292.  bewildered',
#  '293.  bewildering',
#  '294.  bewitched',
#  '295.  bewitching',
#  '296.  biased',
#  '297.  biblical',
#  '298.  big   1',
#  '299.  big-city',
#  '300.  bigger',
#  '301.  biggest',
#  '302.  big-headed',
#  '303.  bighearted',
#  '304.  bigoted',
#  '305.  bilingual',
#  '306.  billable',
#  '307.  billowy',
#  '308.  binary',
#  '309.  binding',
#  '310.  bioactive',
#  '311.  biodegradable',
#  '312.  biographical',
#  '313.  bite-sized',
#  '314.  biting',
#  '315.  bitter   1',
#  '316.  bizarre',
#  '317.  black   1',
#  '318.  black-and-blue',
#  '319.  blamable',
#  '320.  blameless',
#  '321.  bland   1',
#  '322.  blank   1',
#  '323.  blaring',
#  '324.  blasphemous',
#  '325.  blatant',
#  '326.  blazing',
#  '327.  bleached',
#  '328.  bleak   1',
#  '329.  bleary',
#  '330.  bleary-eyed',
#  '331.  blessed',
#  '332.  blind',
#  '333.  blindfolded',
#  '334.  blinding',
#  '335.  blissful',
#  '336.  blistering',
#  '337.  bloated',
#  '338.  blonde   1',
#  '339.  bloodied',
#  '340.  blood-red',
#  '341.  bloodthirsty',
#  '342.  bloody   1',
#  '343.  blooming',
#  '344.  blossoming',
#  '345.  blue   1',
#  '346.  blundering',
#  '347.  blunt   1',
#  '348.  blurred',
#  '349.  blurry   1',
#  '350.  blushing',
#  '351.  boastful',
#  '352.  bodacious',
#  '353.  bohemian',
#  '354.  boiling',
#  '355.  boisterous',
#  '356.  bold   1',
#  '357.  bookish',
#  '358.  booming',
#  '359.  boorish',
#  '360.  bordering',
#  '361.  bored',
#  '362.  boring',
#  '363.  born',
#  '364.  bossy   1',
#  '365.  both   2',
#  '366.  bothered',
#  '367.  bouncing',
#  '368.  bouncy   1',
#  '369.  boundless',
#  '370.  bountiful',
#  '371.  boyish',
#  '372.  braided',
#  '373.  brainless',
#  '374.  brainy   1',
#  '375.  brash   1',
#  '376.  brassy   1',
#  '377.  brave   1',
#  '378.  brawny   1',
#  '379.  brazen',
#  '380.  breakable',
#  '381.  breathable',
#  '382.  breathless',
#  '383.  breathtaking',
#  '384.  breezy   1',
#  '385.  bribable',
#  '386.  brick   3',
#  '387.  brief   1',
#  '388.  bright   1',
#  '389.  bright-eyed',
#  '390.  bright-red',
#  '391.  brilliant',
#  '392.  briny',
#  '393.  brisk   1',
#  '394.  bristly',
#  '395.  broad   1',
#  '396.  broken',
#  '397.  broken-hearted',
#  '398.  bronchial',
#  '399.  bronze   3',
#  '400.  bronzed',
#  '401.  brooding',
#  '402.  brown   1',
#  '403.  bruised',
#  '404.  brunette',
#  '405.  brutal',
#  '406.  brutish',
#  '407.  bubbly   1',
#  '408.  budget   3',
#  '409.  built-in',
#  '410.  bulky   1',
#  '411.  bumpy   1',
#  '412.  bungling',
#  '413.  buoyant',
#  '414.  bureaucratic',
#  '415.  burly   1',
#  '416.  burnable',
#  '417.  burning',
#  '418.  bushy   1',
#  '419.  busiest',
#  '420.  business   3',
#  '421.  bustling',
#  '422.  busy   1',
#  '423.  buzzing',
#  '424.  cackling',
#  '425.  caged',
#  '426.  cagey',
#  '427.  calculable',
#  '428.  calculated',
#  '429.  calculating',
#  '430.  callous',
#  '431.  calm   1',
#  '432.  calming',
#  '433.  camouflaged',
#  '434.  cancelled',
#  '435.  cancerous',
#  '436.  candid',
#  '437.  cantankerous',
#  '438.  capable',
#  '439.  capricious',
#  '440.  captivated',
#  '441.  captivating',
#  '442.  captive',
#  '443.  carefree',
#  '444.  careful',
#  '445.  careless',
#  '446.  caring',
#  '447.  carnivorous',
#  '448.  carpeted',
#  '449.  carsick',
#  '450.  casual',
#  '451.  catastrophic',
#  '452.  catatonic',
#  '453.  catchable',
#  '454.  caustic',
#  '455.  cautious',
#  '456.  cavalier',
#  '457.  cavernous',
#  '458.  ceaseless',
#  '459.  celebrated',
#  '460.  celestial',
#  '461.  centered',
#  '462.  central',
#  '463.  cerebral',
#  '464.  ceremonial',
#  '465.  certain   2',
#  '466.  certifiable',
#  '467.  certified',
#  '468.  challenged',
#  '469.  challenging',
#  '470.  chance   3',
#  '471.  changeable',
#  '472.  changing',
#  '473.  chanting',
#  '474.  charging',
#  '475.  charismatic',
#  '476.  charitable',
#  '477.  charmed',
#  '478.  charming',
#  '479.  chattering',
#  '480.  chatting',
#  '481.  chatty   1',
#  '482.  chauvinistic',
#  '483.  cheap   1',
#  '484.  cheapest',
#  '485.  cheeky   1',
#  '486.  cheerful',
#  '487.  cheering',
#  '488.  cheerless',
#  '489.  cheery   1',
#  '490.  chemical   3',
#  '491.  chewable',
#  '492.  chewy',
#  '493.  chic',
#  '494.  chicken   3',
#  '495.  chief',
#  '496.  childish',
#  '497.  childlike',
#  '498.  chilling',
#  '499.  chilly   1',
#  '500.  chivalrous',
#  '501.  choice   1',
#  '502.  choking',
#  '503.  choppy   1',
#  '504.  chronological',
#  '505.  chubby   1',
#  '506.  chuckling',
#  '507.  chunky   1',
#  '508.  cinematic',
#  '509.  circling',
#  '510.  circular',
#  '511.  circumstantial',
#  '512.  civil',
#  '513.  civilian',
#  '514.  civilized',
#  '515.  clammy   1',
#  '516.  clamoring',
#  '517.  clandestine',
#  '518.  clanging',
#  '519.  clapping',
#  '520.  clashing',
#  '521.  classic',
#  '522.  classical',
#  '523.  classifiable',
#  '524.  classified',
#  '525.  classy   1',
#  '526.  clean   1',
#  '527.  cleanable',
#  '528.  clear   1',
#  '529.  cleared',
#  '530.  clearheaded',
#  '531.  clever   1',
#  '532.  climatic',
#  '533.  climbable',
#  '534.  clinging',
#  '535.  clingy',
#  '536.  clinical',
#  '537.  cliquish',
#  '538.  clogged',
#  '539.  cloistered',
#  '540.  close   1',
#  '541.  closeable',
#  '542.  closed',
#  '543.  close-minded',
#  '544.  cloudless',
#  '545.  cloudy   1',
#  '546.  clownish',
#  '547.  clueless',
#  '548.  clumsy   1',
#  '549.  cluttered',
#  '550.  coachable',
#  '551.  coarse   1',
#  '552.  cockamamie',
#  '553.  cocky',
#  '554.  codified',
#  '555.  coercive',
#  '556.  cognitive',
#  '557.  coherent',
#  '558.  cohesive',
#  '559.  coincidental',
#  '560.  cold   1',
#  '561.  coldhearted',
#  '562.  collaborative',
#  '563.  collapsed',
#  '564.  collapsing',
#  '565.  collectable',
#  '566.  collegial',
#  '567.  colloquial',
#  '568.  colonial',
#  '569.  colorful',
#  '570.  colorless',
#  '571.  colossal',
#  '572.  combative',
#  '573.  combined',
#  '574.  comfortable',
#  '575.  comforted',
#  '576.  comforting',
#  '577.  comical',
#  '578.  commanding',
#  '579.  commemorative',
#  '580.  commendable',
#  '581.  commercial',
#  '582.  committed',
#  '583.  common',
#  '584.  communal',
#  '585.  communicable',
#  '586.  communicative',
#  '587.  communist',
#  '588.  compact',
#  '589.  comparable',
#  '590.  comparative',
#  '591.  compassionate',
#  '592.  compelling',
#  '593.  competent',
#  '594.  competitive',
#  '595.  complacent',
#  '596.  complaining',
#  '597.  complete',
#  '598.  completed',
#  '599.  complex',
#  '600.  compliant',
#  '601.  complicated',
#  '602.  complimentary',
#  '603.  compound',
#  '604.  comprehensive',
#  '605.  compulsive',
#  '606.  compulsory',
#  '607.  computer   3',
#  '608.  computerized',
#  '609.  concealable',
#  '610.  concealed',
#  '611.  conceited',
#  '612.  conceivable',
#  '613.  concerned',
#  '614.  concerning',
#  '615.  concerted',
#  '616.  concise',
#  '617.  concurrent',
#  '618.  condemned',
#  '619.  condensed',
#  '620.  condescending',
#  '621.  conditional',
#  '622.  confident',
#  '623.  confidential',
#  '624.  confirmable',
#  '625.  confirmed',
#  '626.  conflicted',
#  '627.  conflicting',
#  '628.  conformable',
#  '629.  confounded',
#  '630.  confused',
#  '631.  confusing',
#  '632.  congenial',
#  '633.  congested',
#  '634.  congressional',
#  '635.  congruent',
#  '636.  congruous',
#  '637.  connectable',
#  '638.  connected',
#  '639.  connecting',
#  '640.  connective',
#  '641.  conscientious',
#  '642.  conscious',
#  '643.  consecutive',
#  '644.  consensual',
#  '645.  consenting',
#  '646.  conservative',
#  '647.  considerable',
#  '648.  considerate',
#  '649.  consistent',
#  '650.  consoling',
#  '651.  conspicuous',
#  '652.  conspiratorial',
#  '653.  constant',
#  '654.  constitutional',
#  '655.  constrictive',
#  '656.  constructive',
#  '657.  consumable',
#  '658.  consummate',
#  '659.  contagious',
#  '660.  containable',
#  '661.  contemplative',
#  '662.  contemporary',
#  '663.  contemptible',
#  '664.  contemptuous',
#  '665.  content',
#  '666.  contented',
#  '667.  contentious',
#  '668.  contextual',
#  '669.  continual',
#  '670.  continuing',
#  '671.  continuous',
#  '672.  contoured',
#  '673.  contractual',
#  '674.  contradicting',
#  '675.  contradictory',
#  '676.  contrarian',
#  '677.  contrary',
#  '678.  contributive',
#  '679.  contrite',
#  '680.  controllable',
#  '681.  controlling',
#  '682.  controversial',
#  '683.  convenient',
#  '684.  conventional',
#  '685.  conversational',
#  '686.  convinced',
#  '687.  convincing',
#  '688.  convoluted',
#  '689.  convulsive',
#  '690.  cooing',
#  '691.  cooked',
#  '692.  cool   1',
#  '693.  coolest',
#  '694.  cooperative',
#  '695.  coordinated',
#  '696.  copious',
#  '697.  coquettish',
#  '698.  cordial',
#  '699.  corner   3',
#  '700.  cornered',
#  '701.  corny   1',
#  '702.  corporate',
#  '703.  corpulent',
#  '704.  correct',
#  '705.  correctable',
#  '706.  corrective',
#  '707.  corresponding',
#  '708.  corrosive',
#  '709.  corrupt',
#  '710.  corrupting',
#  '711.  corruptive',
#  '712.  cosmetic',
#  '713.  cosmic',
#  '714.  costly',
#  '715.  cottony',
#  '716.  coughing',
#  '717.  courageous',
#  '718.  courteous',
#  '719.  covert',
#  '720.  coveted',
#  '721.  cowardly',
#  '722.  cowering',
#  '723.  coy',
#  '724.  cozy   1',
#  '725.  crabby   1',
#  '726.  cracked',
#  '727.  crackling',
#  '728.  crafty   1',
#  '729.  craggy',
#  '730.  crammed',
#  '731.  cramped',
#  '732.  cranky   1',
#  '733.  crashing',
#  '734.  crass',
#  '735.  craven',
#  '736.  crawling',
#  '737.  crazy   1',
#  '738.  creaking',
#  '739.  creaky   1',
#  '740.  creamy   1',
#  '741.  creative',
#  '742.  credible',
#  '743.  creeping',
#  '744.  creepy   1',
#  '745.  crestfallen',
#  '746.  criminal',
#  '747.  crippled',
#  '748.  crippling',
#  '749.  crisp   1',
#  '750.  crispy   1',
#  '751.  critical',
#  '752.  crooked',
#  '753.  cropped',
#  '754.  cross',
#  '755.  crossed',
#  '756.  crotchety',
#  '757.  crowded',
#  '758.  crucial',
#  '759.  crude   1',
#  '760.  cruel   1',
#  '761.  crumbling',
#  '762.  crumbly   1',
#  '763.  crumply',
#  '764.  crunchable',
#  '765.  crunching',
#  '766.  crunchy   1',
#  '767.  crushable',
#  '768.  crushed',
#  '769.  crusty   1',
#  '770.  crying',
#  '771.  cryptic',
#  '772.  crystalline',
#  '773.  crystallized',
#  '774.  cuddly   1',
#  '775.  culpable',
#  '776.  cultural',
#  '777.  cultured',
#  '778.  cumbersome',
#  '779.  cumulative',
#  '780.  cunning',
#  '781.  curable',
#  '782.  curative',
#  '783.  curious',
#  '784.  curly   1',
#  '785.  current',
#  '786.  cursed',
#  '787.  curt',
#  '788.  curved',
#  '789.  curvy',
#  '790.  customary',
#  '791.  cut',
#  '792.  cute   1',
#  '793.  cutting',
#  '794.  cylindrical',
#  '795.  cynical',
#  '796.  daffy   1',
#  '797.  daft',
#  '798.  daily',
#  '799.  dainty   1',
#  '800.  damaged',
#  '801.  damaging',
#  '802.  damp   1',
#  '803.  danceable',
#  '804.  dandy   1',
#  '805.  dangerous',
#  '806.  dapper',
#  '807.  daring',
#  '808.  dark   1',
#  '809.  darkened',
#  '810.  dashing',
#  '811.  daughterly',
#  '812.  daunting',
#  '813.  dawdling',
#  '814.  day   3',
#  '815.  dazed',
#  '816.  dazzling',
#  '817.  dead',
#  '818.  deadly   1',
#  '819.  deadpan',
#  '820.  deaf',
#  '821.  deafening',
#  '822.  dear   1',
#  '823.  debatable',
#  '824.  debonair',
#  '825.  decadent',
#  '826.  decayed',
#  '827.  decaying',
#  '828.  deceitful',
#  '829.  deceivable',
#  '830.  deceiving',
#  '831.  decent',
#  '832.  decentralized',
#  '833.  deceptive',
#  '834.  decimated',
#  '835.  decipherable',
#  '836.  decisive',
#  '837.  declining',
#  '838.  decorative',
#  '839.  decorous',
#  '840.  decreasing',
#  '841.  decrepit',
#  '842.  dedicated',
#  '843.  deep   1',
#  '844.  deepening',
#  '845.  deeply',
#  '846.  defeated',
#  '847.  defective',
#  '848.  defendable',
#  '849.  defenseless',
#  '850.  defensible',
#  '851.  defensive',
#  '852.  defiant',
#  '853.  deficient',
#  '854.  definable',
#  '855.  definitive',
#  '856.  deformed',
#  '857.  degenerative',
#  '858.  degraded',
#  '859.  dehydrated',
#  '860.  dejected',
#  '861.  delectable',
#  '862.  deliberate',
#  '863.  deliberative',
#  '864.  delicate',
#  '865.  delicious',
#  '866.  delighted',
#  '867.  delightful',
#  '868.  delinquent',
#  '869.  delirious',
#  '870.  deliverable',
#  '871.  deluded',
#  '872.  demanding',
#  '873.  demented',
#  '874.  democratic',
#  '875.  demonic',
#  '876.  demonstrative',
#  '877.  demure',
#  '878.  deniable',
#  '879.  dense   1',
#  '880.  dependable',
#  '881.  dependent',
#  '882.  deplorable',
#  '883.  deploring',
#  '884.  depraved',
#  '885.  depressed',
#  '886.  depressing',
#  '887.  depressive',
#  '888.  deprived',
#  '889.  deranged',
#  '890.  derivative',
#  '891.  derogative',
#  '892.  derogatory',
#  '893.  descriptive',
#  '894.  deserted',
#  '895.  designer   3',
#  '896.  desirable',
#  '897.  desirous',
#  '898.  desolate',
#  '899.  despairing',
#  '900.  desperate',
#  '901.  despicable',
#  '902.  despised',
#  '903.  despondent',
#  '904.  destroyed',
#  '905.  destructive',
#  '906.  detachable',
#  '907.  detached',
#  '908.  detailed',
#  '909.  detectable',
#  '910.  determined',
#  '911.  detestable',
#  '912.  detrimental',
#  '913.  devastated',
#  '914.  devastating',
#  '915.  devious',
#  '916.  devoted',
#  '917.  devout',
#  '918.  dexterous',
#  '919.  diabolical',
#  '920.  diagonal',
#  '921.  didactic',
#  '922.  different',
#  '923.  difficult',
#  '924.  diffuse',
#  '925.  digestive',
#  '926.  digital',
#  '927.  dignified',
#  '928.  digressive',
#  '929.  dilapidated',
#  '930.  diligent',
#  '931.  dim',
#  '932.  diminishing',
#  '933.  diminutive',
#  '934.  dingy   1',
#  '935.  diplomatic',
#  '936.  dire',
#  '937.  direct',
#  '938.  direful',
#  '939.  dirty   1',
#  '940.  disabled',
#  '941.  disadvantaged',
#  '942.  disadvantageous',
#  '943.  disaffected',
#  '944.  disagreeable',
#  '945.  disappearing',
#  '946.  disappointed',
#  '947.  disappointing',
#  '948.  disapproving',
#  '949.  disarming',
#  '950.  disastrous',
#  '951.  discarded',
#  '952.  discernable',
#  '953.  disciplined',
#  '954.  disconnected',
#  '955.  discontented',
#  '956.  discordant',
#  '957.  discouraged',
#  '958.  discouraging',
#  '959.  discourteous',
#  '960.  discredited',
#  '961.  discreet',
#  '962.  discriminating',
#  '963.  discriminatory',
#  '964.  discussable',
#  '965.  disdainful',
#  '966.  diseased',
#  '967.  disenchanted',
#  '968.  disgraceful',
#  '969.  disgruntled',
#  '970.  disgusted',
#  '971.  disgusting',
#  '972.  disheartened',
#  '973.  disheartening',
#  '974.  dishonest',
#  '975.  dishonorable',
#  '976.  disillusioned',
#  '977.  disinclined',
#  '978.  disingenuous',
#  '979.  disinterested',
#  '980.  disjointed',
#  '981.  dislikeable',
#  '982.  disliked',
#  '983.  disloyal',
#  '984.  dismal',
#  '985.  dismissive',
#  '986.  disobedient',
#  '987.  disorderly',
#  '988.  disorganized',
#  '989.  disparaging',
#  '990.  disparate',
#  '991.  dispassionate',
#  '992.  dispensable',
#  '993.  displaced',
#  '994.  displeased',
#  '995.  displeasing',
#  '996.  disposable',
#  '997.  disproportionate',
#  ...]

# %%
list_of_adjectives = []
banned_words = ['the', 'a', 'an', 'its', 'that', 'this', 'my', 'what', 'any', 'their', 'these', 'his', 'her',
                'game', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten']
for i in range(len(words_4800)):
    if len(words_4800[i]) > 0:
        cur_word = words_4800[i].split()[1]
        if cur_word not in banned_words:
            list_of_adjectives.append(cur_word)

np.savetxt("Data/list_of_adjectives.txt", list_of_adjectives, delimiter=",", fmt='%s')

# %%
# Positive words
with open('words-to-use-pos.txt', 'r') as f:
    w2u_pos = [line.strip() for line in f]

oliver_pos = ['absolutely','accepted','acclaimed','accomplish','accomplishment','achievement','action','active','admire','adorable','adventure','affirmative','affluent','agree','agreeable','amazing','angelic','appealing','approve','aptitude','attractive','awesome','beaming','beautiful','believe','beneficial','bliss','bountiful','bounty','brave','bravo','brilliant','bubbly','calm','celebrated','certain','champ','champion','charming','cheery','choice','classic','classical','clean','commend','composed','congratulation','constant','cool','courageous','creative','cute','dazzling','delight','delightful','distinguished','divine','earnest','easy','ecstatic','effective','effervescent','efficient','effortless','electrifying','elegant','enchanting','encouraging','endorsed','energetic','energized','engaging','enthusiastic','essential','esteemed','ethical','excellent','exciting','exquisite','fabulous','fair','familiar','famous','fantastic','favorable','fetching','fine','fitting','flourishing','fortunate','free','fresh','friendly','fun','funny','generous','genius','genuine','giving','glamorous','glowing','good','gorgeous','graceful','great','green','grin','growing','handsome','happy','harmonious','healing','healthy','hearty','heavenly','honest','honorable','honored','hug','idea','ideal','imaginative','imagine','impressive','independent','innovate','innovative','instant','instantaneous','instinctive','intellectual','intelligent','intuitive','inventive','jovial','joy','jubilant','keen','kind','knowing','knowledgeable','laugh','learned','legendary','light','lively','lovely','lucid','lucky','luminous','marvelous','masterful','meaningful','merit','meritorious','miraculous','motivating','moving','natural','nice','novel','now','nurturing','nutritious','okay','one','open','optimistic','paradise','perfect','phenomenal','pleasant','pleasurable','plentiful','poised','polished','popular','positive','powerful','prepared','pretty','principled','productive','progress','prominent','protected','proud','quality','quick','quiet','ready','reassuring','refined','refreshing','rejoice','reliable','remarkable','resounding','respected','restored','reward','rewarding','right','robust','safe','satisfactory','secure','seemly','simple','skilled','skillful','smile','soulful','sparkling','special','spirited','spiritual','stirring','stunning','stupendous','successsuccessful','sunny','super','superb','supporting','surprising','terrific','thorough','thrilling','thriving','tops','tranquil','transformative','transforming','trusting','truthful','unreal','unwavering','up','upbeat','upright','upstanding','valued','vibrant','victorious','victory','vigorous','virtuous','vital','vivacious','wealthy','welcome','well','whole','wholesome','willing','wonderful','wondrous','worthy','wow','yes','yummy','zeal','zealous']
    
combined_pos = list(np.unique(w2u_pos+oliver_pos))

np.savetxt("Data/positive_adjectives.txt", combined_pos, delimiter=",", fmt='%s')

# Negative words 

with open('words-to-use-neg.txt', 'r') as f:
    w2u_neg = [line.strip() for line in f]
    
oliver_neg = ['abysmal','adverse','alarming','angry','annoy','anxious','apathy','appalling','atrocious','awful','bad','banal','barbed','belligerent','bemoan','beneath','boring','broken','callous','clumsy','coarse','cold','cold','hearted','collapse','confused','contradictory','contrary','corrosive','corrupt','crazy','creepy','criminal','cruel','cry','cutting','damage','damaging','dastardly','dead','decaying','deformed','deny','deplorable','depressed','deprived','despicable','detrimental','dirty','disease','disgusting','disheveled','dishonest','dishonorable','dismal','distress','dreadful','dreary','enraged','eroding','evil','fail','faulty','fear','feeble','fight','filthy','foul','frighten','frightful','gawky','ghastly','grave','greed','grim','grimace','gross','grotesque','gruesome','guilty','haggard','hard','hard','hearted','harmful','hate','hideous','homely','horrendous','horrible','hostile','hurt','hurtful','icky','ignorant','ignore','ill','immature','imperfect','impossible','inane','inelegant','infernal','injure','injurious','insane','insidious','insipid','jealous','junky','lose','lousy','lumpy','malicious','mean','menacing','messy','misshapen','missing','misunderstood','moan','moldy','monstrous','naive','nasty','naughty','negate','negative','never','no','nobody','nondescript','nonsense','not','noxious','objectionable','odious','offensive','old','oppressive','pain','perturb','pessimistic','petty','plain','poisonous','poor','prejudice','questionable','quirky','quit','reject','renege','repellant','reptilian','repugnant','repulsive','revenge','revolting','rocky','rotten','rude','ruthless','sad','savage','scare','scary','scream','severe','shocking','shoddy','sick','sickening','sinister','slimy','smelly','sobbing','sorry','spiteful','sticky','stinky','stormy','stressful','stuck','stupid','substandard','suspect','suspicious','tense','terrible','terrifying','threatening','ugly','undermine','unfair','unfavorable','unhappy','unhealthy','unjust','unlucky','unpleasant','unsatisfactory','unsightly','untoward','unwanted','unwelcome','unwholesome','unwieldy','unwise','upset','vice','vicious','vile','villainous','vindictive','wary','weary','wicked','woeful','worthless','wound','yell','yucky','zero']

combined_neg = np.unique(w2u_neg+oliver_neg)

np.savetxt("Data/negative_adjectives.txt", combined_neg, delimiter=",", fmt='%s')

# %%
# Removing the words not in the adjective list from the review words
filtered_review_words = []
for word in review_words:
    if word in list_of_adjectives:
        filtered_review_words.append(word)
' '.join(filtered_review_words)
# Out:
# 'silver medium more other studied hard explosive most more more each successive more evocative explosive natural expanded huge few vital huge choice only hilarious much dizzying overwhelming down pressing destroyed only extreme only down combined right breathtaking constant combined wrong incredible hilarious random open gold moved better inherent productive clever funny possible just open enough different pretty flying nearby protective general both moving certain which fit stale some new different more time more elaborate same some better still normal engaging well every many main clever possible open more other clever incredible still just more memorable specialized well same time still extreme great either specific another random variable impressive every which impressive outside just fun open right refreshing complete utter specific more relaxed other either long certain open weak fictional evil ludicrous goofy past compelling funny simple easy moving decent separate each completed time only beginning all left right choice choice worse more notorious broken time stable most only few short odd lead some visual most poor promised better just general even long seamless other dense easy which helpful many technical complete other quality life more pleasant overall better enough natural embarrassing flexible most only pretend even down poor giving total flattering cinematic highest digital new fun new next top famous just much fun forward just new even more plus good well short resounding pretty simple main much new still better down those some fun pretty much much which more involved least even free complete specific top expansive home pretty much all fun both down treacherous mountain challenging well worth time busy well some just either top moving pretty cool still rewarding just marked red just just more most likely most fun basic awesome sure best different most which other another more explosive each other good fun trying just fun little ominous bad other just big some visual sheer destructive some time fun sure more giving latest very first mission tired right final mission first total down flat all down work full awake first down first objective whole down only old all restored full tired only down those close no gaping just second more just few second mission later all last new long involved those some distinct following giving massive every even minimal those minor significant long near stingy our choice few available next free significant quality life more whole moving rich other work little less well open revolutionary forward time able front full which other which soaring various breathtaking swooping close pretty many opening just blurred no jarring moved modern useless good just few warning another exposed good engaging wrong more another some reliable knowing no no either reliable few pretty hard only all much even less some easy own critical terrible other infuriating many leading down useless double same time suffering occasional mission trying even more friendly just many next still minor irksome major seamless open fast other little low big some some no longer just some private time top silly goofy lead main all logical next wise just busy trying right pretty obvious top some indiscriminate just next new no high flying just real precise bad well each primary easy even down easy intuitive only well well time fun time plane plane small low hanging fast blazing past background abrupt fast time those fast blurry some technical seamless open final mission last very both main much day far perfect silly fun open artificial most enjoyable no choice more all much little more major more just another major true just more just more real just inviting entire own mother fateful day happy least flimsy those more time mother fateful day happy least flimsy those more time shattering condensed single most outrageous most explosive fourth time very real former late latter endless previous primary used expedient convenient di ...
