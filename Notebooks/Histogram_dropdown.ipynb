# %%
from plotly.offline import init_notebook_mode, iplot
from IPython.display import display, HTML
from plotly.graph_objs import Histogram as H
import plotly.graph_objs as go
import pandas as pd
import numpy as np
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
# RUN THIS
# Load data about games
meta_games = pd.read_csv('../Data/extra_details_complete.csv')

# make new year column and replace tbd values with np.nans
meta_games['year'] = np.nan
meta_games.replace('tbd', np.nan)

# enter year value from date column
for i, row in meta_games.iterrows():
    year_value = meta_games['date'][i].split(',')[1].strip()
    meta_games.at[i, 'year'] = int(year_value)

# make a dict of meta_game dataframes for each year from 2000 to 2019 #irrelevant
#meta_games_years=[]
#for i in range(2000, 2019):
#    meta_games_years[i] = meta_games[(meta_games['year'] == i)]

# remove tbd and replace with nan
meta_games = meta_games.replace('tbd', np.nan)

# make dict for consoles
console_dict = {}
for console in np.unique(meta_games['console']):
    console_dict[console] = meta_games[(meta_games['console'] == console)]

# make dict for publishers
pub_dict = {}
for pub in np.unique(meta_games['publisher']):
    all_by_pub = meta_games[(meta_games['publisher'] == pub)]
    if len(all_by_pub) > 20:  # only pubs with 20 games
        pub_dict[pub] = meta_games[(meta_games['publisher'] == pub)]
    # remove ' ' empty string from pub names
pub_dict.pop(' ', None)

# make dict for devs
dev_dict = {}
for dev in np.unique(meta_games['developer']):
    all_by_dev = meta_games[(meta_games['developer'] == dev)]
    if len(all_by_dev) > 20:  # only devs with 20 games
        dev_dict[dev] = meta_games[(meta_games['developer'] == dev)]
dev_dict.pop(' ', None)

# make dict for genre
genre_dict = {}
for genre in np.unique(meta_games['genre(s)']):
    all_by_genre = meta_games[(meta_games['genre(s)'] == genre)]
    if len(all_by_genre) > 100:  # only genre with 20 games
        genre_dict[genre] = meta_games[(meta_games['genre(s)'] == genre)]
genre_dict.pop(' ', None)

# remove wrong pc and vita console
del console_dict[' PC']
del console_dict[' VITA']

# %%
import plotly.plotly as py
import plotly.graph_objs as go
from datetime import datetime
import pandas as pd

# make a user on plotly - add username and generated new api key
import plotly
plotly.tools.set_credentials_file(username='thomasnicolet', api_key='ln0vpFkn0fVIxOkBwpnL')

# Plots histogram with dropdown menus for console, publisher, developer and genre

# make data traces of metascore, one for each console, make data a list of these hist traces.
data_console = []
for console in console_dict:
    console_metatrace = go.Histogram(
        x=console_dict[console]['metascore'],
        ##ADD/REMOVE HISTNORM FOR NORMALISING
        histnorm='percent',
        name='metascore',
        xbins=dict(
            start=0,
            end=100,
            size=5
        ),
        marker=dict(
            color='#8181F7',
        ),
        opacity=0.75
    )
    console_usertrace = go.Histogram(
        x=console_dict[console]['userscore'].astype(float) * 10,
        ##ADD/REMOVE HISTNORM FOR NORMALISING
        histnorm='percent',
        name='userscore',
        xbins=dict(
            start=0,
            end=100,
            size=5
        ),
        marker=dict(
            color='#FFD7E9',
        ),
        opacity=0.75
    )
    data_console.append(console_metatrace)
    data_console.append(console_usertrace)

#### publisher data trace
data_pub = []
for pub in pub_dict:
    pub_metatrace = go.Histogram(
        x=pub_dict[pub]['metascore'],
        ##ADD/REMOVE HISTNORM FOR NORMALISING
        histnorm='percent',
        name='metascore',
        xbins=dict(
            start=0,
            end=100,
            size=5
        ),
        marker=dict(
            color='#8181F7',
        ),
        opacity=0.75
    )
    pub_usertrace = go.Histogram(
        x=pub_dict[pub]['userscore'].astype(float) * 10,
        ##ADD/REMOVE HISTNORM FOR NORMALISING
        histnorm='percent',
        name='userscore',
        xbins=dict(
            start=0,
            end=100,
            size=5
        ),
        marker=dict(
            color='#FFD7E9',
        ),
        opacity=0.75
    )
    data_pub.append(pub_metatrace)
    data_pub.append(pub_usertrace)

####Making dev traces
data_dev = []
for dev in dev_dict:
    dev_metatrace = go.Histogram(
        x=dev_dict[dev]['metascore'],
        ##ADD/REMOVE HISTNORM FOR NORMALISING
        histnorm='percent',
        name='metascore',
        xbins=dict(
            start=0,
            end=100,
            size=5
        ),
        marker=dict(
            color='#8181F7',
        ),
        opacity=0.75
    )
    dev_usertrace = go.Histogram(
        x=dev_dict[dev]['userscore'].astype(float) * 10,
        ##ADD/REMOVE HISTNORM FOR NORMALISING
        histnorm='percent',
        name='userscore',
        xbins=dict(
            start=0,
            end=100,
            size=5
        ),
        marker=dict(
            color='#FFD7E9',
        ),
        opacity=0.75
    )
    data_dev.append(dev_metatrace)
    data_dev.append(dev_usertrace)

# make data trace for genre
data_genre = []
for genre in genre_dict:
    genre_metatrace = go.Histogram(
        x=genre_dict[genre]['metascore'],
        ##ADD/REMOVE HISTNORM FOR NORMALISING
        histnorm='percent',
        name='metascore',
        xbins=dict(
            start=0,
            end=100,
            size=5
        ),
        marker=dict(
            color='#8181F7',
        ),
        opacity=0.75
    )
    genre_usertrace = go.Histogram(
        x=genre_dict[genre]['userscore'].astype(float) * 10,
        ##ADD/REMOVE HISTNORM FOR NORMALISING
        histnorm='percent',
        name='userscore',
        xbins=dict(
            start=0,
            end=100,
            size=5
        ),
        marker=dict(
            color='#FFD7E9',
        ),
        opacity=0.75
    )
    data_genre.append(genre_metatrace)
    data_genre.append(genre_usertrace)

### make a list with all lists of data traces
total_data = data_console + data_pub + data_dev + data_genre

# Irrelevant now
# make list of lists of bools, e.g. [True, True, False, False], [False, False, True, True]
# used in args within buttons.
# Only makes individual bool lists for single parameters
# console_bool_list1 = []
# for i in range(0, len(console_dict)*2, 2):
#    temp = [False]*(len(console_dict)*2)
#    temp[i] = True
#    temp[i+1] = True
#    console_bool_list1.append(temp)
#
####
# pub_bool_list1 = []
# for i in range(0, len(pub_dict)*2, 2):
#    temp = [False]*(len(pub_dict)*2)
#    temp[i] = True
#    temp[i+1] = True
#    pub_bool_list1.append(temp)
####


### big bool list for all data values
# big_bool list is length of all data traces
empty_big_bool = len(total_data) * [False]
big_bool = []
for i in range(0, len(total_data), 2):
    temp_big_bool = len(total_data) * [False]
    temp_big_bool[i] = True
    temp_big_bool[i + 1] = True
    big_bool.append(temp_big_bool)

###
# making list of dictionaries to be used as argument for buttons in updatemenus
buttons_console_list = []
for i in list(range(0, len(console_dict))):
    temp_list = dict(label=list(console_dict)[i],
                     method='update',
                     args=[{'visible': big_bool[0:len(console_dict)][i]},
                           {'title': list(console_dict)[i]}])
    buttons_console_list.append(temp_list)

#### publisher
buttons_pub_list = []
for i in list(range(0, len(pub_dict))):
    temp_list = dict(label=list(pub_dict)[i],
                     method='update',
                     args=[{'visible': big_bool[len(console_dict):len(console_dict) + len(pub_dict)][i]},
                           {'title': list(pub_dict)[i]}])
    buttons_pub_list.append(temp_list)

### developer
buttons_dev_list = []
for i in list(range(0, len(dev_dict))):
    temp_list = dict(label=list(dev_dict)[i],
                     method='update',
                     args=[{'visible': big_bool[
                                       len(console_dict) + len(pub_dict):len(console_dict) + len(pub_dict) + len(
                                           dev_dict)][i]},
                           {'title': list(dev_dict)[i]}])
    buttons_dev_list.append(temp_list)

# genre
buttons_genre_list = []
for i in list(range(0, len(genre_dict))):
    temp_list = dict(label=list(genre_dict)[i],
                     method='update',
                     args=[{'visible': big_bool[len(console_dict) + len(pub_dict) + len(dev_dict):][i]},
                           {'title': list(dev_dict)[i]}])
    buttons_genre_list.append(temp_list)
###

# make update menus. buttons is made up of buttons_list, i.e. list of dictionaries containing label, method, args and title.
# args variable determines when what is being shown, e.g. [True, False False... False] means first is being shown only
button_layer_1_height = 1.12
updatemenus = list([
    dict(
        active=0,
        buttons=buttons_console_list,
        name='Console',
        direction='down',
        pad={'r': 10, 't': 10},
        showactive=True,
        x=0,
        xanchor='left',
        y=button_layer_1_height,
        yanchor='top'
    ),
    dict(
        active=0,
        buttons=buttons_pub_list,
        name='Publisher',
        direction='down',
        pad={'r': 10, 't': 10},
        showactive=True,
        x=0.1,
        xanchor='left',
        y=button_layer_1_height,
        yanchor='top'
    ),
    dict(
        active=1,
        buttons=buttons_dev_list,
        name='Developer',
        direction='down',
        pad={'r': 10, 't': 10},
        showactive=True,
        x=0.35,
        xanchor='left',
        y=button_layer_1_height,
        yanchor='top'
    ),
    dict(
        active=2,
        buttons=buttons_genre_list,
        name='Developer',
        direction='down',
        pad={'r': 10, 't': 10},
        showactive=True,
        x=0.755,
        xanchor='left',
        y=button_layer_1_height,
        yanchor='top'
    )
])

# set layout
layout = dict(title='Userscores and metascores across platform, publisher, developer and genre',
              showlegend=False,
              yaxis=dict(
                  range=[0, 40],
                  title='Count'
              ),
              xaxis=dict(
                  range=[0, 100],
                  title='Userscore and metascores'
              ),
              updatemenus=updatemenus)
# plot figure
fig = dict(data=total_data, layout=layout)
py.iplot(fig, filename='update_dropdown')

# %%
#DONT RUN BELOW THIS - SUPERFLUOUS NOTES
#data wrangling testing
#making data traces for consoles, both meta and user
data_test=[]
for console in console_dict:
    console_metatrace = go.Histogram(
                x=console_dict[console]['metascore'],
            histnorm='percent',
            name='metascore for '+str(console),
            xbins=dict(
            start=0,
            end=100,
            size=5
            ),
            marker=dict(
            color='#FFD7E9',
            ),
            opacity=0.75
    )
    console_usertrace = go.Histogram(
                x=console_dict[console]['userscore'].astype(float)*10,
            histnorm='percent',
            name='userscore for '+str(console),
            xbins=dict(
            start=0,
            end=100,
            size=5
            ),
            marker=dict(
            color='#FFD7E9',
            ),
            opacity=0.75
    )
    data_test.append(console_metatrace)
    data_test.append(console_usertrace)
    
#make a list of lists of bools. as data list consists of [DS_meta, DS_user, PC_meta, PC_user],
#bool list consists of [[true, true, false, false], [false, false, true, true]]
console_bool_list1 = []
for i in range(0, len(console_dict)*2, 2):
    temp = [False]*(len(console_dict)*2)
    temp[i] = True
    temp[i+1] = True
    console_bool_list1.append(temp)
    
len(console_bool_list1)
#data_test

console_bool_listtest = []
for i in range(0,len(console_dict)):
    temp = [False]*len(console_dict)
    temp[i] = True
    console_bool_listtest.append(temp)
len(console_bool_list)

# %%
# annotations from original code from example
high_annotations=[dict(x='2016-03-01',
                       y=df.High.mean(),
                       xref='x', yref='y',
                       text='High Average:<br>'+str(df.High.mean()),
                       ax=0, ay=-40),
                  dict(x=df.High.idxmax(),
                       y=df.High.max(),
                       xref='x', yref='y',
                       text='High Max:<br>'+str(df.High.max()),
                       ax=0, ay=-40)]
low_annotations=[dict(x='2015-05-01',
                      y=df.Low.mean(),
                      xref='x', yref='y',
                      text='Low Average:<br>'+str(df.Low.mean()),
                      ax=0, ay=40),
                 dict(x=df.High.idxmin(),
                      y=df.Low.min(),
                      xref='x', yref='y',
                      text='Low Min:<br>'+str(df.Low.min()),
                      ax=0, ay=40)]

# %%
dev_dict['Blizzard Entertainment']
# Out:
#       Unnamed: 0  metascore                                            name  \
# 44            44         87                                      Diablo III
# 57            57         86                Starcraft II: Heart of the Swarm
# 64            64         86                                      Diablo III
# 75            75         90               Diablo III: Ultimate Evil Edition
# 108          108         88                 Hearthstone: Heroes of Warcraft
# 126          126         87                     Diablo III: Reaper of Souls
# 129          129         87          World of Warcraft: Warlords of Draenor
# 143          143         86               Diablo III: Ultimate Evil Edition
# 177          177         84                 Hearthstone: Goblins Vs. Gnomes
# 293          293         91                                       Overwatch
# 294          294         91                                       Overwatch
# 298          298         90                                       Overwatch
# 374          374         88                       World of Warcraft: Legion
# 567          567         85           Hearthstone: Whispers of the Old Gods
# 588          588         88                Starcraft II: Legacy of the Void
# 642          642         88                                      Diablo III
# 692          692         85                            Starcraft Remastered
# 701          701         86                             Heroes of the Storm
# 771          771         93                  Starcraft II: Wings of Liberty
# 785          785         84               Hearthstone: The Grand Tournament
# 801          801         90                    World of Warcraft: Cataclysm
# 1202        1202         91          World of Warcraft: The Burning Crusade
# 1315        1315         91       World of Warcraft: Wrath of the Lich King
# 1507        1507         93                               World of Warcraft
# 1769        1769         88                 Warcraft III: The Frozen Throne
# 2312        2312         92                    Warcraft III: Reign of Chaos
# 2622        2622         82                 Hearthstone: Blackrock Mountain
# 2746        2746         82            World of Warcraft: Mists of Pandaria
# 3520        3520         79           World of Warcraft: Battle for Azeroth
# 3957        3957         78                 Hearthstone: Curse of Naxxramas
# 4699        4699         79                 Hearthstone: Journey to Un'Goro
# 7140        7140         73  StarCraft II: Nova Covert Ops - Mission Pack 1
# 7700        7700         76             Diablo III: Rise of the Necromancer
#
#      console userscore          date  \
# 44      X360       6.7   Sep 3, 2013
# 57        PC       7.9  Mar 12, 2013
# 64       PS3       6.4   Sep 3, 2013
# 75       PS4         8  Aug 19, 2014
# 108       PC       6.1  Mar 11, 2014
# 126       PC       6.6  Mar 25, 2014
# 129       PC       5.9  Nov 13, 2014
# 143     XONE       7.8  Aug 19, 2014
# 177       PC       6.2   Dec 8, 2014
# 293       PC       6.7  May 23, 2016
# 294     XONE       5.8  May 23, 2016
# 298      PS4       6.3  May 23, 2016
# 374       PC       7.3  Aug 30, 2016
# 567       PC       5.4  Apr 26, 2016
# 588       PC       8.3  Nov 10, 2015
# 642       PC       4.1  May 15, 2012
# 692       PC       7.8  Aug 14, 2017
# 701       PC       6.5   Jun 2, 2015
# 771       PC       8.2  Jul 27, 2010
# 785       PC       4.1  Aug 24, 2015
# 801       PC       5.6   Dec 7, 2010
# 1202      PC         8  Jan 16, 2007
# 1315      PC       7.6  Nov 13, 2008
# 1507      PC       7.3  Nov 23, 2004
# 1769      PC         9   Jul 1, 2003
# 2312      PC       9.1   Jul 3, 2002
# 2622      PC         6   Apr 2, 2015
# 2746      PC         5  Sep 25, 2012
# 3520      PC       3.1  Aug 13, 2018
# 3957      PC       6.5  Jul 22, 2014
# 4699      PC       4.4   Apr 6, 2017
# 7140      PC       7.1  Mar 29, 2016
# 7700      PC       4.8  Jun 27, 2017
#
#                                                genre(s)  \
# 44                             Action RPG, Role-Playing
# 57                 Command, Real-Time, Sci-Fi, Strategy
# 64                             Action RPG, Role-Playing
# 75                             Action RPG, Role-Playing
# 108    Card Battle, Miscellaneous, Strategy, Turn-Based
# 126                            Action RPG, Role-Playing
# 129   Fantasy, Massively Multiplayer, Massively Mult...
# 143                            Action RPG, Role-Playing
# 177    Card Battle, Miscellaneous, Strategy, Turn-Based
# 293    Action, First-Person, General, Shooter, Tactical
# 294             Action, First-Person, Shooter, Tactical
# 298             Action, First-Person, Shooter, Tactical
# 374                 Massively Multiplayer, Role-Playing
# 567                   Card Battle, Strategy, Turn-Based
# 588       Command, General, Real-Time, Sci-Fi, Strategy
# 642                            Action RPG, Role-Playing
# 692                        Command, Real-Time, Strategy
# 701          Action, General, MOBA, Real-Time, Strategy
# 771                Command, Real-Time, Sci-Fi, Strategy
# 785                   Card Battle, Strategy, Turn-Based
# 801   Fantasy, Massively Multiplayer, Massively Mult...
# 1202  Fantasy, Massively Multiplayer, Massively Mult...
# 1315  Fantasy, Massively Multiplayer, Massively Mult...
# 1507  Fantasy, Massively Multiplayer, Massively Mult...
# 1769              Fantasy, General, Real-Time, Strategy
# 2312              Fantasy, General, Real-Time, Strategy
# 2622                  Card Battle, Strategy, Turn-Based
# 2746  Fantasy, Massively Multiplayer, Massively Mult...
# 3520                Massively Multiplayer, Role-Playing
# 3957   Card Battle, Miscellaneous, Strategy, Turn-Based
# 4699                  Card Battle, Strategy, Turn-Based
# 7140                       Command, Real-Time, Strategy
# 7700                           Action RPG, Role-Playing
#
#                    developer               publisher rating  \
# 44    Blizzard Entertainment  Blizzard Entertainment      M
# 57    Blizzard Entertainment  Blizzard Entertainment      T
# 64    Blizzard Entertainment  Blizzard Entertainment      M
# 75    Blizzard Entertainment  Blizzard Entertainment      M
# 108   Blizzard Entertainment  Blizzard Entertainment      T
# 126   Blizzard Entertainment  Blizzard Entertainment      M
# 129   Blizzard Entertainment  Blizzard Entertainment      T
# 143   Blizzard Entertainment  Blizzard Entertainment      M
# 177   Blizzard Entertainment  Blizzard Entertainment
# 293   Blizzard Entertainment  Blizzard Entertainment      T
# 294   Blizzard Entertainment  Blizzard Entertainment      T
# 298   Blizzard Entertainment  Blizzard Entertainment      T
# 374   Blizzard Entertainment  Blizzard Entertainment      T
# 567   Blizzard Entertainment  Blizzard Entertainment
# 588   Blizzard Entertainment  Blizzard Entertainment      T
# 642   Blizzard Entertainment  Blizzard Entertainment      M
# 692   Blizzard Entertainment  Blizzard Entertainment
# 701   Blizzard Entertainment  Blizzard Entertainment      T
# 771   Blizzard Entertainment  Blizzard Entertainment      T
# 785   Blizzard Entertainment  Blizzard Entertainment
# 801   Blizzard Entertainment  Blizzard Entertainment      T
# 1202  Blizzard Entertainment  Blizzard Entertainment      T
# 1315  Blizzard Entertainment  Blizzard Entertainment      T
# 1507  Blizzard Entertainment  Blizzard Entertainment      T
# 1769  Blizzard Entertainment  Blizzard Entertainment      T
# 2312  Blizzard Entertainment  Blizzard Entertainment      T
# 2622  Blizzard Entertainment  Blizzard Entertainment
# 2746  Blizzard Entertainment  Blizzard Entertainment      T
# 3520  Blizzard Entertainment  Blizzard Entertainment      T
# 3957  Blizzard Entertainment  Blizzard Entertainment
# 4699  Blizzard Entertainment  Blizzard Entertainment
# 7140  Blizzard Entertainment  Blizzard Entertainment
# 7700  Blizzard Entertainment  Blizzard Entertainment      M
#
#                                        esrb descriptors  \
# 44                              Blood and Gore Violence
# 57    Blood and Gore Language Suggestive Themes Use ...
# 64                              Blood and Gore Violence
# 75
# 108
# 126
# 129
# 143
# 177
# 293
# 294
# 298
# 374
# 567
# 588
# 642                             Blood and Gore Violence
# 692
# 701
# 771   Blood and Gore Language Suggestive Themes Use ...
# 785
# 801   Blood and Gore Crude Humor Mild Language Sugge...
# 1202    Blood Suggestive Themes Use of Alcohol Violence
# 1315  Blood and Gore Suggestive Themes Use of Alcoho...
# 1507    Blood Suggestive Themes Use of Alcohol Violence
# 1769                                     Blood Violence
# 2312                   Animated Violence Blood Violence
# 2622
# 2746  Blood and Gore Crude Humor Mild Language Sugge...
# 3520
# 3957
# 4699
# 7140
# 7700
#
#      number of online players special controllers      number of players  \
# 44            Up to 4 Players
# 57
# 64            Up to 4 Players
# 75            Up to 4 Players
# 108                 2 Players
# 126
# 129     Massively Multiplayer
# 143           Up to 4 Players
# 177
# 293          Up to 12 Players
# 294          Up to 12 Players
# 298          Up to 12 Players
# 374
# 567
# 588
# 642           Up to 4 Players
# 692
# 701          Up to 10 Players
# 771           Up to 4 Players
# 785
# 801     Massively Multiplayer
# 1202    Massively Multiplayer                      Massively Multiplayer
# 1315    Massively Multiplayer
# 1507    Massively Multiplayer
# 1769                                                        1-12 Players
# 2312
# 2622
# 2746    Massively Multiplayer
# 3520    Massively Multiplayer
# 3957
# 4699
# 7140
# 7700
#
#                                           official site         franchise  \
# 44                     http://www.blizzard.com/diablo3/     Diablo Series
# 57                           http://www.starcraft2.com/  Starcraft Series
# 64                     http://www.blizzard.com/diablo3/     Diablo Series
# 75                                                          Diablo Series
# 108                                                       Warcraft Series
# 126                                                         Diablo Series
# 129                                                       Warcraft Series
# 143                                                         Diablo Series
# 177                                                       Warcraft Series
# 293                                                                   NaN
# 294                                                                   NaN
# 298                                                                   NaN
# 374                                                       Warcraft Series
# 567                                                       Warcraft Series
# 588                          http://www.starcraft2.com/  Starcraft Series
# 642                    http://www.blizzard.com/diablo3/     Diablo Series
# 692                                                      Starcraft Series
# 701          http://us.blizzard.com/en-us/games/heroes/               NaN
# 771                          http://www.starcraft2.com/  Starcraft Series
# 785                                                       Warcraft Series
# 801           http://www.worldofwarcraft.com/cataclysm/   Warcraft Series
# 1202  http://worldofwarcraft.com/burningcrusade/inde...   Warcraft Series
# 1315              http://www.worldofwarcraft.com/wrath/   Warcraft Series
# 1507                        http://worldofwarcraft.com/   Warcraft Series
# 1769                     http://www.blizzard.com/war3x/   Warcraft Series
# 2312           http://us.blizzard.com/en-us/games/war3/   Warcraft Series
# 2622                                                      Warcraft Series
# 2746                                                      Warcraft Series
# 3520                                                      Warcraft Series
# 3957                                                      Warcraft Series
# 4699                                                      Warcraft Series
# 7140                                                     Starcraft Series
# 7700                                                        Diablo Series
#
#         year
# 44    2013.0
# 57    2013.0
# 64    2013.0
# 75    2014.0
# 108   2014.0
# 126   2014.0
# 129   2014.0
# 143   2014.0
# 177   2014.0
# 293   2016.0
# 294   2016.0
# 298   2016.0
# 374   2016.0
# 567   2016.0
# 588   2015.0
# 642   2012.0
# 692   2017.0
# 701   2015.0
# 771   2010.0
# 785   2015.0
# 801   2010.0
# 1202  2007.0
# 1315  2008.0
# 1507  2004.0
# 1769  2003.0
# 2312  2002.0
# 2622  2015.0
# 2746  2012.0
# 3520  2018.0
# 3957  2014.0
# 4699  2017.0
# 7140  2016.0
# 7700  2017.0
